# %%
import psycopg2 as pg
import pandas as pd
import pandas.io.sql as psql
import sys,os,re
from datetime import datetime
import pymysql

from time import sleep
from smtplib import SMTP
from email.MIMEMultipart import MIMEMultipart
from email.MIMEText import MIMEText
from email.MIMEImage import MIMEImage

import pdfkit
import wkhtmltopdf
from datetime import date, timedelta

import pandasql
import math

# %%
SQL_EXTRACT = '/home/ricardo/Tripda/cohort'
DATA_DIR = "/home/ricardo/Tripda/cohort/"

# %%
#semanal aux = -1 , dias = 270 red = '<font color="#FF0000">'
#mensal aux = 1 , dias = 300 red = ''

periodo = 'mensal'


if periodo == 'semanal':
    aux = -1
    dias = 270
    red = '<font color="#FF0000">'
elif periodo == 'mensal':
    aux = 1
    dias = 300
    red = ''
else:
    print 'erro'

# %%
countries = []
countries.append(' TOTAL')
countries.append('Argentina + Uruguay')
countries.append('Brasil')
countries.append('Chile')
countries.append('Colombia')
countries.append('India')
countries.append('Malaysia + Singapore')
countries.append('Mexico')
countries.append('Pakistan')
#countries.append('Philippines')
#countries.append('Taiwan')
#countries.append('United States')

month = datetime.now().strftime("%m")
year = datetime.now().strftime("%Y")
months = []
actual_month = datetime.strptime('15' + month + year , "%d%m%Y").date()
actual_month = actual_month - timedelta(days=dias)
for count in range(0,9):
    actual_month = actual_month + timedelta(days=30)
    months.append(actual_month)

reference_month = []
reference_month.append('same_month')
reference_month.append('1_month')
reference_month.append('2_month')
reference_month.append('3_month')
reference_month.append('4_month')
reference_month.append('5_month')
reference_month.append('6_month')
reference_month.append('7_to_12_month')

cohort_type = []
cohort_type.append('RR1')
cohort_type.append('RR1_Ac')
cohort_type.append('RR2')
cohort_type.append('RR2_Ac')

titles_main = ['Country','Month','Cohort size']
titles_cohort = ['(B) <br/> Same month','(C) <br/> 1 month','(D) <br/> 2 months','(E) <br/> 3 months', \
                 '(F) <br/> 4 months','(G) <br/> 5 months','(H) <br/> 6 months','(I) <br/> More than 6 months']
titles_name = []
titles_name.extend(titles_main)
titles_name.extend(titles_cohort)
titles_name.extend(titles_cohort)

# %%
all_drivers_table = pd.read_csv(file(DATA_DIR + "all_drivers.csv"))
first_driver_table = pd.read_csv(file(DATA_DIR + "first_driver.csv"))
all_pax_table = pd.read_csv(file(DATA_DIR + "all_pax.csv"))
first_pax_table = pd.read_csv(file(DATA_DIR + "first_pax.csv"))

# %%
def transform_1(first_table):

    ##### Create a list for first time using Tripda per country and per month #####
    cohort_first = {}
    for locate in countries:
        cohort_first[locate] = {}
        for date in months:
            cohort_first[locate][date] = {}
            
            cohort_first[locate][date]['RR1'] = first_table[(first_table.country == locate) & \
                                         (first_table.year == date.year) & \
                                         (first_table.month == date.month)].user_id.tolist()

            cohort_first[locate][date]['RR2'] = first_table[(first_table.country == locate) & \
                                         (first_table.year == date.year) & \
                                         (first_table.month == date.month)].distance.tolist()

    return cohort_first

# %%
def transform_2(first_table, all_table, cohort_first):

    pysql = lambda q: pandasql.sqldf(q, globals())

    cohort_lists = {}

    for locate in countries:
        cohort_lists[locate] = {}
        
        for date in months:
            cohort_lists[locate][date] = {}
            acumulated_list = []
            
            if cohort_first[locate][date]['RR1'] == []:
                l = []
                intermediary_query = "select distinct all_table.user_id from all_table where all_table.user_id in ('')"
            else:
                l = [str(x) for x in cohort_first[locate][date]['RR1']]
                intermediary_query = "select distinct all_table.user_id from all_table where all_table.user_id in (" + ','.join(l) + ")"

            for reference in reference_month:
                print str(datetime.now()) + ' ==> ' + str(locate) + ' - ' + str(date) + ' - ' + str(reference)
                cohort_lists[locate][date][reference] = {}         

                if reference == 'same_month':
                    reference_date = date
                    same_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                       ' and all_table.month = ' + str(reference_date.month) + \
                                       ' and all_table.count > 1'
                    
                    end_query = ' and ' + same_month_query
                    end_query_Ac = ' and ' + same_month_query
                
                Ac_month = actual_month - timedelta(days=30)
                if reference == '1_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=30)
                    _1_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _1_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + '))'

                Ac_month = actual_month - timedelta(days=60)
                if reference == '2_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=60)
                    _2_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _2_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + '))'
                
                Ac_month = actual_month - timedelta(days=90)
                if reference == '3_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=90)
                    _3_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _3_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + '))' 
                
                Ac_month = actual_month - timedelta(days=120)
                if reference == '4_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=120)
                    _4_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _4_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + '))' 
                
                Ac_month = actual_month - timedelta(days=150)
                if reference == '5_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=150)
                    _5_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _5_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + '))' 
        
                Ac_month = actual_month - timedelta(days=180)
                if reference == '6_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=180)
                    _6_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _6_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + '))' 

                Ac_month = actual_month - timedelta(days=210)
                if reference == '7_to_12_month':
                    reference_date = date + timedelta(days=210)
                    _7_to_12_month_query = '((all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month) + ')'
                    reference_date = date + timedelta(days=240)
                    _7_to_12_month_query += ' or (all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month) + ')'
                    reference_date = date + timedelta(days=270)
                    _7_to_12_month_query += ' or (all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month) + ')'
                    reference_date = date + timedelta(days=300)
                    _7_to_12_month_query += ' or (all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month) + ')'
                    reference_date = date + timedelta(days=330)
                    _7_to_12_month_query += ' or (all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month) + ')'
                    reference_date = date + timedelta(days=360)
                    _7_to_12_month_query += ' or (all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month) + '))'
                    
                    end_query = ' and ' + _7_to_12_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + ') or (' \
                                        + _7_to_12_month_query + '))'

                auxiliar_query = intermediary_query + end_query
                
                auxiliar_df = pandasql.sqldf(auxiliar_query, locals()) 
                auxiliar_list = auxiliar_df['user_id'].values.tolist()

                #List of accumulated users on the referent date
                acumulated_list.extend(auxiliar_list)
                acumulated_list = list(set(acumulated_list))

                ml = [str(x) for x in l]
                al = [str(x) for x in acumulated_list]
       
                if ml == []:
                    RR1_query = "select count(distinct all_table.user_id) from all_table where all_table.user_id in ('')"
                    RR2_query = "select sum(all_table.distance) from all_table where all_table.user_id in ('')"
                else:
                    RR1_query = "select count(distinct all_table.user_id) from all_table where all_table.user_id in (" + ','.join(ml) + ')'
                    RR2_query = "select sum(all_table.distance) from all_table where all_table.user_id in (" + ','.join(ml) + ')'

                if al == []:
                    RR1Ac_query = "select count(distinct all_table.user_id) from all_table where all_table.user_id in ('')"
                    RR2Ac_query = "select sum(all_table.distance) from all_table where all_table.user_id in ('')"
                else:
                    RR1Ac_query = "select count(distinct all_table.user_id) from all_table where all_table.user_id in (" + ','.join(al) + ')'
                    RR2Ac_query = "select sum(all_table.distance) from all_table where all_table.user_id in (" + ','.join(al) + ')'              
                 
                RR1_query += end_query
                RR1Ac_query += end_query_Ac
                RR2_query += end_query
                RR2Ac_query += end_query_Ac

                default_format = lambda x: str(x).translate(None, ''.join(['[' , ']' , '.', ' ']))
                
                cohort_lists[locate][date][reference] = {}
                
                final_df = pandasql.sqldf(RR1_query, locals())
                if default_format(final_df.values) == 'None':
                    cohort_lists[locate][date][reference]['RR1'] = 0
                else:
                    cohort_lists[locate][date][reference]['RR1'] = default_format(final_df.values)

                final_df = pandasql.sqldf(RR1Ac_query, locals()) 
                if default_format(final_df.values) == 'None':
                    cohort_lists[locate][date][reference]['RR1_Ac'] = 0
                else:
                    cohort_lists[locate][date][reference]['RR1_Ac'] = default_format(final_df.values)
                
                final_df = pandasql.sqldf(RR2_query, locals()) 
                if default_format(final_df.values) == 'None':
                    cohort_lists[locate][date][reference]['RR2'] = 0
                else:
                    cohort_lists[locate][date][reference]['RR2'] = default_format(final_df.values)
                
                final_df = pandasql.sqldf(RR2Ac_query, locals()) 
                if default_format(final_df.values) == 'None':
                    cohort_lists[locate][date][reference]['RR2_Ac'] = 0
                else:
                    cohort_lists[locate][date][reference]['RR2_Ac'] = default_format(final_df.values)
                    
    for locate in countries:
        for date in months:
            for reference in reference_month:
                for cohort in cohort_type:
                    cohort_lists[' TOTAL'][date][reference][cohort] =  str(int(cohort_lists[' TOTAL'][date][reference][cohort]) +
                                                                        int(cohort_lists[locate][date][reference][cohort]))
                    
    return cohort_lists

# %%
def transform_3(cohort_first):

    cohort_size = {}
    for locate in countries:
        cohort_size[locate] = {}
        
        for date in months:
            cohort_size[locate][date] = {}
            
            if int(date.month) == int(month) and int(date.year) == int(year):
                cohort_size[locate][date]['RR1'] = aux*len(cohort_first[locate][date]['RR1'])
                cohort_size[locate][date]['RR2'] = aux*sum([int(x) for x in cohort_first[locate][date]['RR2']])

                cohort_size[' TOTAL'][date]['RR1'] = cohort_size[' TOTAL'][date]['RR1'] + aux*int(math.sqrt(cohort_size[locate][date]['RR1']*cohort_size[locate][date]['RR1'])) 
                cohort_size[' TOTAL'][date]['RR2'] = cohort_size[' TOTAL'][date]['RR2'] + aux*int(math.sqrt(cohort_size[locate][date]['RR2']*cohort_size[locate][date]['RR2']))            
            else:
                cohort_size[locate][date]['RR1'] = len(cohort_first[locate][date]['RR1'])
                cohort_size[locate][date]['RR2'] = sum([int(x) for x in cohort_first[locate][date]['RR2']]) 
                
                cohort_size[' TOTAL'][date]['RR1'] += int(math.sqrt(cohort_size[locate][date]['RR1']*cohort_size[locate][date]['RR1'])) 
                cohort_size[' TOTAL'][date]['RR2'] += int(math.sqrt(cohort_size[locate][date]['RR2']*cohort_size[locate][date]['RR2']))              


    return cohort_size

# %%
def transform_4(cohort_lists):
    for country in countries:
        for cohort in cohort_type:
            
            counter = len(months) - 1
            for reference in reference_month:
                counter -= 1
                aux = counter
                for date in months:
                    
                    if aux >= 0:
                        cohort_lists[country][date][reference][cohort] = int(cohort_lists[country][date][reference][cohort])
                        aux -= 1
                    elif aux == -1:
                        if int(cohort_lists[country][date][reference][cohort]) == 0:
                            cohort_lists[country][date][reference][cohort] = aux*0.000001
                        else:
                            cohort_lists[country][date][reference][cohort] = aux*int(cohort_lists[country][date][reference][cohort])
                            
                        aux -= 1                   
                    else:
                        cohort_lists[country][date][reference][cohort] = pow(10,100)

    return cohort_lists

# %%
def html_inicial():

    ### TEXTO INICIAL ##########################################
    
    html_texto_inicial = "Please find bellow the Pax Cohort Report.\n <br/> \
    I attached Eduardo's presentation with the meaning of each cohort (for any doubt). \n <br/>\
    Also, please let me know if you need any additional data or help reading the report. \n <br/>\
    PDF attached, with the same data. <br/><br/><br/>\n\n"
    
    return html_texto_inicial

# %%
def html (cohort_lists, cohort_size, index):

    import pandas
    import numpy as np

    ### TITULO ##########################################
    if index == 1:
        html_titulo = '\n <br/> <table border="1"; style="font-size:30px"; align="center"; width="1100"; height="55";>\
    <th>Cohort - Driver</th></table><br/><br/>\n\n'
    else:
        html_titulo = '\n <br/> <table border="1"; style="font-size:30px"; align="center"; width="1100"; height="55";>\
    <th>Cohort - Passenger</th></table><br/><br/>\n\n'        
    ### CORPO 1 (RR1)##########################################
    rate_format = lambda x: str('%.1f' % x) + '%'

    html_corpo = '<table border="1" style="font-size:12px; border-collapse: collapse;" width="1100" align="center"> \
    <style> table, th, td {border: 1px solid black;} </style>\n'

    html_corpo += '    <tr> \n\
            <th colspan="3"></th> \n\
            <th bgcolor="#18BD9D" colspan="8" style="border-width: 2px;"><font color = "white">RR1</font></th> \n\
            <th bgcolor="#18BD9D" colspan="8" style="border-width: 2px;"><font color = "white">RR1 Acummulated</font></th> \n\
        </tr>\n\n'

    html_corpo += '    <tr bgcolor="#36E6C4" colspan="2"  height="60" style="border: solid 2px; font-size:9px">\n'

    for title in titles_name:
        if title == 'Month':
            html_corpo += '       <th width="200" style="border-width: 1px 2px 1px 1px ;">'
        else:
            html_corpo += '       <th width="90" style="border-width: 1px 2px 1px 1px ;">'
        html_corpo += title
        html_corpo +='</th>\n'
    html_corpo += '    </tr>\n\n'

    ref_country = ''
    for country in countries:
        for date in months:
            if country == ref_country:
                html_corpo += '    <tr>\n'
                html_corpo += ''
            else:
                html_corpo += '    <tr style="border-top: 2px solid black;">\n'
                html_corpo += '       <td align="center"; rowspan=" '+ str(len(months)) +'";>' + country + '</td>\n'
                ref_country = country
            html_corpo += '       <td align="center";>' + date.strftime("%b %Y") + '</td>\n'
            
            if cohort_size[country][date]['RR1'] < 0:
                cohort_size[country][date]['RR1'] = -cohort_size[country][date]['RR1']
                html_corpo += '       <td align="center"; bgcolor="#EEEEEE";><font color="#FF0000">' + str(cohort_size[country][date]['RR1']) + '</td>\n'
            else:
                html_corpo += '       <td align="center"; bgcolor="#EEEEEE">' + str(cohort_size[country][date]['RR1']) + '</td>\n'
                
            for cohort in ('RR1','RR1_Ac'):
                for reference in reference_month:
                    if reference == '6_to_12_month':
                        if cohort_size[country][date]['RR1'] == 0 or cohort_lists[country][date][reference][cohort] >= pow(10,100):
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>''</td>\n'
                        elif cohort_lists[country][date][reference][cohort] < 0:
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>' + red + rate_format(100*float(-cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR1']) + '</td>\n'
                        else:
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>' + rate_format(100*float(cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR1']) + '</td>\n'
                    else:
                        if cohort_size[country][date]['RR1'] == 0 or cohort_lists[country][date][reference][cohort] >= pow(10,100):
                            html_corpo += '       <td align="center";>''</td>\n'
                        elif cohort_lists[country][date][reference][cohort] < 0:
                            html_corpo += '       <td align="center";">' + red + rate_format(100*float(-cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR1']) + '</td>\n'
                        else:
                            html_corpo += '       <td align="center";>' + rate_format(100*float(cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR1']) + '</td>\n'
            html_corpo += '    </tr>\n'

    html_corpo += '</table>\n <br/><br/>'        


    ### CORPO 2 (RR2)##########################################

    html_corpo += '\n\n<table border="1" style="font-size:12px; border-collapse: collapse;" width="1100" align="center"> \
    <style> table, th, td {border: 1px solid black;} </style>\n'

    html_corpo += '    <tr> \n\
            <th colspan="3"></th> \n\
            <th bgcolor="#18BD9D" colspan="8" style="border-width: 2px;"><font color = "white">RR2</font></th> \n\
            <th bgcolor="#18BD9D" colspan="8" style="border-width: 2px;"><font color = "white">RR2 Acummulated</font></th> \n\
        </tr>\n\n'

    html_corpo += '    <tr bgcolor="#36E6C4" colspan="2"  height="60" style="border: solid 2px; font-size:9px">\n'

    for title in titles_name:
        if title == 'Month':
            html_corpo += '       <th width="200" style="border-width: 1px 2px 1px 1px ;">'
        else:
            html_corpo += '       <th width="90" style="border-width: 1px 2px 1px 1px ;">'
        html_corpo += title
        html_corpo +='</th>\n'
    html_corpo += '    </tr>\n\n'

    ref_country = ''
    for country in countries:
        for date in months:
            if country == ref_country:
                html_corpo += '    <tr>\n'
                html_corpo += ''
            else:
                html_corpo += '    <tr style="border-top: 2px solid black;">\n'
                html_corpo += '       <td align="center"; rowspan=" '+ str(len(months)) +'";>' + country + '</td>\n'
                ref_country = country
            html_corpo += '       <td align="center";>' + date.strftime("%b %Y") + '</td>\n'
            
            if cohort_size[country][date]['RR2'] < 0:
                cohort_size[country][date]['RR2'] = -cohort_size[country][date]['RR2']
                html_corpo += '       <td align="center"; bgcolor="#EEEEEE";><font color="#FF0000">' + str(cohort_size[country][date]['RR2']) + '</td>\n'
            else:
                html_corpo += '       <td align="center"; bgcolor="#EEEEEE">' + str(cohort_size[country][date]['RR2']) + '</td>\n'
                
            for cohort in ('RR2','RR2_Ac'):
                for reference in reference_month:
                    if reference == '6_to_12_month':
                        if cohort_size[country][date]['RR2'] == 0 or cohort_lists[country][date][reference][cohort] >= pow(10,100):
                             html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>''</td>\n'
                        elif cohort_lists[country][date][reference][cohort] < 0:
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>' + red + rate_format(100*float(-cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR2']) + '</td>\n'
                        else:
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>' + rate_format(100*float(cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR2']) + '</td>\n'
                    else:
                        if cohort_size[country][date]['RR2'] == 0 or cohort_lists[country][date][reference][cohort] >= pow(10,100):
                            html_corpo += '       <td align="center";>''</td>\n'
                        elif cohort_lists[country][date][reference][cohort] < 0:
                            html_corpo += '       <td align="center";>' + red + rate_format(100*float(-cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR2']) + '</td>\n'
                        else:
                            html_corpo += '       <td align="center";>' + rate_format(100*float(cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR2']) + '</td>\n'
            html_corpo += '    </tr>\n'

    html_corpo += '</table> \n <br/>'

    html_body = html_titulo + html_corpo
    
    return html_body

# %%
def html_final():

    ### LEGENDA GERAL ##########################################
    html_legenda_geral = '<table border="1" style="font-size:12px; border-collapse: collapse; border-width: 2px;" width="700">\n\
    <tr>  \n\
        <th bgcolor="#18BD9D" width="160"><font color = "white">Traffic activity view</font></th>\n\
        <td>Date of when users book or offer a ride on the site</td>\n\
    </tr>\n\
    <tr>  \n\
        <th bgcolor="#18BD9D"><font color = "white">Realized view</font></th>\n\
        <td>Date of when trips actually occurs</td>\n\
    </tr>\n \
    </table><br/>\n'

    ### LEGENDA DETALHADA 1 ##########################################
    html_legenda_detalhada = '<table border="1" style="font-size:12px; border-collapse: collapse; border-width: 2px;" width="1100">\n\
    \
    <tr>  \n\
        <th bgcolor="#18BD9D" rowspan="6"  width="120" align="center"><font color = "white">Traffic activity view</font></th>\n\
        <th bgcolor="#36E6C4" width="200">New Users</th>\n\
        <td>New users on the given period</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">New Drivers</th>\n\
        <td>New drivers on the given period</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">New Passangers</th>\n\
        <td>New passangers  on the given period</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Trips Offered</th>\n\
        <td>Number of new trips offered in the given date. Number of trips don\'t include stopovers.\
    Eg: a trip from San Francisco to Los Angeles, stoping at Monterey and Santa Maria would count as 1 trip offered.</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Bookings</th>\n\
        <td>Number of bookings in the given period. Eg: a booking of 3 seats booked on 12/09/2014 to travel on 14/09/2014 would be counted as 1 booking on 12/09/2014 </td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Available Seat Kilometer (ASK)</th>\n\
        <td>Number of seats offered in the given period times the number of kilometers of each trip.</td>\n\
    </tr>\n'

    ### LEGENDA DETALHADA 2 ##########################################
    html_legenda_detalhada += '<tr>  \n\
        <th bgcolor="#18BD9D" rowspan="7" align="center"><font color = "white">Realized view</font></th>\n\
        <th bgcolor="#36E6C4">Trips realized</th>\n\
        <td>Number of trips with at least one Tripda passenger in the given period, regardless the number of bookings in the car.\
    Eg: a trip from Bogota to Manizales with 3 PAX and 3 different bookings would caount as 1 trip.</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">PAX transported</th>\n\
        <td>Number os passengers transported in the given period</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Average PAX per trip realized</th>\n\
        <td>Average PAX per trip realized  (PAX transported / Trips realized)</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Realized TRIP Yield</th>\n\
        <td>Percentage of outstanding trips offered that converted into a realized trip, having at least one PAX transported.\
    Don\'t confuse with "Trips offered". Here we consider the date when the trip takes place. \
    Eg: if in one day Malaysia had 100 trips outstanding and 12 trips realized, the \"Realized trip yield\" would be 12%.</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Average realized trip distance</th>\n\
        <td>Average distance traveled in the given period. The average is weighted by the number of passenger on each trip.</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Driver Cancelation rate</th>\n\
        <td>Percentage of PAX affected by driver cancellations for trips that would happen in that given period.\
    If a Driver cancels a trip, in which no PAX has yet booked a seat, this wont\'t count for this statistics. \
    Eg: If there are 100 PAX travelig on Tripda in a given day and one driver cancels a ride with 4 seats booked, \
    the cacelation rate would be 4%</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">PAX Cancelation rate</th>\n\
        <td>Percentage of trips canceled by passengers that would actually become a real trip in the given period</td>\n\
    </tr>\n\
    \
    </table>'


    html_legend = html_legenda_geral + html_legenda_detalhada


    return html_legend

# %%
def SendEmail(subject, msgText, to, user,password, alias, imgName, replyTo=None):
    sender = alias

    try:
        conn = SMTP('smtp.gmail.com', 587)

        msg = MIMEMultipart()
        msg.attach(MIMEText(msgText, 'html'))
        msg['Subject']= subject
        msg['From']   = sender
        msg['cc'] = to
        #msg['cc'] = ', '.join(to)

        if replyTo:
            msg['reply-to'] = replyTo

        if imgName != None:
            fp = open(imgName, 'rb')
            img = MIMEImage(fp.read(), _subtype="pdf")
            fp.close()
            img.add_header('Content-Disposition', 'attachment', filename = imgName)
            msg.attach(img)

        conn.ehlo()
        conn.starttls()
        conn.set_debuglevel(False)
        conn.login(user, password)
        try:
            conn.sendmail(sender, to, msg.as_string())
        finally:
            conn.close()
    except:
        print "Unexpected error:", sys.exc_info()[0]

def titles (index):
    import time
    from time import strftime

    month = (date.today().strftime("%B"))
    Subject = "Tripda - Pax Cohort Report - " + month
    
    month = date.today().strftime("%B")
    year = date.today().strftime("%y")
    PDFReport_Name = "Cohorts " + month + " 20" +  year + ".pdf"

    if index == 1 :
        return Subject
    else:
        return PDFReport_Name

# %%
driver_first_list = transform_1(first_driver_table)
pax_first_list = transform_1(first_pax_table)

cohort_driver = transform_2(first_driver_table, all_drivers_table, driver_first_list)
cohort_passenger = transform_2(first_pax_table, all_pax_table, pax_first_list)

cohort_size_driver = transform_3(driver_first_list)
cohort_size_pax = transform_3(pax_first_list)

cohort_driver_final = transform_4(cohort_driver)
cohort_passenger_final = transform_4(cohort_passenger)
# Out:
# 2016-01-04 14:04:21.299792 ==>  TOTAL - 2015-04-20 - same_month
# 2016-01-04 14:04:22.555084 ==>  TOTAL - 2015-04-20 - 1_month
# 2016-01-04 14:04:23.548419 ==>  TOTAL - 2015-04-20 - 2_month
# 2016-01-04 14:04:24.598257 ==>  TOTAL - 2015-04-20 - 3_month
# 2016-01-04 14:04:25.550836 ==>  TOTAL - 2015-04-20 - 4_month
# 2016-01-04 14:04:26.620728 ==>  TOTAL - 2015-04-20 - 5_month
# 2016-01-04 14:04:27.702621 ==>  TOTAL - 2015-04-20 - 6_month
# 2016-01-04 14:04:28.758357 ==>  TOTAL - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:04:30.253638 ==>  TOTAL - 2015-05-20 - same_month
# 2016-01-04 14:04:31.850510 ==>  TOTAL - 2015-05-20 - 1_month
# 2016-01-04 14:04:33.063190 ==>  TOTAL - 2015-05-20 - 2_month
# 2016-01-04 14:04:34.448688 ==>  TOTAL - 2015-05-20 - 3_month
# 2016-01-04 14:04:35.472549 ==>  TOTAL - 2015-05-20 - 4_month
# 2016-01-04 14:04:36.517489 ==>  TOTAL - 2015-05-20 - 5_month
# 2016-01-04 14:04:37.639311 ==>  TOTAL - 2015-05-20 - 6_month
# 2016-01-04 14:04:38.959062 ==>  TOTAL - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:04:40.618223 ==>  TOTAL - 2015-06-19 - same_month
# 2016-01-04 14:04:42.076753 ==>  TOTAL - 2015-06-19 - 1_month
# 2016-01-04 14:04:43.391727 ==>  TOTAL - 2015-06-19 - 2_month
# 2016-01-04 14:04:44.487907 ==>  TOTAL - 2015-06-19 - 3_month
# 2016-01-04 14:04:45.613090 ==>  TOTAL - 2015-06-19 - 4_month
# 2016-01-04 14:04:46.619646 ==>  TOTAL - 2015-06-19 - 5_month
# 2016-01-04 14:04:47.594082 ==>  TOTAL - 2015-06-19 - 6_month
# 2016-01-04 14:04:48.523113 ==>  TOTAL - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:04:49.478608 ==>  TOTAL - 2015-07-19 - same_month
# 2016-01-04 14:04:50.397780 ==>  TOTAL - 2015-07-19 - 1_month
# 2016-01-04 14:04:51.350311 ==>  TOTAL - 2015-07-19 - 2_month
# 2016-01-04 14:04:52.448038 ==>  TOTAL - 2015-07-19 - 3_month
# 2016-01-04 14:04:53.468027 ==>  TOTAL - 2015-07-19 - 4_month
# 2016-01-04 14:04:54.548660 ==>  TOTAL - 2015-07-19 - 5_month
# 2016-01-04 14:04:55.512200 ==>  TOTAL - 2015-07-19 - 6_month
# 2016-01-04 14:04:56.728923 ==>  TOTAL - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:04:57.792893 ==>  TOTAL - 2015-08-18 - same_month
# 2016-01-04 14:04:58.935573 ==>  TOTAL - 2015-08-18 - 1_month
# 2016-01-04 14:04:59.980845 ==>  TOTAL - 2015-08-18 - 2_month
# 2016-01-04 14:05:00.976823 ==>  TOTAL - 2015-08-18 - 3_month
# 2016-01-04 14:05:01.942015 ==>  TOTAL - 2015-08-18 - 4_month
# 2016-01-04 14:05:03.687218 ==>  TOTAL - 2015-08-18 - 5_month
# 2016-01-04 14:05:04.688538 ==>  TOTAL - 2015-08-18 - 6_month
# 2016-01-04 14:05:05.624123 ==>  TOTAL - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:05:06.636398 ==>  TOTAL - 2015-09-17 - same_month
# 2016-01-04 14:05:07.607437 ==>  TOTAL - 2015-09-17 - 1_month
# 2016-01-04 14:05:08.646709 ==>  TOTAL - 2015-09-17 - 2_month
# 2016-01-04 14:05:09.630875 ==>  TOTAL - 2015-09-17 - 3_month
# 2016-01-04 14:05:10.613385 ==>  TOTAL - 2015-09-17 - 4_month
# 2016-01-04 14:05:11.637399 ==>  TOTAL - 2015-09-17 - 5_month
# 2016-01-04 14:05:12.612709 ==>  TOTAL - 2015-09-17 - 6_month
# 2016-01-04 14:05:13.743501 ==>  TOTAL - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:05:14.739801 ==>  TOTAL - 2015-10-17 - same_month
# 2016-01-04 14:05:15.714961 ==>  TOTAL - 2015-10-17 - 1_month
# 2016-01-04 14:05:16.619841 ==>  TOTAL - 2015-10-17 - 2_month
# 2016-01-04 14:05:17.569965 ==>  TOTAL - 2015-10-17 - 3_month
# 2016-01-04 14:05:18.807257 ==>  TOTAL - 2015-10-17 - 4_month
# 2016-01-04 14:05:19.830485 ==>  TOTAL - 2015-10-17 - 5_month
# 2016-01-04 14:05:20.998661 ==>  TOTAL - 2015-10-17 - 6_month
# 2016-01-04 14:05:22.122314 ==>  TOTAL - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:05:23.153643 ==>  TOTAL - 2015-11-16 - same_month
# 2016-01-04 14:05:24.160415 ==>  TOTAL - 2015-11-16 - 1_month
# 2016-01-04 14:05:25.102641 ==>  TOTAL - 2015-11-16 - 2_month
# 2016-01-04 14:05:26.060804 ==>  TOTAL - 2015-11-16 - 3_month
# 2016-01-04 14:05:26.982411 ==>  TOTAL - 2015-11-16 - 4_month
# 2016-01-04 14:05:27.906685 ==>  TOTAL - 2015-11-16 - 5_month
# 2016-01-04 14:05:28.879389 ==>  TOTAL - 2015-11-16 - 6_month
# 2016-01-04 14:05:29.814359 ==>  TOTAL - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:05:30.813849 ==>  TOTAL - 2015-12-16 - same_month
# 2016-01-04 14:05:31.816899 ==>  TOTAL - 2015-12-16 - 1_month
# 2016-01-04 14:05:32.769915 ==>  TOTAL - 2015-12-16 - 2_month
# 2016-01-04 14:05:33.692878 ==>  TOTAL - 2015-12-16 - 3_month
# 2016-01-04 14:05:34.623347 ==>  TOTAL - 2015-12-16 - 4_month
# 2016-01-04 14:05:35.556524 ==>  TOTAL - 2015-12-16 - 5_month
# 2016-01-04 14:05:36.709079 ==>  TOTAL - 2015-12-16 - 6_month
# 2016-01-04 14:05:37.675045 ==>  TOTAL - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:05:38.645467 ==> Argentina + Uruguay - 2015-04-20 - same_month
# 2016-01-04 14:05:39.656379 ==> Argentina + Uruguay - 2015-04-20 - 1_month
# 2016-01-04 14:05:40.836072 ==> Argentina + Uruguay - 2015-04-20 - 2_month
# 2016-01-04 14:05:41.853663 ==> Argentina + Uruguay - 2015-04-20 - 3_month
# 2016-01-04 14:05:42.833404 ==> Argentina + Uruguay - 2015-04-20 - 4_month
# 2016-01-04 14:05:43.787072 ==> Argentina + Uruguay - 2015-04-20 - 5_month
# 2016-01-04 14:05:44.714423 ==> Argentina + Uruguay - 2015-04-20 - 6_month
# 2016-01-04 14:05:45.720061 ==> Argentina + Uruguay - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:05:46.686604 ==> Argentina + Uruguay - 2015-05-20 - same_month
# 2016-01-04 14:05:47.723175 ==> Argentina + Uruguay - 2015-05-20 - 1_month
# 2016-01-04 14:05:48.740661 ==> Argentina + Uruguay - 2015-05-20 - 2_month
# 2016-01-04 14:05:49.728461 ==> Argentina + Uruguay - 2015-05-20 - 3_month
# 2016-01-04 14:05:50.702722 ==> Argentina + Uruguay - 2015-05-20 - 4_month
# 2016-01-04 14:05:51.661294 ==> Argentina + Uruguay - 2015-05-20 - 5_month
# 2016-01-04 14:05:52.622057 ==> Argentina + Uruguay - 2015-05-20 - 6_month
# 2016-01-04 14:05:53.577349 ==> Argentina + Uruguay - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:05:54.537993 ==> Argentina + Uruguay - 2015-06-19 - same_month
# 2016-01-04 14:05:55.493612 ==> Argentina + Uruguay - 2015-06-19 - 1_month
# 2016-01-04 14:05:56.448421 ==> Argentina + Uruguay - 2015-06-19 - 2_month
# 2016-01-04 14:05:57.452583 ==> Argentina + Uruguay - 2015-06-19 - 3_month
# 2016-01-04 14:05:58.411818 ==> Argentina + Uruguay - 2015-06-19 - 4_month
# 2016-01-04 14:05:59.387301 ==> Argentina + Uruguay - 2015-06-19 - 5_month
# 2016-01-04 14:06:00.342286 ==> Argentina + Uruguay - 2015-06-19 - 6_month
# 2016-01-04 14:06:01.287375 ==> Argentina + Uruguay - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:06:02.273023 ==> Argentina + Uruguay - 2015-07-19 - same_month
# 2016-01-04 14:06:03.204575 ==> Argentina + Uruguay - 2015-07-19 - 1_month
# 2016-01-04 14:06:04.131538 ==> Argentina + Uruguay - 2015-07-19 - 2_month
# 2016-01-04 14:06:05.062976 ==> Argentina + Uruguay - 2015-07-19 - 3_month
# 2016-01-04 14:06:06.014325 ==> Argentina + Uruguay - 2015-07-19 - 4_month
# 2016-01-04 14:06:07.008792 ==> Argentina + Uruguay - 2015-07-19 - 5_month
# 2016-01-04 14:06:07.977934 ==> Argentina + Uruguay - 2015-07-19 - 6_month
# 2016-01-04 14:06:09.142758 ==> Argentina + Uruguay - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:06:10.118405 ==> Argentina + Uruguay - 2015-08-18 - same_month
# 2016-01-04 14:06:11.110405 ==> Argentina + Uruguay - 2015-08-18 - 1_month
# 2016-01-04 14:06:12.110466 ==> Argentina + Uruguay - 2015-08-18 - 2_month
# 2016-01-04 14:06:13.131979 ==> Argentina + Uruguay - 2015-08-18 - 3_month
# 2016-01-04 14:06:14.424396 ==> Argentina + Uruguay - 2015-08-18 - 4_month
# 2016-01-04 14:06:15.822945 ==> Argentina + Uruguay - 2015-08-18 - 5_month
# 2016-01-04 14:06:16.964613 ==> Argentina + Uruguay - 2015-08-18 - 6_month
# 2016-01-04 14:06:18.116392 ==> Argentina + Uruguay - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:06:19.119114 ==> Argentina + Uruguay - 2015-09-17 - same_month
# 2016-01-04 14:06:20.141248 ==> Argentina + Uruguay - 2015-09-17 - 1_month
# 2016-01-04 14:06:21.300375 ==> Argentina + Uruguay - 2015-09-17 - 2_month
# 2016-01-04 14:06:22.279545 ==> Argentina + Uruguay - 2015-09-17 - 3_month
# 2016-01-04 14:06:23.237418 ==> Argentina + Uruguay - 2015-09-17 - 4_month
# 2016-01-04 14:06:24.433117 ==> Argentina + Uruguay - 2015-09-17 - 5_month
# 2016-01-04 14:06:25.392856 ==> Argentina + Uruguay - 2015-09-17 - 6_month
# 2016-01-04 14:06:26.382609 ==> Argentina + Uruguay - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:06:27.315569 ==> Argentina + Uruguay - 2015-10-17 - same_month
# 2016-01-04 14:06:28.413963 ==> Argentina + Uruguay - 2015-10-17 - 1_month
# 2016-01-04 14:06:29.424338 ==> Argentina + Uruguay - 2015-10-17 - 2_month
# 2016-01-04 14:06:30.590764 ==> Argentina + Uruguay - 2015-10-17 - 3_month
# 2016-01-04 14:06:31.884346 ==> Argentina + Uruguay - 2015-10-17 - 4_month
# 2016-01-04 14:06:33.314106 ==> Argentina + Uruguay - 2015-10-17 - 5_month
# 2016-01-04 14:06:34.358031 ==> Argentina + Uruguay - 2015-10-17 - 6_month
# 2016-01-04 14:06:36.041309 ==> Argentina + Uruguay - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:06:37.657666 ==> Argentina + Uruguay - 2015-11-16 - same_month
# 2016-01-04 14:06:39.458312 ==> Argentina + Uruguay - 2015-11-16 - 1_month
# 2016-01-04 14:06:41.275683 ==> Argentina + Uruguay - 2015-11-16 - 2_month
# 2016-01-04 14:06:42.997405 ==> Argentina + Uruguay - 2015-11-16 - 3_month
# 2016-01-04 14:06:44.520959 ==> Argentina + Uruguay - 2015-11-16 - 4_month
# 2016-01-04 14:06:45.868733 ==> Argentina + Uruguay - 2015-11-16 - 5_month
# 2016-01-04 14:06:47.211107 ==> Argentina + Uruguay - 2015-11-16 - 6_month
# 2016-01-04 14:06:48.505925 ==> Argentina + Uruguay - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:06:49.937293 ==> Argentina + Uruguay - 2015-12-16 - same_month
# 2016-01-04 14:06:51.555773 ==> Argentina + Uruguay - 2015-12-16 - 1_month
# 2016-01-04 14:06:52.912275 ==> Argentina + Uruguay - 2015-12-16 - 2_month
# 2016-01-04 14:06:54.632502 ==> Argentina + Uruguay - 2015-12-16 - 3_month
# 2016-01-04 14:06:56.319221 ==> Argentina + Uruguay - 2015-12-16 - 4_month
# 2016-01-04 14:06:57.950837 ==> Argentina + Uruguay - 2015-12-16 - 5_month
# 2016-01-04 14:06:59.364166 ==> Argentina + Uruguay - 2015-12-16 - 6_month
# 2016-01-04 14:07:00.791520 ==> Argentina + Uruguay - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:07:02.151560 ==> Brasil - 2015-04-20 - same_month
# 2016-01-04 14:07:03.922765 ==> Brasil - 2015-04-20 - 1_month
# 2016-01-04 14:07:05.331384 ==> Brasil - 2015-04-20 - 2_month
# 2016-01-04 14:07:06.920282 ==> Brasil - 2015-04-20 - 3_month
# 2016-01-04 14:07:08.655644 ==> Brasil - 2015-04-20 - 4_month
# 2016-01-04 14:07:10.268358 ==> Brasil - 2015-04-20 - 5_month
# 2016-01-04 14:07:11.756273 ==> Brasil - 2015-04-20 - 6_month
# 2016-01-04 14:07:12.796573 ==> Brasil - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:07:13.939428 ==> Brasil - 2015-05-20 - same_month
# 2016-01-04 14:07:14.998675 ==> Brasil - 2015-05-20 - 1_month
# 2016-01-04 14:07:16.031955 ==> Brasil - 2015-05-20 - 2_month
# 2016-01-04 14:07:17.300793 ==> Brasil - 2015-05-20 - 3_month
# 2016-01-04 14:07:18.371165 ==> Brasil - 2015-05-20 - 4_month
# 2016-01-04 14:07:19.896129 ==> Brasil - 2015-05-20 - 5_month
# 2016-01-04 14:07:20.999302 ==> Brasil - 2015-05-20 - 6_month
# 2016-01-04 14:07:22.091513 ==> Brasil - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:07:23.180902 ==> Brasil - 2015-06-19 - same_month
# 2016-01-04 14:07:24.663400 ==> Brasil - 2015-06-19 - 1_month
# 2016-01-04 14:07:26.082451 ==> Brasil - 2015-06-19 - 2_month
# 2016-01-04 14:07:27.394483 ==> Brasil - 2015-06-19 - 3_month
# 2016-01-04 14:07:28.960679 ==> Brasil - 2015-06-19 - 4_month
# 2016-01-04 14:07:30.686878 ==> Brasil - 2015-06-19 - 5_month
# 2016-01-04 14:07:32.302337 ==> Brasil - 2015-06-19 - 6_month
# 2016-01-04 14:07:33.304245 ==> Brasil - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:07:34.310065 ==> Brasil - 2015-07-19 - same_month
# 2016-01-04 14:07:35.260179 ==> Brasil - 2015-07-19 - 1_month
# 2016-01-04 14:07:36.221570 ==> Brasil - 2015-07-19 - 2_month
# 2016-01-04 14:07:37.634666 ==> Brasil - 2015-07-19 - 3_month
# 2016-01-04 14:07:39.378980 ==> Brasil - 2015-07-19 - 4_month
# 2016-01-04 14:07:40.727011 ==> Brasil - 2015-07-19 - 5_month
# 2016-01-04 14:07:41.720824 ==> Brasil - 2015-07-19 - 6_month
# 2016-01-04 14:07:42.706893 ==> Brasil - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:07:43.657590 ==> Brasil - 2015-08-18 - same_month
# 2016-01-04 14:07:44.618055 ==> Brasil - 2015-08-18 - 1_month
# 2016-01-04 14:07:45.597997 ==> Brasil - 2015-08-18 - 2_month
# 2016-01-04 14:07:47.180759 ==> Brasil - 2015-08-18 - 3_month
# 2016-01-04 14:07:48.924935 ==> Brasil - 2015-08-18 - 4_month
# 2016-01-04 14:07:50.151192 ==> Brasil - 2015-08-18 - 5_month
# 2016-01-04 14:07:51.138437 ==> Brasil - 2015-08-18 - 6_month
# 2016-01-04 14:07:52.092611 ==> Brasil - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:07:53.219723 ==> Brasil - 2015-09-17 - same_month
# 2016-01-04 14:07:54.194273 ==> Brasil - 2015-09-17 - 1_month
# 2016-01-04 14:07:55.196080 ==> Brasil - 2015-09-17 - 2_month
# 2016-01-04 14:07:56.349877 ==> Brasil - 2015-09-17 - 3_month
# 2016-01-04 14:07:57.853657 ==> Brasil - 2015-09-17 - 4_month
# 2016-01-04 14:07:58.924786 ==> Brasil - 2015-09-17 - 5_month
# 2016-01-04 14:07:59.935226 ==> Brasil - 2015-09-17 - 6_month
# 2016-01-04 14:08:00.906179 ==> Brasil - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:08:02.146076 ==> Brasil - 2015-10-17 - same_month
# 2016-01-04 14:08:03.213774 ==> Brasil - 2015-10-17 - 1_month
# 2016-01-04 14:08:04.448221 ==> Brasil - 2015-10-17 - 2_month
# 2016-01-04 14:08:05.571759 ==> Brasil - 2015-10-17 - 3_month
# 2016-01-04 14:08:06.640999 ==> Brasil - 2015-10-17 - 4_month
# 2016-01-04 14:08:07.894174 ==> Brasil - 2015-10-17 - 5_month
# 2016-01-04 14:08:09.244332 ==> Brasil - 2015-10-17 - 6_month
# 2016-01-04 14:08:10.320651 ==> Brasil - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:08:11.341808 ==> Brasil - 2015-11-16 - same_month
# 2016-01-04 14:08:12.321448 ==> Brasil - 2015-11-16 - 1_month
# 2016-01-04 14:08:13.327921 ==> Brasil - 2015-11-16 - 2_month
# 2016-01-04 14:08:14.698556 ==> Brasil - 2015-11-16 - 3_month
# 2016-01-04 14:08:15.774909 ==> Brasil - 2015-11-16 - 4_month
# 2016-01-04 14:08:16.932336 ==> Brasil - 2015-11-16 - 5_month
# 2016-01-04 14:08:18.010989 ==> Brasil - 2015-11-16 - 6_month
# 2016-01-04 14:08:19.215624 ==> Brasil - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:08:20.930079 ==> Brasil - 2015-12-16 - same_month
# 2016-01-04 14:08:22.453806 ==> Brasil - 2015-12-16 - 1_month
# 2016-01-04 14:08:23.513487 ==> Brasil - 2015-12-16 - 2_month
# 2016-01-04 14:08:24.699937 ==> Brasil - 2015-12-16 - 3_month
# 2016-01-04 14:08:25.726474 ==> Brasil - 2015-12-16 - 4_month
# 2016-01-04 14:08:26.722925 ==> Brasil - 2015-12-16 - 5_month
# 2016-01-04 14:08:27.683146 ==> Brasil - 2015-12-16 - 6_month
# 2016-01-04 14:08:28.699347 ==> Brasil - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:08:29.686701 ==> Chile - 2015-04-20 - same_month
# 2016-01-04 14:08:30.708749 ==> Chile - 2015-04-20 - 1_month
# 2016-01-04 14:08:31.756515 ==> Chile - 2015-04-20 - 2_month
# 2016-01-04 14:08:32.775218 ==> Chile - 2015-04-20 - 3_month
# 2016-01-04 14:08:33.773251 ==> Chile - 2015-04-20 - 4_month
# 2016-01-04 14:08:34.756308 ==> Chile - 2015-04-20 - 5_month
# 2016-01-04 14:08:35.743681 ==> Chile - 2015-04-20 - 6_month
# 2016-01-04 14:08:36.776657 ==> Chile - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:08:37.800126 ==> Chile - 2015-05-20 - same_month
# 2016-01-04 14:08:38.795856 ==> Chile - 2015-05-20 - 1_month
# 2016-01-04 14:08:39.809019 ==> Chile - 2015-05-20 - 2_month
# 2016-01-04 14:08:40.810154 ==> Chile - 2015-05-20 - 3_month
# 2016-01-04 14:08:41.823851 ==> Chile - 2015-05-20 - 4_month
# 2016-01-04 14:08:42.816005 ==> Chile - 2015-05-20 - 5_month
# 2016-01-04 14:08:44.213573 ==> Chile - 2015-05-20 - 6_month
# 2016-01-04 14:08:45.273297 ==> Chile - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:08:46.476217 ==> Chile - 2015-06-19 - same_month
# 2016-01-04 14:08:47.422610 ==> Chile - 2015-06-19 - 1_month
# 2016-01-04 14:08:48.395305 ==> Chile - 2015-06-19 - 2_month
# 2016-01-04 14:08:49.693069 ==> Chile - 2015-06-19 - 3_month
# 2016-01-04 14:08:51.464958 ==> Chile - 2015-06-19 - 4_month
# 2016-01-04 14:08:52.452374 ==> Chile - 2015-06-19 - 5_month
# 2016-01-04 14:08:53.403949 ==> Chile - 2015-06-19 - 6_month
# 2016-01-04 14:08:54.408142 ==> Chile - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:08:55.546708 ==> Chile - 2015-07-19 - same_month
# 2016-01-04 14:08:56.746960 ==> Chile - 2015-07-19 - 1_month
# 2016-01-04 14:08:58.216496 ==> Chile - 2015-07-19 - 2_month
# 2016-01-04 14:08:59.618343 ==> Chile - 2015-07-19 - 3_month
# 2016-01-04 14:09:00.691133 ==> Chile - 2015-07-19 - 4_month
# 2016-01-04 14:09:01.682856 ==> Chile - 2015-07-19 - 5_month
# 2016-01-04 14:09:02.660408 ==> Chile - 2015-07-19 - 6_month
# 2016-01-04 14:09:03.609814 ==> Chile - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:09:04.562069 ==> Chile - 2015-08-18 - same_month
# 2016-01-04 14:09:05.525685 ==> Chile - 2015-08-18 - 1_month
# 2016-01-04 14:09:06.522302 ==> Chile - 2015-08-18 - 2_month
# 2016-01-04 14:09:07.676252 ==> Chile - 2015-08-18 - 3_month
# 2016-01-04 14:09:08.736641 ==> Chile - 2015-08-18 - 4_month
# 2016-01-04 14:09:09.913007 ==> Chile - 2015-08-18 - 5_month
# 2016-01-04 14:09:10.915766 ==> Chile - 2015-08-18 - 6_month
# 2016-01-04 14:09:11.923083 ==> Chile - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:09:12.920714 ==> Chile - 2015-09-17 - same_month
# 2016-01-04 14:09:13.944899 ==> Chile - 2015-09-17 - 1_month
# 2016-01-04 14:09:14.947398 ==> Chile - 2015-09-17 - 2_month
# 2016-01-04 14:09:16.177454 ==> Chile - 2015-09-17 - 3_month
# 2016-01-04 14:09:17.197536 ==> Chile - 2015-09-17 - 4_month
# 2016-01-04 14:09:18.277581 ==> Chile - 2015-09-17 - 5_month
# 2016-01-04 14:09:19.318427 ==> Chile - 2015-09-17 - 6_month
# 2016-01-04 14:09:20.320064 ==> Chile - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:09:21.276271 ==> Chile - 2015-10-17 - same_month
# 2016-01-04 14:09:22.242155 ==> Chile - 2015-10-17 - 1_month
# 2016-01-04 14:09:23.210318 ==> Chile - 2015-10-17 - 2_month
# 2016-01-04 14:09:24.235321 ==> Chile - 2015-10-17 - 3_month
# 2016-01-04 14:09:25.500163 ==> Chile - 2015-10-17 - 4_month
# 2016-01-04 14:09:26.546430 ==> Chile - 2015-10-17 - 5_month
# 2016-01-04 14:09:27.592263 ==> Chile - 2015-10-17 - 6_month
# 2016-01-04 14:09:28.640653 ==> Chile - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:09:29.651745 ==> Chile - 2015-11-16 - same_month
# 2016-01-04 14:09:30.642344 ==> Chile - 2015-11-16 - 1_month
# 2016-01-04 14:09:31.624209 ==> Chile - 2015-11-16 - 2_month
# 2016-01-04 14:09:32.639709 ==> Chile - 2015-11-16 - 3_month
# 2016-01-04 14:09:33.710221 ==> Chile - 2015-11-16 - 4_month
# 2016-01-04 14:09:35.151168 ==> Chile - 2015-11-16 - 5_month
# 2016-01-04 14:09:36.845814 ==> Chile - 2015-11-16 - 6_month
# 2016-01-04 14:09:38.330095 ==> Chile - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:09:39.377345 ==> Chile - 2015-12-16 - same_month
# 2016-01-04 14:09:40.377610 ==> Chile - 2015-12-16 - 1_month
# 2016-01-04 14:09:41.336365 ==> Chile - 2015-12-16 - 2_month
# 2016-01-04 14:09:42.280764 ==> Chile - 2015-12-16 - 3_month
# 2016-01-04 14:09:43.474706 ==> Chile - 2015-12-16 - 4_month
# 2016-01-04 14:09:44.707171 ==> Chile - 2015-12-16 - 5_month
# 2016-01-04 14:09:45.833983 ==> Chile - 2015-12-16 - 6_month
# 2016-01-04 14:09:46.852303 ==> Chile - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:09:47.870595 ==> Colombia - 2015-04-20 - same_month
# 2016-01-04 14:09:48.869092 ==> Colombia - 2015-04-20 - 1_month
# 2016-01-04 14:09:49.843933 ==> Colombia - 2015-04-20 - 2_month
# 2016-01-04 14:09:50.858256 ==> Colombia - 2015-04-20 - 3_month
# 2016-01-04 14:09:51.908292 ==> Colombia - 2015-04-20 - 4_month
# 2016-01-04 14:09:53.001731 ==> Colombia - 2015-04-20 - 5_month
# 2016-01-04 14:09:54.036753 ==> Colombia - 2015-04-20 - 6_month
# 2016-01-04 14:09:55.123301 ==> Colombia - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:09:56.156703 ==> Colombia - 2015-05-20 - same_month
# 2016-01-04 14:09:57.337528 ==> Colombia - 2015-05-20 - 1_month
# 2016-01-04 14:09:58.385863 ==> Colombia - 2015-05-20 - 2_month
# 2016-01-04 14:09:59.773298 ==> Colombia - 2015-05-20 - 3_month
# 2016-01-04 14:10:01.103646 ==> Colombia - 2015-05-20 - 4_month
# 2016-01-04 14:10:02.115545 ==> Colombia - 2015-05-20 - 5_month
# 2016-01-04 14:10:03.148338 ==> Colombia - 2015-05-20 - 6_month
# 2016-01-04 14:10:04.131989 ==> Colombia - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:10:05.072290 ==> Colombia - 2015-06-19 - same_month
# 2016-01-04 14:10:06.037385 ==> Colombia - 2015-06-19 - 1_month
# 2016-01-04 14:10:07.124234 ==> Colombia - 2015-06-19 - 2_month
# 2016-01-04 14:10:08.142122 ==> Colombia - 2015-06-19 - 3_month
# 2016-01-04 14:10:09.175984 ==> Colombia - 2015-06-19 - 4_month
# 2016-01-04 14:10:10.543601 ==> Colombia - 2015-06-19 - 5_month
# 2016-01-04 14:10:12.293973 ==> Colombia - 2015-06-19 - 6_month
# 2016-01-04 14:10:13.703702 ==> Colombia - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:10:14.747658 ==> Colombia - 2015-07-19 - same_month
# 2016-01-04 14:10:15.761182 ==> Colombia - 2015-07-19 - 1_month
# 2016-01-04 14:10:16.773206 ==> Colombia - 2015-07-19 - 2_month
# 2016-01-04 14:10:17.739250 ==> Colombia - 2015-07-19 - 3_month
# 2016-01-04 14:10:18.724641 ==> Colombia - 2015-07-19 - 4_month
# 2016-01-04 14:10:19.945849 ==> Colombia - 2015-07-19 - 5_month
# 2016-01-04 14:10:20.962001 ==> Colombia - 2015-07-19 - 6_month
# 2016-01-04 14:10:21.964551 ==> Colombia - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:10:22.999827 ==> Colombia - 2015-08-18 - same_month
# 2016-01-04 14:10:23.952867 ==> Colombia - 2015-08-18 - 1_month
# 2016-01-04 14:10:25.391356 ==> Colombia - 2015-08-18 - 2_month
# 2016-01-04 14:10:26.567908 ==> Colombia - 2015-08-18 - 3_month
# 2016-01-04 14:10:27.680498 ==> Colombia - 2015-08-18 - 4_month
# 2016-01-04 14:10:28.959364 ==> Colombia - 2015-08-18 - 5_month
# 2016-01-04 14:10:30.075396 ==> Colombia - 2015-08-18 - 6_month
# 2016-01-04 14:10:31.144511 ==> Colombia - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:10:32.362570 ==> Colombia - 2015-09-17 - same_month
# 2016-01-04 14:10:33.534163 ==> Colombia - 2015-09-17 - 1_month
# 2016-01-04 14:10:34.615176 ==> Colombia - 2015-09-17 - 2_month
# 2016-01-04 14:10:35.845312 ==> Colombia - 2015-09-17 - 3_month
# 2016-01-04 14:10:36.936539 ==> Colombia - 2015-09-17 - 4_month
# 2016-01-04 14:10:38.723343 ==> Colombia - 2015-09-17 - 5_month
# 2016-01-04 14:10:40.343737 ==> Colombia - 2015-09-17 - 6_month
# 2016-01-04 14:10:41.803369 ==> Colombia - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:10:43.460302 ==> Colombia - 2015-10-17 - same_month
# 2016-01-04 14:10:45.099342 ==> Colombia - 2015-10-17 - 1_month
# 2016-01-04 14:10:46.379232 ==> Colombia - 2015-10-17 - 2_month
# 2016-01-04 14:10:47.400654 ==> Colombia - 2015-10-17 - 3_month
# 2016-01-04 14:10:48.455389 ==> Colombia - 2015-10-17 - 4_month
# 2016-01-04 14:10:49.471218 ==> Colombia - 2015-10-17 - 5_month
# 2016-01-04 14:10:50.487522 ==> Colombia - 2015-10-17 - 6_month
# 2016-01-04 14:10:51.528413 ==> Colombia - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:10:52.531364 ==> Colombia - 2015-11-16 - same_month
# 2016-01-04 14:10:53.640402 ==> Colombia - 2015-11-16 - 1_month
# 2016-01-04 14:10:54.717018 ==> Colombia - 2015-11-16 - 2_month
# 2016-01-04 14:10:55.995586 ==> Colombia - 2015-11-16 - 3_month
# 2016-01-04 14:10:57.301450 ==> Colombia - 2015-11-16 - 4_month
# 2016-01-04 14:10:58.560699 ==> Colombia - 2015-11-16 - 5_month
# 2016-01-04 14:10:59.637417 ==> Colombia - 2015-11-16 - 6_month
# 2016-01-04 14:11:00.873597 ==> Colombia - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:11:01.874442 ==> Colombia - 2015-12-16 - same_month
# 2016-01-04 14:11:03.466466 ==> Colombia - 2015-12-16 - 1_month
# 2016-01-04 14:11:04.545085 ==> Colombia - 2015-12-16 - 2_month
# 2016-01-04 14:11:05.764230 ==> Colombia - 2015-12-16 - 3_month
# 2016-01-04 14:11:06.864867 ==> Colombia - 2015-12-16 - 4_month
# 2016-01-04 14:11:08.176991 ==> Colombia - 2015-12-16 - 5_month
# 2016-01-04 14:11:09.510354 ==> Colombia - 2015-12-16 - 6_month
# 2016-01-04 14:11:10.563524 ==> Colombia - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:11:11.711669 ==> India - 2015-04-20 - same_month
# 2016-01-04 14:11:12.708339 ==> India - 2015-04-20 - 1_month
# 2016-01-04 14:11:13.916855 ==> India - 2015-04-20 - 2_month
# 2016-01-04 14:11:15.055247 ==> India - 2015-04-20 - 3_month
# 2016-01-04 14:11:16.282918 ==> India - 2015-04-20 - 4_month
# 2016-01-04 14:11:17.271637 ==> India - 2015-04-20 - 5_month
# 2016-01-04 14:11:18.314087 ==> India - 2015-04-20 - 6_month
# 2016-01-04 14:11:19.372820 ==> India - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:11:20.506481 ==> India - 2015-05-20 - same_month
# 2016-01-04 14:11:21.466423 ==> India - 2015-05-20 - 1_month
# 2016-01-04 14:11:22.532201 ==> India - 2015-05-20 - 2_month
# 2016-01-04 14:11:23.718631 ==> India - 2015-05-20 - 3_month
# 2016-01-04 14:11:25.009398 ==> India - 2015-05-20 - 4_month
# 2016-01-04 14:11:26.298992 ==> India - 2015-05-20 - 5_month
# 2016-01-04 14:11:27.584256 ==> India - 2015-05-20 - 6_month
# 2016-01-04 14:11:28.613055 ==> India - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:11:29.635246 ==> India - 2015-06-19 - same_month
# 2016-01-04 14:11:30.641303 ==> India - 2015-06-19 - 1_month
# 2016-01-04 14:11:31.820910 ==> India - 2015-06-19 - 2_month
# 2016-01-04 14:11:32.902392 ==> India - 2015-06-19 - 3_month
# 2016-01-04 14:11:33.903306 ==> India - 2015-06-19 - 4_month
# 2016-01-04 14:11:34.865099 ==> India - 2015-06-19 - 5_month
# 2016-01-04 14:11:35.845897 ==> India - 2015-06-19 - 6_month
# 2016-01-04 14:11:36.845553 ==> India - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:11:37.879606 ==> India - 2015-07-19 - same_month
# 2016-01-04 14:11:38.925480 ==> India - 2015-07-19 - 1_month
# 2016-01-04 14:11:40.035220 ==> India - 2015-07-19 - 2_month
# 2016-01-04 14:11:41.040467 ==> India - 2015-07-19 - 3_month
# 2016-01-04 14:11:42.096489 ==> India - 2015-07-19 - 4_month
# 2016-01-04 14:11:43.089046 ==> India - 2015-07-19 - 5_month
# 2016-01-04 14:11:44.061687 ==> India - 2015-07-19 - 6_month
# 2016-01-04 14:11:45.037924 ==> India - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:11:46.059094 ==> India - 2015-08-18 - same_month
# 2016-01-04 14:11:47.071152 ==> India - 2015-08-18 - 1_month
# 2016-01-04 14:11:48.058134 ==> India - 2015-08-18 - 2_month
# 2016-01-04 14:11:49.281478 ==> India - 2015-08-18 - 3_month
# 2016-01-04 14:11:50.329952 ==> India - 2015-08-18 - 4_month
# 2016-01-04 14:11:51.384415 ==> India - 2015-08-18 - 5_month
# 2016-01-04 14:11:52.363189 ==> India - 2015-08-18 - 6_month
# 2016-01-04 14:11:53.363519 ==> India - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:11:54.361658 ==> India - 2015-09-17 - same_month
# 2016-01-04 14:11:55.622747 ==> India - 2015-09-17 - 1_month
# 2016-01-04 14:11:56.862792 ==> India - 2015-09-17 - 2_month
# 2016-01-04 14:11:57.944749 ==> India - 2015-09-17 - 3_month
# 2016-01-04 14:11:58.991300 ==> India - 2015-09-17 - 4_month
# 2016-01-04 14:12:00.007391 ==> India - 2015-09-17 - 5_month
# 2016-01-04 14:12:01.023028 ==> India - 2015-09-17 - 6_month
# 2016-01-04 14:12:02.007863 ==> India - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:12:03.058665 ==> India - 2015-10-17 - same_month
# 2016-01-04 14:12:04.069701 ==> India - 2015-10-17 - 1_month
# 2016-01-04 14:12:05.075367 ==> India - 2015-10-17 - 2_month
# 2016-01-04 14:12:06.315372 ==> India - 2015-10-17 - 3_month
# 2016-01-04 14:12:07.575067 ==> India - 2015-10-17 - 4_month
# 2016-01-04 14:12:08.712989 ==> India - 2015-10-17 - 5_month
# 2016-01-04 14:12:09.769709 ==> India - 2015-10-17 - 6_month
# 2016-01-04 14:12:10.761996 ==> India - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:12:11.723064 ==> India - 2015-11-16 - same_month
# 2016-01-04 14:12:12.679332 ==> India - 2015-11-16 - 1_month
# 2016-01-04 14:12:13.655497 ==> India - 2015-11-16 - 2_month
# 2016-01-04 14:12:14.623672 ==> India - 2015-11-16 - 3_month
# 2016-01-04 14:12:15.621205 ==> India - 2015-11-16 - 4_month
# 2016-01-04 14:12:16.883594 ==> India - 2015-11-16 - 5_month
# 2016-01-04 14:12:18.399461 ==> India - 2015-11-16 - 6_month
# 2016-01-04 14:12:19.435721 ==> India - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:12:20.473440 ==> India - 2015-12-16 - same_month
# 2016-01-04 14:12:21.460509 ==> India - 2015-12-16 - 1_month
# 2016-01-04 14:12:22.427672 ==> India - 2015-12-16 - 2_month
# 2016-01-04 14:12:23.416371 ==> India - 2015-12-16 - 3_month
# 2016-01-04 14:12:24.429255 ==> India - 2015-12-16 - 4_month
# 2016-01-04 14:12:25.428933 ==> India - 2015-12-16 - 5_month
# 2016-01-04 14:12:26.470058 ==> India - 2015-12-16 - 6_month
# 2016-01-04 14:12:27.717200 ==> India - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:12:28.836668 ==> Malaysia + Singapore - 2015-04-20 - same_month
# 2016-01-04 14:12:29.888540 ==> Malaysia + Singapore - 2015-04-20 - 1_month
# 2016-01-04 14:12:30.998137 ==> Malaysia + Singapore - 2015-04-20 - 2_month
# 2016-01-04 14:12:31.992696 ==> Malaysia + Singapore - 2015-04-20 - 3_month
# 2016-01-04 14:12:33.013596 ==> Malaysia + Singapore - 2015-04-20 - 4_month
# 2016-01-04 14:12:34.038490 ==> Malaysia + Singapore - 2015-04-20 - 5_month
# 2016-01-04 14:12:35.064977 ==> Malaysia + Singapore - 2015-04-20 - 6_month
# 2016-01-04 14:12:36.140029 ==> Malaysia + Singapore - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:12:37.211230 ==> Malaysia + Singapore - 2015-05-20 - same_month
# 2016-01-04 14:12:38.529622 ==> Malaysia + Singapore - 2015-05-20 - 1_month
# 2016-01-04 14:12:39.618858 ==> Malaysia + Singapore - 2015-05-20 - 2_month
# 2016-01-04 14:12:40.647261 ==> Malaysia + Singapore - 2015-05-20 - 3_month
# 2016-01-04 14:12:41.610880 ==> Malaysia + Singapore - 2015-05-20 - 4_month
# 2016-01-04 14:12:42.615093 ==> Malaysia + Singapore - 2015-05-20 - 5_month
# 2016-01-04 14:12:43.668492 ==> Malaysia + Singapore - 2015-05-20 - 6_month
# 2016-01-04 14:12:44.705586 ==> Malaysia + Singapore - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:12:45.738968 ==> Malaysia + Singapore - 2015-06-19 - same_month
# 2016-01-04 14:12:46.703670 ==> Malaysia + Singapore - 2015-06-19 - 1_month
# 2016-01-04 14:12:47.691640 ==> Malaysia + Singapore - 2015-06-19 - 2_month
# 2016-01-04 14:12:48.729016 ==> Malaysia + Singapore - 2015-06-19 - 3_month
# 2016-01-04 14:12:49.735697 ==> Malaysia + Singapore - 2015-06-19 - 4_month
# 2016-01-04 14:12:50.727681 ==> Malaysia + Singapore - 2015-06-19 - 5_month
# 2016-01-04 14:12:51.737403 ==> Malaysia + Singapore - 2015-06-19 - 6_month
# 2016-01-04 14:12:52.834898 ==> Malaysia + Singapore - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:12:54.184036 ==> Malaysia + Singapore - 2015-07-19 - same_month
# 2016-01-04 14:12:55.473048 ==> Malaysia + Singapore - 2015-07-19 - 1_month
# 2016-01-04 14:12:56.610850 ==> Malaysia + Singapore - 2015-07-19 - 2_month
# 2016-01-04 14:12:57.805109 ==> Malaysia + Singapore - 2015-07-19 - 3_month
# 2016-01-04 14:12:58.916111 ==> Malaysia + Singapore - 2015-07-19 - 4_month
# 2016-01-04 14:12:59.971018 ==> Malaysia + Singapore - 2015-07-19 - 5_month
# 2016-01-04 14:13:00.956432 ==> Malaysia + Singapore - 2015-07-19 - 6_month
# 2016-01-04 14:13:02.023563 ==> Malaysia + Singapore - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:13:03.152402 ==> Malaysia + Singapore - 2015-08-18 - same_month
# 2016-01-04 14:13:04.408938 ==> Malaysia + Singapore - 2015-08-18 - 1_month
# 2016-01-04 14:13:05.400938 ==> Malaysia + Singapore - 2015-08-18 - 2_month
# 2016-01-04 14:13:06.504085 ==> Malaysia + Singapore - 2015-08-18 - 3_month
# 2016-01-04 14:13:07.658152 ==> Malaysia + Singapore - 2015-08-18 - 4_month
# 2016-01-04 14:13:09.331702 ==> Malaysia + Singapore - 2015-08-18 - 5_month
# 2016-01-04 14:13:10.857344 ==> Malaysia + Singapore - 2015-08-18 - 6_month
# 2016-01-04 14:13:12.001480 ==> Malaysia + Singapore - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:13:13.344975 ==> Malaysia + Singapore - 2015-09-17 - same_month
# 2016-01-04 14:13:14.451657 ==> Malaysia + Singapore - 2015-09-17 - 1_month
# 2016-01-04 14:13:15.552049 ==> Malaysia + Singapore - 2015-09-17 - 2_month
# 2016-01-04 14:13:16.772547 ==> Malaysia + Singapore - 2015-09-17 - 3_month
# 2016-01-04 14:13:17.916210 ==> Malaysia + Singapore - 2015-09-17 - 4_month
# 2016-01-04 14:13:19.323549 ==> Malaysia + Singapore - 2015-09-17 - 5_month
# 2016-01-04 14:13:20.514422 ==> Malaysia + Singapore - 2015-09-17 - 6_month
# 2016-01-04 14:13:21.762005 ==> Malaysia + Singapore - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:13:22.846219 ==> Malaysia + Singapore - 2015-10-17 - same_month
# 2016-01-04 14:13:24.174353 ==> Malaysia + Singapore - 2015-10-17 - 1_month
# 2016-01-04 14:13:25.226546 ==> Malaysia + Singapore - 2015-10-17 - 2_month
# 2016-01-04 14:13:26.279155 ==> Malaysia + Singapore - 2015-10-17 - 3_month
# 2016-01-04 14:13:27.228387 ==> Malaysia + Singapore - 2015-10-17 - 4_month
# 2016-01-04 14:13:28.191598 ==> Malaysia + Singapore - 2015-10-17 - 5_month
# 2016-01-04 14:13:29.232865 ==> Malaysia + Singapore - 2015-10-17 - 6_month
# 2016-01-04 14:13:30.234072 ==> Malaysia + Singapore - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:13:31.245598 ==> Malaysia + Singapore - 2015-11-16 - same_month
# 2016-01-04 14:13:32.392316 ==> Malaysia + Singapore - 2015-11-16 - 1_month
# 2016-01-04 14:13:33.425103 ==> Malaysia + Singapore - 2015-11-16 - 2_month
# 2016-01-04 14:13:34.432754 ==> Malaysia + Singapore - 2015-11-16 - 3_month
# 2016-01-04 14:13:35.381830 ==> Malaysia + Singapore - 2015-11-16 - 4_month
# 2016-01-04 14:13:36.333548 ==> Malaysia + Singapore - 2015-11-16 - 5_month
# 2016-01-04 14:13:37.336530 ==> Malaysia + Singapore - 2015-11-16 - 6_month
# 2016-01-04 14:13:38.366478 ==> Malaysia + Singapore - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:13:40.061559 ==> Malaysia + Singapore - 2015-12-16 - same_month
# 2016-01-04 14:13:41.141053 ==> Malaysia + Singapore - 2015-12-16 - 1_month
# 2016-01-04 14:13:42.110296 ==> Malaysia + Singapore - 2015-12-16 - 2_month
# 2016-01-04 14:13:43.065837 ==> Malaysia + Singapore - 2015-12-16 - 3_month
# 2016-01-04 14:13:44.021483 ==> Malaysia + Singapore - 2015-12-16 - 4_month
# 2016-01-04 14:13:44.979415 ==> Malaysia + Singapore - 2015-12-16 - 5_month
# 2016-01-04 14:13:45.936340 ==> Malaysia + Singapore - 2015-12-16 - 6_month
# 2016-01-04 14:13:47.044951 ==> Malaysia + Singapore - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:13:48.060167 ==> Mexico - 2015-04-20 - same_month
# 2016-01-04 14:13:49.016649 ==> Mexico - 2015-04-20 - 1_month
# 2016-01-04 14:13:49.970665 ==> Mexico - 2015-04-20 - 2_month
# 2016-01-04 14:13:50.959708 ==> Mexico - 2015-04-20 - 3_month
# 2016-01-04 14:13:51.956290 ==> Mexico - 2015-04-20 - 4_month
# 2016-01-04 14:13:52.921562 ==> Mexico - 2015-04-20 - 5_month
# 2016-01-04 14:13:53.861471 ==> Mexico - 2015-04-20 - 6_month
# 2016-01-04 14:13:54.788920 ==> Mexico - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:13:55.793508 ==> Mexico - 2015-05-20 - same_month
# 2016-01-04 14:13:56.861615 ==> Mexico - 2015-05-20 - 1_month
# 2016-01-04 14:13:57.913372 ==> Mexico - 2015-05-20 - 2_month
# 2016-01-04 14:13:58.914792 ==> Mexico - 2015-05-20 - 3_month
# 2016-01-04 14:13:59.894708 ==> Mexico - 2015-05-20 - 4_month
# 2016-01-04 14:14:00.866398 ==> Mexico - 2015-05-20 - 5_month
# 2016-01-04 14:14:01.823952 ==> Mexico - 2015-05-20 - 6_month
# 2016-01-04 14:14:02.777052 ==> Mexico - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:14:03.737448 ==> Mexico - 2015-06-19 - same_month
# 2016-01-04 14:14:04.751675 ==> Mexico - 2015-06-19 - 1_month
# 2016-01-04 14:14:05.725978 ==> Mexico - 2015-06-19 - 2_month
# 2016-01-04 14:14:06.710401 ==> Mexico - 2015-06-19 - 3_month
# 2016-01-04 14:14:07.655218 ==> Mexico - 2015-06-19 - 4_month
# 2016-01-04 14:14:08.606138 ==> Mexico - 2015-06-19 - 5_month
# 2016-01-04 14:14:09.552465 ==> Mexico - 2015-06-19 - 6_month
# 2016-01-04 14:14:10.527626 ==> Mexico - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:14:11.460699 ==> Mexico - 2015-07-19 - same_month
# 2016-01-04 14:14:12.402250 ==> Mexico - 2015-07-19 - 1_month
# 2016-01-04 14:14:13.394475 ==> Mexico - 2015-07-19 - 2_month
# 2016-01-04 14:14:14.435832 ==> Mexico - 2015-07-19 - 3_month
# 2016-01-04 14:14:15.420177 ==> Mexico - 2015-07-19 - 4_month
# 2016-01-04 14:14:16.385156 ==> Mexico - 2015-07-19 - 5_month
# 2016-01-04 14:14:17.342242 ==> Mexico - 2015-07-19 - 6_month
# 2016-01-04 14:14:18.358688 ==> Mexico - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:14:19.421572 ==> Mexico - 2015-08-18 - same_month
# 2016-01-04 14:14:20.746913 ==> Mexico - 2015-08-18 - 1_month
# 2016-01-04 14:14:21.795170 ==> Mexico - 2015-08-18 - 2_month
# 2016-01-04 14:14:23.220001 ==> Mexico - 2015-08-18 - 3_month
# 2016-01-04 14:14:24.356923 ==> Mexico - 2015-08-18 - 4_month
# 2016-01-04 14:14:25.671172 ==> Mexico - 2015-08-18 - 5_month
# 2016-01-04 14:14:26.781495 ==> Mexico - 2015-08-18 - 6_month
# 2016-01-04 14:14:27.850329 ==> Mexico - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:14:28.866059 ==> Mexico - 2015-09-17 - same_month
# 2016-01-04 14:14:30.029722 ==> Mexico - 2015-09-17 - 1_month
# 2016-01-04 14:14:31.294016 ==> Mexico - 2015-09-17 - 2_month
# 2016-01-04 14:14:32.612815 ==> Mexico - 2015-09-17 - 3_month
# 2016-01-04 14:14:33.683314 ==> Mexico - 2015-09-17 - 4_month
# 2016-01-04 14:14:34.689397 ==> Mexico - 2015-09-17 - 5_month
# 2016-01-04 14:14:35.650586 ==> Mexico - 2015-09-17 - 6_month
# 2016-01-04 14:14:36.626391 ==> Mexico - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:14:37.607385 ==> Mexico - 2015-10-17 - same_month
# 2016-01-04 14:14:38.560662 ==> Mexico - 2015-10-17 - 1_month
# 2016-01-04 14:14:39.529553 ==> Mexico - 2015-10-17 - 2_month
# 2016-01-04 14:14:40.544165 ==> Mexico - 2015-10-17 - 3_month
# 2016-01-04 14:14:42.281279 ==> Mexico - 2015-10-17 - 4_month
# 2016-01-04 14:14:44.039338 ==> Mexico - 2015-10-17 - 5_month
# 2016-01-04 14:14:45.149288 ==> Mexico - 2015-10-17 - 6_month
# 2016-01-04 14:14:46.276919 ==> Mexico - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:14:47.308387 ==> Mexico - 2015-11-16 - same_month
# 2016-01-04 14:14:48.272788 ==> Mexico - 2015-11-16 - 1_month
# 2016-01-04 14:14:49.229829 ==> Mexico - 2015-11-16 - 2_month
# 2016-01-04 14:14:50.236440 ==> Mexico - 2015-11-16 - 3_month
# 2016-01-04 14:14:51.235130 ==> Mexico - 2015-11-16 - 4_month
# 2016-01-04 14:14:52.235361 ==> Mexico - 2015-11-16 - 5_month
# 2016-01-04 14:14:53.200889 ==> Mexico - 2015-11-16 - 6_month
# 2016-01-04 14:14:54.180464 ==> Mexico - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:14:55.159049 ==> Mexico - 2015-12-16 - same_month
# 2016-01-04 14:14:56.147313 ==> Mexico - 2015-12-16 - 1_month
# 2016-01-04 14:14:57.469312 ==> Mexico - 2015-12-16 - 2_month
# 2016-01-04 14:14:58.658638 ==> Mexico - 2015-12-16 - 3_month
# 2016-01-04 14:14:59.924923 ==> Mexico - 2015-12-16 - 4_month
# 2016-01-04 14:15:00.919262 ==> Mexico - 2015-12-16 - 5_month
# 2016-01-04 14:15:01.881315 ==> Mexico - 2015-12-16 - 6_month
# 2016-01-04 14:15:02.827087 ==> Mexico - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:15:03.768932 ==> Pakistan - 2015-04-20 - same_month
# 2016-01-04 14:15:04.720311 ==> Pakistan - 2015-04-20 - 1_month
# 2016-01-04 14:15:05.673147 ==> Pakistan - 2015-04-20 - 2_month
# 2016-01-04 14:15:06.656636 ==> Pakistan - 2015-04-20 - 3_month
# 2016-01-04 14:15:07.680782 ==> Pakistan - 2015-04-20 - 4_month
# 2016-01-04 14:15:08.747627 ==> Pakistan - 2015-04-20 - 5_month
# 2016-01-04 14:15:10.123349 ==> Pakistan - 2015-04-20 - 6_month
# 2016-01-04 14:15:11.868687 ==> Pakistan - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:15:12.950633 ==> Pakistan - 2015-05-20 - same_month
# 2016-01-04 14:15:13.904467 ==> Pakistan - 2015-05-20 - 1_month
# 2016-01-04 14:15:14.922951 ==> Pakistan - 2015-05-20 - 2_month
# 2016-01-04 14:15:16.120162 ==> Pakistan - 2015-05-20 - 3_month
# 2016-01-04 14:15:17.306858 ==> Pakistan - 2015-05-20 - 4_month
# 2016-01-04 14:15:18.357191 ==> Pakistan - 2015-05-20 - 5_month
# 2016-01-04 14:15:19.405063 ==> Pakistan - 2015-05-20 - 6_month
# 2016-01-04 14:15:20.424132 ==> Pakistan - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:15:21.441227 ==> Pakistan - 2015-06-19 - same_month
# 2016-01-04 14:15:22.419886 ==> Pakistan - 2015-06-19 - 1_month
# 2016-01-04 14:15:23.387275 ==> Pakistan - 2015-06-19 - 2_month
# 2016-01-04 14:15:24.359890 ==> Pakistan - 2015-06-19 - 3_month
# 2016-01-04 14:15:25.393705 ==> Pakistan - 2015-06-19 - 4_month
# 2016-01-04 14:15:26.415593 ==> Pakistan - 2015-06-19 - 5_month
# 2016-01-04 14:15:27.560158 ==> Pakistan - 2015-06-19 - 6_month
# 2016-01-04 14:15:28.646201 ==> Pakistan - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:15:29.664701 ==> Pakistan - 2015-07-19 - same_month
# 2016-01-04 14:15:30.641612 ==> Pakistan - 2015-07-19 - 1_month
# 2016-01-04 14:15:31.652809 ==> Pakistan - 2015-07-19 - 2_month
# 2016-01-04 14:15:32.660855 ==> Pakistan - 2015-07-19 - 3_month
# 2016-01-04 14:15:33.682625 ==> Pakistan - 2015-07-19 - 4_month
# 2016-01-04 14:15:34.710116 ==> Pakistan - 2015-07-19 - 5_month
# 2016-01-04 14:15:35.704834 ==> Pakistan - 2015-07-19 - 6_month
# 2016-01-04 14:15:36.768891 ==> Pakistan - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:15:37.797062 ==> Pakistan - 2015-08-18 - same_month
# 2016-01-04 14:15:38.939121 ==> Pakistan - 2015-08-18 - 1_month
# 2016-01-04 14:15:39.940680 ==> Pakistan - 2015-08-18 - 2_month
# 2016-01-04 14:15:40.929741 ==> Pakistan - 2015-08-18 - 3_month
# 2016-01-04 14:15:41.891902 ==> Pakistan - 2015-08-18 - 4_month
# 2016-01-04 14:15:42.864390 ==> Pakistan - 2015-08-18 - 5_month
# 2016-01-04 14:15:43.886738 ==> Pakistan - 2015-08-18 - 6_month
# 2016-01-04 14:15:44.917325 ==> Pakistan - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:15:45.898791 ==> Pakistan - 2015-09-17 - same_month
# 2016-01-04 14:15:46.851125 ==> Pakistan - 2015-09-17 - 1_month
# 2016-01-04 14:15:47.808502 ==> Pakistan - 2015-09-17 - 2_month
# 2016-01-04 14:15:48.769167 ==> Pakistan - 2015-09-17 - 3_month
# 2016-01-04 14:15:49.726122 ==> Pakistan - 2015-09-17 - 4_month
# 2016-01-04 14:15:50.773443 ==> Pakistan - 2015-09-17 - 5_month
# 2016-01-04 14:15:51.820367 ==> Pakistan - 2015-09-17 - 6_month
# 2016-01-04 14:15:53.046693 ==> Pakistan - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:15:54.092370 ==> Pakistan - 2015-10-17 - same_month
# 2016-01-04 14:15:55.134137 ==> Pakistan - 2015-10-17 - 1_month
# 2016-01-04 14:15:56.145544 ==> Pakistan - 2015-10-17 - 2_month
# 2016-01-04 14:15:57.260047 ==> Pakistan - 2015-10-17 - 3_month
# 2016-01-04 14:15:58.321958 ==> Pakistan - 2015-10-17 - 4_month
# 2016-01-04 14:15:59.350753 ==> Pakistan - 2015-10-17 - 5_month
# 2016-01-04 14:16:00.346707 ==> Pakistan - 2015-10-17 - 6_month
# 2016-01-04 14:16:01.399040 ==> Pakistan - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:16:02.419813 ==> Pakistan - 2015-11-16 - same_month
# 2016-01-04 14:16:03.440868 ==> Pakistan - 2015-11-16 - 1_month
# 2016-01-04 14:16:04.419614 ==> Pakistan - 2015-11-16 - 2_month
# 2016-01-04 14:16:05.397651 ==> Pakistan - 2015-11-16 - 3_month
# 2016-01-04 14:16:06.410555 ==> Pakistan - 2015-11-16 - 4_month
# 2016-01-04 14:16:07.444907 ==> Pakistan - 2015-11-16 - 5_month
# 2016-01-04 14:16:08.692966 ==> Pakistan - 2015-11-16 - 6_month
# 2016-01-04 14:16:09.737102 ==> Pakistan - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:16:10.817510 ==> Pakistan - 2015-12-16 - same_month
# 2016-01-04 14:16:11.818346 ==> Pakistan - 2015-12-16 - 1_month
# 2016-01-04 14:16:12.944154 ==> Pakistan - 2015-12-16 - 2_month
# 2016-01-04 14:16:14.060681 ==> Pakistan - 2015-12-16 - 3_month
# 2016-01-04 14:16:15.077694 ==> Pakistan - 2015-12-16 - 4_month
# 2016-01-04 14:16:16.054395 ==> Pakistan - 2015-12-16 - 5_month
# 2016-01-04 14:16:17.005938 ==> Pakistan - 2015-12-16 - 6_month
# 2016-01-04 14:16:17.962658 ==> Pakistan - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:16:18.940602 ==>  TOTAL - 2015-04-20 - same_month
# 2016-01-04 14:16:21.314964 ==>  TOTAL - 2015-04-20 - 1_month
# 2016-01-04 14:16:23.588572 ==>  TOTAL - 2015-04-20 - 2_month
# 2016-01-04 14:16:25.840351 ==>  TOTAL - 2015-04-20 - 3_month
# 2016-01-04 14:16:28.084002 ==>  TOTAL - 2015-04-20 - 4_month
# 2016-01-04 14:16:30.518634 ==>  TOTAL - 2015-04-20 - 5_month
# 2016-01-04 14:16:32.963727 ==>  TOTAL - 2015-04-20 - 6_month
# 2016-01-04 14:16:35.638524 ==>  TOTAL - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:16:38.462380 ==>  TOTAL - 2015-05-20 - same_month
# 2016-01-04 14:16:41.521892 ==>  TOTAL - 2015-05-20 - 1_month
# 2016-01-04 14:16:43.971300 ==>  TOTAL - 2015-05-20 - 2_month
# 2016-01-04 14:16:47.142602 ==>  TOTAL - 2015-05-20 - 3_month
# 2016-01-04 14:16:50.124909 ==>  TOTAL - 2015-05-20 - 4_month
# 2016-01-04 14:16:53.884557 ==>  TOTAL - 2015-05-20 - 5_month
# 2016-01-04 14:16:57.693859 ==>  TOTAL - 2015-05-20 - 6_month
# 2016-01-04 14:17:01.414789 ==>  TOTAL - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:17:04.889929 ==>  TOTAL - 2015-06-19 - same_month
# 2016-01-04 14:17:08.452590 ==>  TOTAL - 2015-06-19 - 1_month
# 2016-01-04 14:17:11.236943 ==>  TOTAL - 2015-06-19 - 2_month
# 2016-01-04 14:17:13.764428 ==>  TOTAL - 2015-06-19 - 3_month
# 2016-01-04 14:17:16.099503 ==>  TOTAL - 2015-06-19 - 4_month
# 2016-01-04 14:17:18.573962 ==>  TOTAL - 2015-06-19 - 5_month
# 2016-01-04 14:17:20.946611 ==>  TOTAL - 2015-06-19 - 6_month
# 2016-01-04 14:17:23.228687 ==>  TOTAL - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:17:25.542016 ==>  TOTAL - 2015-07-19 - same_month
# 2016-01-04 14:17:28.410016 ==>  TOTAL - 2015-07-19 - 1_month
# 2016-01-04 14:17:31.100209 ==>  TOTAL - 2015-07-19 - 2_month
# 2016-01-04 14:17:33.751275 ==>  TOTAL - 2015-07-19 - 3_month
# 2016-01-04 14:17:36.058578 ==>  TOTAL - 2015-07-19 - 4_month
# 2016-01-04 14:17:39.462027 ==>  TOTAL - 2015-07-19 - 5_month
# 2016-01-04 14:17:42.117647 ==>  TOTAL - 2015-07-19 - 6_month
# 2016-01-04 14:17:44.489878 ==>  TOTAL - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:17:46.757984 ==>  TOTAL - 2015-08-18 - same_month
# 2016-01-04 14:17:50.086873 ==>  TOTAL - 2015-08-18 - 1_month
# 2016-01-04 14:17:52.981948 ==>  TOTAL - 2015-08-18 - 2_month
# 2016-01-04 14:17:55.727522 ==>  TOTAL - 2015-08-18 - 3_month
# 2016-01-04 14:17:58.480109 ==>  TOTAL - 2015-08-18 - 4_month
# 2016-01-04 14:18:01.726533 ==>  TOTAL - 2015-08-18 - 5_month
# 2016-01-04 14:18:04.209323 ==>  TOTAL - 2015-08-18 - 6_month
# 2016-01-04 14:18:06.479790 ==>  TOTAL - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:18:08.887970 ==>  TOTAL - 2015-09-17 - same_month
# 2016-01-04 14:18:11.170245 ==>  TOTAL - 2015-09-17 - 1_month
# 2016-01-04 14:18:13.412335 ==>  TOTAL - 2015-09-17 - 2_month
# 2016-01-04 14:18:15.762141 ==>  TOTAL - 2015-09-17 - 3_month
# 2016-01-04 14:18:18.562327 ==>  TOTAL - 2015-09-17 - 4_month
# 2016-01-04 14:18:22.242242 ==>  TOTAL - 2015-09-17 - 5_month
# 2016-01-04 14:18:24.631196 ==>  TOTAL - 2015-09-17 - 6_month
# 2016-01-04 14:18:27.049858 ==>  TOTAL - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:18:29.446090 ==>  TOTAL - 2015-10-17 - same_month
# 2016-01-04 14:18:32.304205 ==>  TOTAL - 2015-10-17 - 1_month
# 2016-01-04 14:18:34.607102 ==>  TOTAL - 2015-10-17 - 2_month
# 2016-01-04 14:18:37.323009 ==>  TOTAL - 2015-10-17 - 3_month
# 2016-01-04 14:18:39.852696 ==>  TOTAL - 2015-10-17 - 4_month
# 2016-01-04 14:18:42.247701 ==>  TOTAL - 2015-10-17 - 5_month
# 2016-01-04 14:18:44.895697 ==>  TOTAL - 2015-10-17 - 6_month
# 2016-01-04 14:18:47.259675 ==>  TOTAL - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:18:49.843244 ==>  TOTAL - 2015-11-16 - same_month
# 2016-01-04 14:18:52.391467 ==>  TOTAL - 2015-11-16 - 1_month
# 2016-01-04 14:18:54.787003 ==>  TOTAL - 2015-11-16 - 2_month
# 2016-01-04 14:18:58.037571 ==>  TOTAL - 2015-11-16 - 3_month
# 2016-01-04 14:19:01.104102 ==>  TOTAL - 2015-11-16 - 4_month
# 2016-01-04 14:19:03.384196 ==>  TOTAL - 2015-11-16 - 5_month
# 2016-01-04 14:19:06.657550 ==>  TOTAL - 2015-11-16 - 6_month
# 2016-01-04 14:19:10.330309 ==>  TOTAL - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:19:13.308520 ==>  TOTAL - 2015-12-16 - same_month
# 2016-01-04 14:19:16.616744 ==>  TOTAL - 2015-12-16 - 1_month
# 2016-01-04 14:19:19.353814 ==>  TOTAL - 2015-12-16 - 2_month
# 2016-01-04 14:19:22.598694 ==>  TOTAL - 2015-12-16 - 3_month
# 2016-01-04 14:19:25.449188 ==>  TOTAL - 2015-12-16 - 4_month
# 2016-01-04 14:19:27.679141 ==>  TOTAL - 2015-12-16 - 5_month
# 2016-01-04 14:19:30.413886 ==>  TOTAL - 2015-12-16 - 6_month
# 2016-01-04 14:19:33.057156 ==>  TOTAL - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:19:36.070521 ==> Argentina + Uruguay - 2015-04-20 - same_month
# 2016-01-04 14:19:39.054810 ==> Argentina + Uruguay - 2015-04-20 - 1_month
# 2016-01-04 14:19:41.521717 ==> Argentina + Uruguay - 2015-04-20 - 2_month
# 2016-01-04 14:19:44.086152 ==> Argentina + Uruguay - 2015-04-20 - 3_month
# 2016-01-04 14:19:47.039188 ==> Argentina + Uruguay - 2015-04-20 - 4_month
# 2016-01-04 14:19:49.884623 ==> Argentina + Uruguay - 2015-04-20 - 5_month
# 2016-01-04 14:19:52.313949 ==> Argentina + Uruguay - 2015-04-20 - 6_month
# 2016-01-04 14:19:54.572777 ==> Argentina + Uruguay - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:19:57.128237 ==> Argentina + Uruguay - 2015-05-20 - same_month
# 2016-01-04 14:19:59.639946 ==> Argentina + Uruguay - 2015-05-20 - 1_month
# 2016-01-04 14:20:01.909295 ==> Argentina + Uruguay - 2015-05-20 - 2_month
# 2016-01-04 14:20:04.369562 ==> Argentina + Uruguay - 2015-05-20 - 3_month
# 2016-01-04 14:20:07.272386 ==> Argentina + Uruguay - 2015-05-20 - 4_month
# 2016-01-04 14:20:10.129324 ==> Argentina + Uruguay - 2015-05-20 - 5_month
# 2016-01-04 14:20:13.085292 ==> Argentina + Uruguay - 2015-05-20 - 6_month
# ...
# 2016-01-04 14:35:03.304160 ==> India - 2015-10-17 - 1_month
# 2016-01-04 14:35:05.683853 ==> India - 2015-10-17 - 2_month
# 2016-01-04 14:35:08.463700 ==> India - 2015-10-17 - 3_month
# 2016-01-04 14:35:10.964791 ==> India - 2015-10-17 - 4_month
# 2016-01-04 14:35:13.444031 ==> India - 2015-10-17 - 5_month
# 2016-01-04 14:35:16.153659 ==> India - 2015-10-17 - 6_month
# 2016-01-04 14:35:18.665794 ==> India - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:35:21.126557 ==> India - 2015-11-16 - same_month
# 2016-01-04 14:35:23.671521 ==> India - 2015-11-16 - 1_month
# 2016-01-04 14:35:26.429685 ==> India - 2015-11-16 - 2_month
# 2016-01-04 14:35:28.789181 ==> India - 2015-11-16 - 3_month
# 2016-01-04 14:35:32.694023 ==> India - 2015-11-16 - 4_month
# 2016-01-04 14:35:35.641879 ==> India - 2015-11-16 - 5_month
# 2016-01-04 14:35:38.158295 ==> India - 2015-11-16 - 6_month
# 2016-01-04 14:35:40.717806 ==> India - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:35:43.306949 ==> India - 2015-12-16 - same_month
# 2016-01-04 14:35:45.876012 ==> India - 2015-12-16 - 1_month
# 2016-01-04 14:35:48.254078 ==> India - 2015-12-16 - 2_month
# 2016-01-04 14:35:50.871844 ==> India - 2015-12-16 - 3_month
# 2016-01-04 14:35:53.795796 ==> India - 2015-12-16 - 4_month
# 2016-01-04 14:35:56.478004 ==> India - 2015-12-16 - 5_month
# 2016-01-04 14:35:59.554216 ==> India - 2015-12-16 - 6_month
# 2016-01-04 14:36:02.524691 ==> India - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:36:05.390500 ==> Malaysia + Singapore - 2015-04-20 - same_month
# 2016-01-04 14:36:07.873667 ==> Malaysia + Singapore - 2015-04-20 - 1_month
# 2016-01-04 14:36:10.787142 ==> Malaysia + Singapore - 2015-04-20 - 2_month
# 2016-01-04 14:36:13.621097 ==> Malaysia + Singapore - 2015-04-20 - 3_month
# 2016-01-04 14:36:16.846666 ==> Malaysia + Singapore - 2015-04-20 - 4_month
# 2016-01-04 14:36:19.401763 ==> Malaysia + Singapore - 2015-04-20 - 5_month
# 2016-01-04 14:36:21.806617 ==> Malaysia + Singapore - 2015-04-20 - 6_month
# 2016-01-04 14:36:25.696889 ==> Malaysia + Singapore - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:36:28.174778 ==> Malaysia + Singapore - 2015-05-20 - same_month
# 2016-01-04 14:36:30.612421 ==> Malaysia + Singapore - 2015-05-20 - 1_month
# 2016-01-04 14:36:33.079647 ==> Malaysia + Singapore - 2015-05-20 - 2_month
# 2016-01-04 14:36:35.426758 ==> Malaysia + Singapore - 2015-05-20 - 3_month
# 2016-01-04 14:36:38.144618 ==> Malaysia + Singapore - 2015-05-20 - 4_month
# 2016-01-04 14:36:40.903501 ==> Malaysia + Singapore - 2015-05-20 - 5_month
# 2016-01-04 14:36:43.329922 ==> Malaysia + Singapore - 2015-05-20 - 6_month
# 2016-01-04 14:36:45.773345 ==> Malaysia + Singapore - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:36:48.232775 ==> Malaysia + Singapore - 2015-06-19 - same_month
# 2016-01-04 14:36:50.628070 ==> Malaysia + Singapore - 2015-06-19 - 1_month
# 2016-01-04 14:36:52.954545 ==> Malaysia + Singapore - 2015-06-19 - 2_month
# 2016-01-04 14:36:55.499882 ==> Malaysia + Singapore - 2015-06-19 - 3_month
# 2016-01-04 14:36:58.750951 ==> Malaysia + Singapore - 2015-06-19 - 4_month
# 2016-01-04 14:37:01.350981 ==> Malaysia + Singapore - 2015-06-19 - 5_month
# 2016-01-04 14:37:03.775749 ==> Malaysia + Singapore - 2015-06-19 - 6_month
# 2016-01-04 14:37:06.245285 ==> Malaysia + Singapore - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:37:09.065445 ==> Malaysia + Singapore - 2015-07-19 - same_month
# 2016-01-04 14:37:11.741919 ==> Malaysia + Singapore - 2015-07-19 - 1_month
# 2016-01-04 14:37:14.319411 ==> Malaysia + Singapore - 2015-07-19 - 2_month
# 2016-01-04 14:37:16.644087 ==> Malaysia + Singapore - 2015-07-19 - 3_month
# 2016-01-04 14:37:18.970576 ==> Malaysia + Singapore - 2015-07-19 - 4_month
# 2016-01-04 14:37:21.395106 ==> Malaysia + Singapore - 2015-07-19 - 5_month
# 2016-01-04 14:37:24.695292 ==> Malaysia + Singapore - 2015-07-19 - 6_month
# 2016-01-04 14:37:27.552257 ==> Malaysia + Singapore - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:37:29.961849 ==> Malaysia + Singapore - 2015-08-18 - same_month
# 2016-01-04 14:37:32.663000 ==> Malaysia + Singapore - 2015-08-18 - 1_month
# 2016-01-04 14:37:35.077878 ==> Malaysia + Singapore - 2015-08-18 - 2_month
# 2016-01-04 14:37:37.535688 ==> Malaysia + Singapore - 2015-08-18 - 3_month
# 2016-01-04 14:37:40.017904 ==> Malaysia + Singapore - 2015-08-18 - 4_month
# 2016-01-04 14:37:42.399286 ==> Malaysia + Singapore - 2015-08-18 - 5_month
# 2016-01-04 14:37:45.036743 ==> Malaysia + Singapore - 2015-08-18 - 6_month
# 2016-01-04 14:37:47.485467 ==> Malaysia + Singapore - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:37:49.987469 ==> Malaysia + Singapore - 2015-09-17 - same_month
# 2016-01-04 14:37:52.329124 ==> Malaysia + Singapore - 2015-09-17 - 1_month
# 2016-01-04 14:37:54.858560 ==> Malaysia + Singapore - 2015-09-17 - 2_month
# 2016-01-04 14:37:57.409922 ==> Malaysia + Singapore - 2015-09-17 - 3_month
# 2016-01-04 14:37:59.923134 ==> Malaysia + Singapore - 2015-09-17 - 4_month
# 2016-01-04 14:38:02.344765 ==> Malaysia + Singapore - 2015-09-17 - 5_month
# 2016-01-04 14:38:04.787255 ==> Malaysia + Singapore - 2015-09-17 - 6_month
# 2016-01-04 14:38:07.175117 ==> Malaysia + Singapore - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:38:09.805100 ==> Malaysia + Singapore - 2015-10-17 - same_month
# 2016-01-04 14:38:12.242868 ==> Malaysia + Singapore - 2015-10-17 - 1_month
# 2016-01-04 14:38:14.578783 ==> Malaysia + Singapore - 2015-10-17 - 2_month
# 2016-01-04 14:38:17.088066 ==> Malaysia + Singapore - 2015-10-17 - 3_month
# 2016-01-04 14:38:19.458972 ==> Malaysia + Singapore - 2015-10-17 - 4_month
# 2016-01-04 14:38:21.835995 ==> Malaysia + Singapore - 2015-10-17 - 5_month
# 2016-01-04 14:38:24.414540 ==> Malaysia + Singapore - 2015-10-17 - 6_month
# 2016-01-04 14:38:26.992303 ==> Malaysia + Singapore - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:38:29.395052 ==> Malaysia + Singapore - 2015-11-16 - same_month
# 2016-01-04 14:38:31.778801 ==> Malaysia + Singapore - 2015-11-16 - 1_month
# 2016-01-04 14:38:34.379789 ==> Malaysia + Singapore - 2015-11-16 - 2_month
# 2016-01-04 14:38:36.898707 ==> Malaysia + Singapore - 2015-11-16 - 3_month
# 2016-01-04 14:38:39.568295 ==> Malaysia + Singapore - 2015-11-16 - 4_month
# 2016-01-04 14:38:42.236362 ==> Malaysia + Singapore - 2015-11-16 - 5_month
# 2016-01-04 14:38:44.708972 ==> Malaysia + Singapore - 2015-11-16 - 6_month
# 2016-01-04 14:38:47.024816 ==> Malaysia + Singapore - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:38:49.691696 ==> Malaysia + Singapore - 2015-12-16 - same_month
# 2016-01-04 14:38:52.179666 ==> Malaysia + Singapore - 2015-12-16 - 1_month
# 2016-01-04 14:38:54.904550 ==> Malaysia + Singapore - 2015-12-16 - 2_month
# 2016-01-04 14:38:58.414725 ==> Malaysia + Singapore - 2015-12-16 - 3_month
# 2016-01-04 14:39:02.533125 ==> Malaysia + Singapore - 2015-12-16 - 4_month
# 2016-01-04 14:39:05.048784 ==> Malaysia + Singapore - 2015-12-16 - 5_month
# 2016-01-04 14:39:07.507948 ==> Malaysia + Singapore - 2015-12-16 - 6_month
# 2016-01-04 14:39:10.034180 ==> Malaysia + Singapore - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:39:12.701876 ==> Mexico - 2015-04-20 - same_month
# 2016-01-04 14:39:15.108983 ==> Mexico - 2015-04-20 - 1_month
# 2016-01-04 14:39:17.360903 ==> Mexico - 2015-04-20 - 2_month
# 2016-01-04 14:39:21.140377 ==> Mexico - 2015-04-20 - 3_month
# 2016-01-04 14:39:23.560821 ==> Mexico - 2015-04-20 - 4_month
# 2016-01-04 14:39:25.937994 ==> Mexico - 2015-04-20 - 5_month
# 2016-01-04 14:39:28.355924 ==> Mexico - 2015-04-20 - 6_month
# 2016-01-04 14:39:30.728497 ==> Mexico - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:39:33.108501 ==> Mexico - 2015-05-20 - same_month
# 2016-01-04 14:39:35.477128 ==> Mexico - 2015-05-20 - 1_month
# 2016-01-04 14:39:37.935825 ==> Mexico - 2015-05-20 - 2_month
# 2016-01-04 14:39:40.396670 ==> Mexico - 2015-05-20 - 3_month
# 2016-01-04 14:39:42.676596 ==> Mexico - 2015-05-20 - 4_month
# 2016-01-04 14:39:44.963675 ==> Mexico - 2015-05-20 - 5_month
# 2016-01-04 14:39:47.348104 ==> Mexico - 2015-05-20 - 6_month
# 2016-01-04 14:39:49.816549 ==> Mexico - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:39:52.532755 ==> Mexico - 2015-06-19 - same_month
# 2016-01-04 14:39:55.392458 ==> Mexico - 2015-06-19 - 1_month
# 2016-01-04 14:39:58.509819 ==> Mexico - 2015-06-19 - 2_month
# 2016-01-04 14:40:01.682902 ==> Mexico - 2015-06-19 - 3_month
# 2016-01-04 14:40:04.871632 ==> Mexico - 2015-06-19 - 4_month
# 2016-01-04 14:40:07.890356 ==> Mexico - 2015-06-19 - 5_month
# 2016-01-04 14:40:10.393782 ==> Mexico - 2015-06-19 - 6_month
# 2016-01-04 14:40:12.782435 ==> Mexico - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:40:15.688995 ==> Mexico - 2015-07-19 - same_month
# 2016-01-04 14:40:18.014233 ==> Mexico - 2015-07-19 - 1_month
# 2016-01-04 14:40:20.442729 ==> Mexico - 2015-07-19 - 2_month
# 2016-01-04 14:40:23.275572 ==> Mexico - 2015-07-19 - 3_month
# 2016-01-04 14:40:25.692503 ==> Mexico - 2015-07-19 - 4_month
# 2016-01-04 14:40:27.956064 ==> Mexico - 2015-07-19 - 5_month
# 2016-01-04 14:40:30.252906 ==> Mexico - 2015-07-19 - 6_month
# 2016-01-04 14:40:33.806732 ==> Mexico - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:40:36.112637 ==> Mexico - 2015-08-18 - same_month
# 2016-01-04 14:40:38.586428 ==> Mexico - 2015-08-18 - 1_month
# 2016-01-04 14:40:41.058617 ==> Mexico - 2015-08-18 - 2_month
# 2016-01-04 14:40:43.397437 ==> Mexico - 2015-08-18 - 3_month
# 2016-01-04 14:40:45.703074 ==> Mexico - 2015-08-18 - 4_month
# 2016-01-04 14:40:48.080572 ==> Mexico - 2015-08-18 - 5_month
# 2016-01-04 14:40:50.738606 ==> Mexico - 2015-08-18 - 6_month
# 2016-01-04 14:40:53.226933 ==> Mexico - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:40:55.801124 ==> Mexico - 2015-09-17 - same_month
# 2016-01-04 14:40:59.280085 ==> Mexico - 2015-09-17 - 1_month
# 2016-01-04 14:41:01.645635 ==> Mexico - 2015-09-17 - 2_month
# 2016-01-04 14:41:03.931499 ==> Mexico - 2015-09-17 - 3_month
# 2016-01-04 14:41:06.256431 ==> Mexico - 2015-09-17 - 4_month
# 2016-01-04 14:41:08.884022 ==> Mexico - 2015-09-17 - 5_month
# 2016-01-04 14:41:11.277654 ==> Mexico - 2015-09-17 - 6_month
# 2016-01-04 14:41:13.712772 ==> Mexico - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:41:16.197594 ==> Mexico - 2015-10-17 - same_month
# 2016-01-04 14:41:18.571772 ==> Mexico - 2015-10-17 - 1_month
# 2016-01-04 14:41:20.977681 ==> Mexico - 2015-10-17 - 2_month
# 2016-01-04 14:41:23.444586 ==> Mexico - 2015-10-17 - 3_month
# 2016-01-04 14:41:26.121628 ==> Mexico - 2015-10-17 - 4_month
# 2016-01-04 14:41:28.474015 ==> Mexico - 2015-10-17 - 5_month
# 2016-01-04 14:41:30.914606 ==> Mexico - 2015-10-17 - 6_month
# 2016-01-04 14:41:34.270997 ==> Mexico - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:41:37.883802 ==> Mexico - 2015-11-16 - same_month
# 2016-01-04 14:41:41.593712 ==> Mexico - 2015-11-16 - 1_month
# 2016-01-04 14:41:44.312714 ==> Mexico - 2015-11-16 - 2_month
# 2016-01-04 14:41:46.650081 ==> Mexico - 2015-11-16 - 3_month
# 2016-01-04 14:41:48.933349 ==> Mexico - 2015-11-16 - 4_month
# 2016-01-04 14:41:51.316961 ==> Mexico - 2015-11-16 - 5_month
# 2016-01-04 14:41:53.943379 ==> Mexico - 2015-11-16 - 6_month
# 2016-01-04 14:41:56.664345 ==> Mexico - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:41:59.887428 ==> Mexico - 2015-12-16 - same_month
# 2016-01-04 14:42:02.751249 ==> Mexico - 2015-12-16 - 1_month
# 2016-01-04 14:42:05.102208 ==> Mexico - 2015-12-16 - 2_month
# 2016-01-04 14:42:07.508785 ==> Mexico - 2015-12-16 - 3_month
# 2016-01-04 14:42:10.025242 ==> Mexico - 2015-12-16 - 4_month
# 2016-01-04 14:42:12.435336 ==> Mexico - 2015-12-16 - 5_month
# 2016-01-04 14:42:14.727944 ==> Mexico - 2015-12-16 - 6_month
# 2016-01-04 14:42:17.050435 ==> Mexico - 2015-12-16 - 7_to_12_month
# 2016-01-04 14:42:19.465092 ==> Pakistan - 2015-04-20 - same_month
# 2016-01-04 14:42:22.159809 ==> Pakistan - 2015-04-20 - 1_month
# 2016-01-04 14:42:24.861218 ==> Pakistan - 2015-04-20 - 2_month
# 2016-01-04 14:42:27.255582 ==> Pakistan - 2015-04-20 - 3_month
# 2016-01-04 14:42:29.902903 ==> Pakistan - 2015-04-20 - 4_month
# 2016-01-04 14:42:32.386861 ==> Pakistan - 2015-04-20 - 5_month
# 2016-01-04 14:42:35.820310 ==> Pakistan - 2015-04-20 - 6_month
# 2016-01-04 14:42:38.379225 ==> Pakistan - 2015-04-20 - 7_to_12_month
# 2016-01-04 14:42:40.825403 ==> Pakistan - 2015-05-20 - same_month
# 2016-01-04 14:42:43.180118 ==> Pakistan - 2015-05-20 - 1_month
# 2016-01-04 14:42:45.760096 ==> Pakistan - 2015-05-20 - 2_month
# 2016-01-04 14:42:48.159908 ==> Pakistan - 2015-05-20 - 3_month
# 2016-01-04 14:42:50.491765 ==> Pakistan - 2015-05-20 - 4_month
# 2016-01-04 14:42:52.803852 ==> Pakistan - 2015-05-20 - 5_month
# 2016-01-04 14:42:55.343574 ==> Pakistan - 2015-05-20 - 6_month
# 2016-01-04 14:42:59.270375 ==> Pakistan - 2015-05-20 - 7_to_12_month
# 2016-01-04 14:43:01.617772 ==> Pakistan - 2015-06-19 - same_month
# 2016-01-04 14:43:05.449273 ==> Pakistan - 2015-06-19 - 1_month
# 2016-01-04 14:43:07.829145 ==> Pakistan - 2015-06-19 - 2_month
# 2016-01-04 14:43:10.392305 ==> Pakistan - 2015-06-19 - 3_month
# 2016-01-04 14:43:13.019908 ==> Pakistan - 2015-06-19 - 4_month
# 2016-01-04 14:43:15.438745 ==> Pakistan - 2015-06-19 - 5_month
# 2016-01-04 14:43:17.789358 ==> Pakistan - 2015-06-19 - 6_month
# 2016-01-04 14:43:20.120256 ==> Pakistan - 2015-06-19 - 7_to_12_month
# 2016-01-04 14:43:23.528118 ==> Pakistan - 2015-07-19 - same_month
# 2016-01-04 14:43:26.007797 ==> Pakistan - 2015-07-19 - 1_month
# 2016-01-04 14:43:28.371986 ==> Pakistan - 2015-07-19 - 2_month
# 2016-01-04 14:43:30.794899 ==> Pakistan - 2015-07-19 - 3_month
# 2016-01-04 14:43:33.717297 ==> Pakistan - 2015-07-19 - 4_month
# 2016-01-04 14:43:36.083776 ==> Pakistan - 2015-07-19 - 5_month
# 2016-01-04 14:43:38.535824 ==> Pakistan - 2015-07-19 - 6_month
# 2016-01-04 14:43:41.049724 ==> Pakistan - 2015-07-19 - 7_to_12_month
# 2016-01-04 14:43:43.447337 ==> Pakistan - 2015-08-18 - same_month
# 2016-01-04 14:43:45.774143 ==> Pakistan - 2015-08-18 - 1_month
# 2016-01-04 14:43:48.145342 ==> Pakistan - 2015-08-18 - 2_month
# 2016-01-04 14:43:50.598893 ==> Pakistan - 2015-08-18 - 3_month
# 2016-01-04 14:43:53.007663 ==> Pakistan - 2015-08-18 - 4_month
# 2016-01-04 14:43:55.741300 ==> Pakistan - 2015-08-18 - 5_month
# 2016-01-04 14:43:58.481868 ==> Pakistan - 2015-08-18 - 6_month
# 2016-01-04 14:44:00.865863 ==> Pakistan - 2015-08-18 - 7_to_12_month
# 2016-01-04 14:44:03.168784 ==> Pakistan - 2015-09-17 - same_month
# 2016-01-04 14:44:05.471367 ==> Pakistan - 2015-09-17 - 1_month
# 2016-01-04 14:44:08.028569 ==> Pakistan - 2015-09-17 - 2_month
# 2016-01-04 14:44:10.640627 ==> Pakistan - 2015-09-17 - 3_month
# 2016-01-04 14:44:13.018433 ==> Pakistan - 2015-09-17 - 4_month
# 2016-01-04 14:44:15.568564 ==> Pakistan - 2015-09-17 - 5_month
# 2016-01-04 14:44:18.074823 ==> Pakistan - 2015-09-17 - 6_month
# 2016-01-04 14:44:20.505786 ==> Pakistan - 2015-09-17 - 7_to_12_month
# 2016-01-04 14:44:22.885109 ==> Pakistan - 2015-10-17 - same_month
# 2016-01-04 14:44:26.311974 ==> Pakistan - 2015-10-17 - 1_month
# 2016-01-04 14:44:29.855210 ==> Pakistan - 2015-10-17 - 2_month
# 2016-01-04 14:44:32.199301 ==> Pakistan - 2015-10-17 - 3_month
# 2016-01-04 14:44:34.648860 ==> Pakistan - 2015-10-17 - 4_month
# 2016-01-04 14:44:37.006720 ==> Pakistan - 2015-10-17 - 5_month
# 2016-01-04 14:44:39.333296 ==> Pakistan - 2015-10-17 - 6_month
# 2016-01-04 14:44:41.690957 ==> Pakistan - 2015-10-17 - 7_to_12_month
# 2016-01-04 14:44:44.199123 ==> Pakistan - 2015-11-16 - same_month
# 2016-01-04 14:44:46.727283 ==> Pakistan - 2015-11-16 - 1_month
# 2016-01-04 14:44:49.401395 ==> Pakistan - 2015-11-16 - 2_month
# 2016-01-04 14:44:51.869214 ==> Pakistan - 2015-11-16 - 3_month
# 2016-01-04 14:44:54.454134 ==> Pakistan - 2015-11-16 - 4_month
# 2016-01-04 14:44:57.047593 ==> Pakistan - 2015-11-16 - 5_month
# 2016-01-04 14:45:00.299045 ==> Pakistan - 2015-11-16 - 6_month
# 2016-01-04 14:45:02.725211 ==> Pakistan - 2015-11-16 - 7_to_12_month
# 2016-01-04 14:45:05.057143 ==> Pakistan - 2015-12-16 - same_month
# 2016-01-04 14:45:07.377895 ==> Pakistan - 2015-12-16 - 1_month
# 2016-01-04 14:45:10.371732 ==> Pakistan - 2015-12-16 - 2_month
# 2016-01-04 14:45:12.860117 ==> Pakistan - 2015-12-16 - 3_month
# 2016-01-04 14:45:15.700415 ==> Pakistan - 2015-12-16 - 4_month
# 2016-01-04 14:45:18.296421 ==> Pakistan - 2015-12-16 - 5_month
# 2016-01-04 14:45:21.112848 ==> Pakistan - 2015-12-16 - 6_month
# 2016-01-04 14:45:23.742763 ==> Pakistan - 2015-12-16 - 7_to_12_month

# %%
html_driver = html(cohort_driver_final,cohort_size_driver,1)
html_pax = html(cohort_passenger_final,cohort_size_pax,2)

# %%
html_pdf = html_driver + '<br/><br/><br/><br/><br/><br/><br/><br/>' +  html_pax 
PDFReport_Name = titles(2)
pdfkit.from_string(html_pdf, "/home/ricardo/Tripda/cohort/" + 'Cohorts-December_2015.pdf')
# Out:
# Loading pages (1/5)
# Resolving links (2/5)
# Counting pages (3/5)
# Printing pages (5/5)
# Done
# True

# %%
html_body = html_inicial() + html_driver + html_pax
Subject = titles(1)
SendEmail('teste',html_body,'ricardo.nakano@tripda.com.br','tripda-datateam@tripda.com.br','123@datateam','','')
# Out:
# Unexpected error: <type 'exceptions.IOError'>

# %%
df = pd.DataFrame(columns=('Country', 'Date', 'Reference', \
                           'cohort size RR1 driver','cohort size RR2 driver', \
                           'RR1 driver', 'RR1 driver_Ac','RR2 driver', 'RR2 driver_Ac', \
                           'cohort size RR1 pax','cohort size  RR2 pax',\
                           'RR1 pax', 'RR1 pax_Ac','RR2 pax', 'RR2 pax_Ac'))
count = 0

for locate in countries:
    for date in months:
        for referece in reference_month:
            toexcel = []
            toexcel.append(locate)
            toexcel.append(date.strftime("%b/%Y"))
            toexcel.append(referece)
            
            toexcel.append(cohort_size_driver[locate][date]['RR1'])
            toexcel.append(cohort_size_driver[locate][date]['RR2'])
            if cohort_driver_final[locate][date][referece]['RR1'] < 0:
                toexcel.append(-cohort_driver_final[locate][date][referece]['RR1'])
                toexcel.append(-cohort_driver_final[locate][date][referece]['RR1_Ac'])
            elif cohort_driver_final[locate][date][referece]['RR1'] >= pow(10,100):
                toexcel.append(0)  
                toexcel.append(0)
            else:
                toexcel.append(cohort_driver_final[locate][date][referece]['RR1'])
                toexcel.append(cohort_driver_final[locate][date][referece]['RR1_Ac'])   
                
            if cohort_driver_final[locate][date][referece]['RR2'] < 0:
                toexcel.append(-cohort_driver_final[locate][date][referece]['RR2'])
                toexcel.append(-cohort_driver_final[locate][date][referece]['RR2_Ac'])
            elif cohort_driver_final[locate][date][referece]['RR2'] >= pow(10,100):
                toexcel.append(0)
                toexcel.append(0) 
            else:
                toexcel.append(cohort_driver_final[locate][date][referece]['RR2'])
                toexcel.append(cohort_driver_final[locate][date][referece]['RR2_Ac']) 
            
            toexcel.append(cohort_size_pax[locate][date]['RR1'])
            toexcel.append(cohort_size_pax[locate][date]['RR2'])
            if cohort_passenger_final[locate][date][referece]['RR1'] < 0:
                toexcel.append(-cohort_passenger_final[locate][date][referece]['RR1'])
                toexcel.append(-cohort_passenger_final[locate][date][referece]['RR1_Ac'])
            elif cohort_passenger_final[locate][date][referece]['RR1'] >= pow(10,100):
                toexcel.append(0)
                toexcel.append(0)
            else:
                toexcel.append(cohort_passenger_final[locate][date][referece]['RR1']) 
                toexcel.append(cohort_passenger_final[locate][date][referece]['RR1_Ac']) 
                
            if cohort_passenger_final[locate][date][referece]['RR2'] < 0:
                toexcel.append(-cohort_passenger_final[locate][date][referece]['RR2'])
                toexcel.append(-cohort_passenger_final[locate][date][referece]['RR2_Ac'])
            elif cohort_passenger_final[locate][date][referece]['RR2'] >= pow(10,100):
                toexcel.append(0)
                toexcel.append(0) 
            else:
                toexcel.append(cohort_passenger_final[locate][date][referece]['RR2'])
                toexcel.append(cohort_passenger_final[locate][date][referece]['RR2_Ac'])

            df.loc[count] = toexcel
            count += 1

# %%
df.to_csv('/home/ricardo/Tripda/cohort/cohort.csv', sep=',')

# %%
writer = pd.ExcelWriter('/home/ricardo/Tripda/cohort/cohort.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='cohort')

writer.save()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-3548906aefb2> in <module>()
# ----> 1 writer = pd.ExcelWriter('/home/ricardo/Tripda/cohort/cohort.csv', engine='xlsxwriter')
#       2 df.to_excel(writer, sheet_name='cohort')
#       3
#       4 writer.save()
#
# /home/ricardo/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, path, engine, date_format, datetime_format, **engine_kwargs)
#    1288                                           date_format=date_format,
#    1289                                           datetime_format=datetime_format,
# -> 1290                                           **engine_kwargs)
#    1291
#    1292         self.book = xlsxwriter.Workbook(path, **engine_kwargs)
#
# /home/ricardo/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, path, engine, date_format, datetime_format, **engine_kwargs)
#     576         # validate that this engine can handle the extension
#     577         ext = os.path.splitext(path)[-1]
# --> 578         self.check_extension(ext)
#     579
#     580         self.path = path
#
# /home/ricardo/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in check_extension(cls, ext)
#     608             msg = (u("Invalid extension for engine '%s': '%s'") %
#     609                    (pprint_thing(cls.engine), pprint_thing(ext)))
# --> 610             raise ValueError(msg)
#     611         else:
#     612             return True
#
# ValueError: Invalid extension for engine 'xlsxwriter': 'csv'

# %%
df
# Out:
#       Country      Date      Reference  cohort size RR1 driver  \
# 0       TOTAL  Jan/2015     same_month                    1430
# 1       TOTAL  Jan/2015        1_month                    1430
# 2       TOTAL  Jan/2015        2_month                    1430
# 3       TOTAL  Jan/2015        3_month                    1430
# 4       TOTAL  Jan/2015        4_month                    1430
# 5       TOTAL  Jan/2015        5_month                    1430
# 6       TOTAL  Jan/2015        6_month                    1430
# 7       TOTAL  Jan/2015  7_to_12_month                    1430
# 8       TOTAL  Feb/2015     same_month                    1292
# 9       TOTAL  Feb/2015        1_month                    1292
# 10      TOTAL  Feb/2015        2_month                    1292
# 11      TOTAL  Feb/2015        3_month                    1292
# 12      TOTAL  Feb/2015        4_month                    1292
# 13      TOTAL  Feb/2015        5_month                    1292
# 14      TOTAL  Feb/2015        6_month                    1292
# 15      TOTAL  Feb/2015  7_to_12_month                    1292
# 16      TOTAL  Mar/2015     same_month                    2226
# 17      TOTAL  Mar/2015        1_month                    2226
# 18      TOTAL  Mar/2015        2_month                    2226
# 19      TOTAL  Mar/2015        3_month                    2226
# 20      TOTAL  Mar/2015        4_month                    2226
# 21      TOTAL  Mar/2015        5_month                    2226
# 22      TOTAL  Mar/2015        6_month                    2226
# 23      TOTAL  Mar/2015  7_to_12_month                    2226
# 24      TOTAL  Apr/2015     same_month                    2191
# 25      TOTAL  Apr/2015        1_month                    2191
# 26      TOTAL  Apr/2015        2_month                    2191
# 27      TOTAL  Apr/2015        3_month                    2191
# 28      TOTAL  Apr/2015        4_month                    2191
# 29      TOTAL  Apr/2015        5_month                    2191
# ..        ...       ...            ...                     ...
# 618  Pakistan  Jun/2015        2_month                     134
# 619  Pakistan  Jun/2015        3_month                     134
# 620  Pakistan  Jun/2015        4_month                     134
# 621  Pakistan  Jun/2015        5_month                     134
# 622  Pakistan  Jun/2015        6_month                     134
# 623  Pakistan  Jun/2015  7_to_12_month                     134
# 624  Pakistan  Jul/2015     same_month                     242
# 625  Pakistan  Jul/2015        1_month                     242
# 626  Pakistan  Jul/2015        2_month                     242
# 627  Pakistan  Jul/2015        3_month                     242
# 628  Pakistan  Jul/2015        4_month                     242
# 629  Pakistan  Jul/2015        5_month                     242
# 630  Pakistan  Jul/2015        6_month                     242
# 631  Pakistan  Jul/2015  7_to_12_month                     242
# 632  Pakistan  Aug/2015     same_month                     342
# 633  Pakistan  Aug/2015        1_month                     342
# 634  Pakistan  Aug/2015        2_month                     342
# 635  Pakistan  Aug/2015        3_month                     342
# 636  Pakistan  Aug/2015        4_month                     342
# 637  Pakistan  Aug/2015        5_month                     342
# 638  Pakistan  Aug/2015        6_month                     342
# 639  Pakistan  Aug/2015  7_to_12_month                     342
# 640  Pakistan  Sep/2015     same_month                     363
# 641  Pakistan  Sep/2015        1_month                     363
# 642  Pakistan  Sep/2015        2_month                     363
# 643  Pakistan  Sep/2015        3_month                     363
# 644  Pakistan  Sep/2015        4_month                     363
# 645  Pakistan  Sep/2015        5_month                     363
# 646  Pakistan  Sep/2015        6_month                     363
# 647  Pakistan  Sep/2015  7_to_12_month                     363
#
#      cohort size RR2 driver  RR1 driver  RR2 driver_Ac  RR1 driver  \
# 0                    552509         363            363      335060
# 1                    552509         211            465      199302
# 2                    552509         158            498      170602
# 3                    552509         157            523      197137
# 4                    552509         105            531      159756
# 5                    552509         110            542      135796
# 6                    552509          87            552      109172
# 7                    552509         121            569      267525
# 8                    464459         364            364      380072
# 9                    464459         246            486      285114
# 10                   464459         194            522      252522
# 11                   464459         150            542      199337
# 12                   464459         115            560      148095
# 13                   464459         101            576      141697
# 14                   464459         121            589      192987
# 15                   464459         106            599      148485
# 16                   656994         870            870      582504
# 17                   656994         341           1008      331995
# 18                   656994         269           1059      277306
# 19                   656994         211           1079      242789
# 20                   656994         151           1094      161811
# 21                   656994         176           1120      216228
# 22                   656994         171           1137      185390
# 23                   656994           0              0           0
# 24                  1083582        1067           1067     1077493
# 25                  1083582         426           1203      405099
# 26                  1083582         327           1263      317056
# 27                  1083582         183           1285      177573
# 28                  1083582         290           1322      371125
# 29                  1083582         247           1342      309001
# ..                      ...         ...            ...         ...
# 618                  165748          11             32       13966
# 619                  165748           8             36        4578
# 620                  165748           0              0           0
# 621                  165748           0              0           0
# 622                  165748           0              0           0
# 623                  165748           0              0           0
# 624                  195906          69             69      139687
# 625                  195906          44             89       41345
# 626                  195906          27             96       23780
# 627                  195906           0              0           0
# 628                  195906           0              0           0
# 629                  195906           0              0           0
# 630                  195906           0              0           0
# 631                  195906           0              0           0
# 632                  278117         109            109      230906
# 633                  278117          53            126       19073
# 634                  278117           0              0           0
# 635                  278117           0              0           0
# 636                  278117           0              0           0
# 637                  278117           0              0           0
# 638                  278117           0              0           0
# 639                  278117           0              0           0
# 640                  188576         106            106       69288
# 641                  188576           0              0           0
# 642                  188576           0              0           0
# 643                  188576           0              0           0
# 644                  188576           0              0           0
# 645                  188576           0              0           0
# 646                  188576           0              0           0
# 647                  188576           0              0           0
#
#      RR2 driver_Ac
# 0           335060
# 1           534362
# 2           704964
# 3           902101
# 4          1061857
# 5          1197653
# 6          1306825
# 7          1574350
# 8           380072
# 9           665186
# 10          917708
# 11         1117045
# 12         1265140
# 13         1406837
# 14         1599824
# 15         1748309
# 16          582504
# 17          914499
# 18         1191805
# 19         1434594
# 20         1596405
# 21         1812633
# 22         1998023
# 23               0
# 24         1077493
# 25         1482592
# 26         1799648
# 27         1977221
# 28         2348346
# 29         2657347
# ..             ...
# 618          89904
# 619          94482
# 620              0
# 621              0
# 622              0
# 623              0
# 624         139687
# 625         181032
# 626         204812
# 627              0
# 628              0
# 629              0
# 630              0
# 631              0
# 632         230906
# 633         249979
# 634              0
# 635              0
# 636              0
# 637              0
# 638              0
# 639              0
# 640          69288
# 641              0
# 642              0
# 643              0
# 644              0
# 645              0
# 646              0
# 647              0
#
# [648 rows x 9 columns]

# %%
datetime.strptime('15' + '09' + '2015' , "%d%m%Y").date()
# Out:
# datetime.date(2015, 9, 15)

# %%
months
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-947b8a09ca50> in <module>()
# ----> 1 months
#
# NameError: name 'months' is not defined
