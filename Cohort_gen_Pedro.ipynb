# %%
import psycopg2 as pg
import pandas as pd
import pandas.io.sql as psql
import sys,os,re
from datetime import datetime
import pymysql

from time import sleep
from smtplib import SMTP
from email.MIMEMultipart import MIMEMultipart
from email.MIMEText import MIMEText
from email.MIMEImage import MIMEImage

import pdfkit
import wkhtmltopdf
from datetime import date, timedelta

import pandasql
import math

# %%
SQL_EXTRACT = '/home/ricardo/Tripda/cohort'
DATA_DIR = "/home/ricardo/Tripda/cohort/"

# %%
#semanal aux = -1 , dias = 270 red = '<font color="#FF0000">'
#mensal aux = 1 , dias = 300 red = ''

periodo = 'mensal'


if periodo == 'semanal':
    aux = -1
    dias = 270
    red = '<font color="#FF0000">'
elif periodo == 'mensal':
    aux = 1
    dias = 480
    red = ''
else:
    print 'erro'

# %%
countries = []
countries.append(' TOTAL')
countries.append('Argentina + Uruguay')
countries.append('Brasil')
countries.append('Chile')
countries.append('Colombia')
countries.append('India')
countries.append('Malaysia + Singapore')
countries.append('Mexico')
countries.append('Pakistan')
#countries.append('Philippines')
#countries.append('Taiwan')
#countries.append('United States')

month = datetime.now().strftime("%m")
year = datetime.now().strftime("%Y")
months = []
actual_month = datetime.strptime('15' + month + year , "%d%m%Y").date()
actual_month = actual_month - timedelta(days=dias)
for count in range(0,15):
    actual_month = actual_month + timedelta(days=30)
    months.append(actual_month)

reference_month = []
reference_month.append('same_month')
reference_month.append('1_month')
reference_month.append('2_month')
reference_month.append('3_month')
reference_month.append('4_month')
reference_month.append('5_month')
reference_month.append('6_month')
reference_month.append('7_month')
reference_month.append('8_month')
reference_month.append('9_month')
reference_month.append('10_month')
reference_month.append('11_month')
reference_month.append('12_month')
reference_month.append('13_month')
reference_month.append('14_month')

cohort_type = []
cohort_type.append('RR1')
cohort_type.append('RR1_Ac')
cohort_type.append('RR2')
cohort_type.append('RR2_Ac')

titles_main = ['Country','Month','Cohort size']
titles_cohort = ['<br/> Same month','<br/> 1 month','<br/> 2 months','<br/> 3 months','<br/> 4 months', \
                 '<br/> 5 months','<br/> 6 months','<br/> 7 months','<br/> 8 months','<br/> 9 months', \
                 '<br/> 10 months','<br/> 11 months','<br/> 12 months','<br/> 13 months','<br/> 14 months']
titles_name = []
titles_name.extend(titles_main)
titles_name.extend(titles_cohort)
titles_name.extend(titles_cohort)

# %%
all_drivers_table = pd.read_csv(file(DATA_DIR + "all_drivers.csv"))
first_driver_table = pd.read_csv(file(DATA_DIR + "first_driver.csv"))
all_pax_table = pd.read_csv(file(DATA_DIR + "all_pax.csv"))
first_pax_table = pd.read_csv(file(DATA_DIR + "first_pax.csv"))

# %%
def transform_1(first_table):

    ##### Create a list for first time using Tripda per country and per month #####
    cohort_first = {}
    for locate in countries:
        cohort_first[locate] = {}
        for date in months:
            cohort_first[locate][date] = {}
            
            cohort_first[locate][date]['RR1'] = first_table[(first_table.country == locate) & \
                                         (first_table.year == date.year) & \
                                         (first_table.month == date.month)].user_id.tolist()

            cohort_first[locate][date]['RR2'] = first_table[(first_table.country == locate) & \
                                         (first_table.year == date.year) & \
                                         (first_table.month == date.month)].distance.tolist()

    return cohort_first

# %%
def transform_2(first_table, all_table, cohort_first):

    pysql = lambda q: pandasql.sqldf(q, globals())

    cohort_lists = {}

    for locate in countries:
        cohort_lists[locate] = {}
        
        for date in months:
            cohort_lists[locate][date] = {}
            acumulated_list = []
            
            if cohort_first[locate][date]['RR1'] == []:
                l = []
                intermediary_query = "select distinct all_table.user_id from all_table where all_table.user_id in ('')"
            else:
                l = [str(x) for x in cohort_first[locate][date]['RR1']]
                intermediary_query = "select distinct all_table.user_id from all_table where all_table.user_id in (" + ','.join(l) + ")"

            for reference in reference_month:
                print str(datetime.now()) + ' ==> ' + str(locate) + ' - ' + str(date) + ' - ' + str(reference)
                cohort_lists[locate][date][reference] = {}         

                if reference == 'same_month':
                    reference_date = date
                    same_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                       ' and all_table.month = ' + str(reference_date.month) + \
                                       ' and all_table.count > 1'
                    
                    end_query = ' and ' + same_month_query
                    end_query_Ac = ' and ' + same_month_query
                
                Ac_month = actual_month - timedelta(days=30)
                if reference == '1_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=30)
                    _1_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _1_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + '))'

                Ac_month = actual_month - timedelta(days=60)
                if reference == '2_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=60)
                    _2_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _2_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + '))'
                
                Ac_month = actual_month - timedelta(days=90)
                if reference == '3_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=90)
                    _3_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _3_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + '))' 
                
                Ac_month = actual_month - timedelta(days=120)
                if reference == '4_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=120)
                    _4_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _4_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + '))' 
                
                Ac_month = actual_month - timedelta(days=150)
                if reference == '5_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=150)
                    _5_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _5_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + '))' 
        
                Ac_month = actual_month - timedelta(days=180)
                if reference == '6_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=180)
                    _6_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _6_month_query
                    end_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + '))' 

                    
                    
                    
                    
                    
                Ac_month = actual_month - timedelta(days=210)
                if reference == '7_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=210)
                    _7_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _7_month_query
                    eend_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + ') or (' \
                                        + _6_month_query + '))' 
                            
                Ac_month = actual_month - timedelta(days=240)
                if reference == '8_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=240)
                    _8_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _8_month_query
                    eend_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + ') or (' \
                                        + _6_month_query + ') or (' + _7_month_query + '))' 

                Ac_month = actual_month - timedelta(days=270)
                if reference == '9_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=270)
                    _9_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _9_month_query
                    eend_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + ') or (' \
                                        + _6_month_query + ') or (' + _7_month_query + ') or (' + _8_month_query + '))' 

                Ac_month = actual_month - timedelta(days=300)
                if reference == '10_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=300)
                    _10_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _10_month_query
                    eend_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + ') or (' \
                                        + _6_month_query + ') or (' + _7_month_query + ') or (' + _8_month_query + ') or (' + _9_month_query + '))' 

                Ac_month = actual_month - timedelta(days=330)
                if reference == '11_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=330)
                    _11_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _11_month_query
                    eend_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + ') or (' \
                                        + _6_month_query + ') or (' + _7_month_query + ') or (' + _8_month_query + ') or (' + _9_month_query + ') or (' \
                                        + _10_month_query + '))' 
                            
                Ac_month = actual_month - timedelta(days=360)
                if reference == '12_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=360)
                    _12_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _12_month_query
                    eend_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + ') or (' \
                                        + _6_month_query + ') or (' + _7_month_query + ') or (' + _8_month_query + ') or (' + _9_month_query + ') or (' \
                                        + _10_month_query + ') or (' + _11_month_query + '))'                             
                    
                Ac_month = actual_month - timedelta(days=390)
                if reference == '13_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=390)
                    _13_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _13_month_query
                    eend_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + ') or (' \
                                        + _6_month_query + ') or (' + _7_month_query + ') or (' + _8_month_query + ') or (' + _9_month_query + ') or (' \
                                        + _10_month_query + ') or (' + _11_month_query + ') or (' + _12_month_query + '))' 
                                
                Ac_month = actual_month - timedelta(days=420)
                if reference == '14_month' and Ac_month >= date:
                    reference_date = date + timedelta(days=420)
                    _14_month_query = 'all_table.year = ' + str(reference_date.year) + \
                                     ' and all_table.month = ' + str(reference_date.month)
                    
                    end_query = ' and ' + _14_month_query
                    eend_query_Ac =  ' and ((' + same_month_query + ') or (' + _1_month_query + ') or (' + _2_month_query + ') or (' \
                                        + _3_month_query + ') or (' + _4_month_query + ') or (' + _5_month_query + ') or (' + _6_month_query + ') or (' \
                                        + _6_month_query + ') or (' + _7_month_query + ') or (' + _8_month_query + ') or (' + _9_month_query + ') or (' \
                                        + _10_month_query + ') or (' + _11_month_query + ') or (' + _12_month_query + ') or (' + _13_month_query + '))'                                 
                    
           

                auxiliar_query = intermediary_query + end_query
                
                auxiliar_df = pandasql.sqldf(auxiliar_query, locals()) 
                auxiliar_list = auxiliar_df['user_id'].values.tolist()

                #List of accumulated users on the referent date
                acumulated_list.extend(auxiliar_list)
                acumulated_list = list(set(acumulated_list))

                ml = [str(x) for x in l]
                al = [str(x) for x in acumulated_list]
       
                if ml == []:
                    RR1_query = "select count(distinct all_table.user_id) from all_table where all_table.user_id in ('')"
                    RR2_query = "select sum(all_table.distance) from all_table where all_table.user_id in ('')"
                else:
                    RR1_query = "select count(distinct all_table.user_id) from all_table where all_table.user_id in (" + ','.join(ml) + ')'
                    RR2_query = "select sum(all_table.distance) from all_table where all_table.user_id in (" + ','.join(ml) + ')'

                if al == []:
                    RR1Ac_query = "select count(distinct all_table.user_id) from all_table where all_table.user_id in ('')"
                    RR2Ac_query = "select sum(all_table.distance) from all_table where all_table.user_id in ('')"
                else:
                    RR1Ac_query = "select count(distinct all_table.user_id) from all_table where all_table.user_id in (" + ','.join(al) + ')'
                    RR2Ac_query = "select sum(all_table.distance) from all_table where all_table.user_id in (" + ','.join(al) + ')'              
                 
                RR1_query += end_query
                RR1Ac_query += end_query_Ac
                RR2_query += end_query
                RR2Ac_query += end_query_Ac

                default_format = lambda x: str(x).translate(None, ''.join(['[' , ']' , '.', ' ']))
                
                cohort_lists[locate][date][reference] = {}
                
                final_df = pandasql.sqldf(RR1_query, locals())
                if default_format(final_df.values) == 'None':
                    cohort_lists[locate][date][reference]['RR1'] = 0
                else:
                    cohort_lists[locate][date][reference]['RR1'] = default_format(final_df.values)

                final_df = pandasql.sqldf(RR1Ac_query, locals()) 
                if default_format(final_df.values) == 'None':
                    cohort_lists[locate][date][reference]['RR1_Ac'] = 0
                else:
                    cohort_lists[locate][date][reference]['RR1_Ac'] = default_format(final_df.values)
                
                final_df = pandasql.sqldf(RR2_query, locals()) 
                if default_format(final_df.values) == 'None':
                    cohort_lists[locate][date][reference]['RR2'] = 0
                else:
                    cohort_lists[locate][date][reference]['RR2'] = default_format(final_df.values)
                
                final_df = pandasql.sqldf(RR2Ac_query, locals()) 
                if default_format(final_df.values) == 'None':
                    cohort_lists[locate][date][reference]['RR2_Ac'] = 0
                else:
                    cohort_lists[locate][date][reference]['RR2_Ac'] = default_format(final_df.values)
                    
    for locate in countries:
        for date in months:
            for reference in reference_month:
                for cohort in cohort_type:
                    cohort_lists[' TOTAL'][date][reference][cohort] =  str(int(cohort_lists[' TOTAL'][date][reference][cohort]) +
                                                                        int(cohort_lists[locate][date][reference][cohort]))
                    
    return cohort_lists

# %%
def transform_3(cohort_first):

    cohort_size = {}
    for locate in countries:
        cohort_size[locate] = {}
        
        for date in months:
            cohort_size[locate][date] = {}
            
            if int(date.month) == int(month) and int(date.year) == int(year):
                cohort_size[locate][date]['RR1'] = aux*len(cohort_first[locate][date]['RR1'])
                cohort_size[locate][date]['RR2'] = aux*sum([int(x) for x in cohort_first[locate][date]['RR2']])

                cohort_size[' TOTAL'][date]['RR1'] = cohort_size[' TOTAL'][date]['RR1'] + aux*int(math.sqrt(cohort_size[locate][date]['RR1']*cohort_size[locate][date]['RR1'])) 
                cohort_size[' TOTAL'][date]['RR2'] = cohort_size[' TOTAL'][date]['RR2'] + aux*int(math.sqrt(cohort_size[locate][date]['RR2']*cohort_size[locate][date]['RR2']))            
            else:
                cohort_size[locate][date]['RR1'] = len(cohort_first[locate][date]['RR1'])
                cohort_size[locate][date]['RR2'] = sum([int(x) for x in cohort_first[locate][date]['RR2']]) 
                
                cohort_size[' TOTAL'][date]['RR1'] += int(math.sqrt(cohort_size[locate][date]['RR1']*cohort_size[locate][date]['RR1'])) 
                cohort_size[' TOTAL'][date]['RR2'] += int(math.sqrt(cohort_size[locate][date]['RR2']*cohort_size[locate][date]['RR2']))              


    return cohort_size

# %%
def transform_4(cohort_lists):
    for country in countries:
        for cohort in cohort_type:
            
            counter = len(months) - 1
            for reference in reference_month:
                counter -= 1
                aux = counter
                for date in months:
                    
                    if aux >= 0:
                        cohort_lists[country][date][reference][cohort] = int(cohort_lists[country][date][reference][cohort])
                        aux -= 1
                    elif aux == -1:
                        if int(cohort_lists[country][date][reference][cohort]) == 0:
                            cohort_lists[country][date][reference][cohort] = aux*0.000001
                        else:
                            cohort_lists[country][date][reference][cohort] = aux*int(cohort_lists[country][date][reference][cohort])
                            
                        aux -= 1                   
                    else:
                        cohort_lists[country][date][reference][cohort] = pow(10,100)

    return cohort_lists

# %%
def html_inicial():

    ### TEXTO INICIAL ##########################################
    
    html_texto_inicial = "Please find bellow the Pax Cohort Report.\n <br/> \
    I attached Eduardo's presentation with the meaning of each cohort (for any doubt). \n <br/>\
    Also, please let me know if you need any additional data or help reading the report. \n <br/>\
    PDF attached, with the same data. <br/><br/><br/>\n\n"
    
    return html_texto_inicial

# %%
def html (cohort_lists, cohort_size, index):

    import pandas
    import numpy as np

    ### TITULO ##########################################
    if index == 1:
        html_titulo = '\n <br/> <table border="1"; style="font-size:30px"; align="center"; width="1600"; height="55";>\
    <th>Cohort - Driver</th></table><br/><br/>\n\n'
    else:
        html_titulo = '\n <br/> <table border="1"; style="font-size:30px"; align="center"; width="1600"; height="55";>\
    <th>Cohort - Passenger</th></table><br/><br/>\n\n'        
    ### CORPO 1 (RR1)##########################################
    rate_format = lambda x: str('%.1f' % x) + '%'

    html_corpo = '<table border="1" style="font-size:9px; border-collapse: collapse;" width="1600" align="center"> \
    <style> table, th, td {border: 1px solid black;} </style>\n'

    html_corpo += '    <tr> \n\
            <th colspan="3"></th> \n\
            <th bgcolor="#18BD9D" colspan="15" style="border-width: 2px;"><font color = "white">RR1</font></th> \n\
            <th bgcolor="#18BD9D" colspan="15" style="border-width: 2px;"><font color = "white">RR1 Acummulated</font></th> \n\
        </tr>\n\n'

    html_corpo += '    <tr bgcolor="#36E6C4" colspan="2"  height="60" style="border: solid 2px; font-size:9px">\n'

    for title in titles_name:
        if title == 'Month':
            html_corpo += '       <th width="200" style="border-width: 1px 2px 1px 1px ;">'
        else:
            html_corpo += '       <th width="90" style="border-width: 1px 2px 1px 1px ;">'
        html_corpo += title
        html_corpo +='</th>\n'
    html_corpo += '    </tr>\n\n'

    ref_country = ''
    for country in countries:
        for date in months:
            if country == ref_country:
                html_corpo += '    <tr>\n'
                html_corpo += ''
            else:
                html_corpo += '    <tr style="border-top: 2px solid black;">\n'
                html_corpo += '       <td align="center"; rowspan=" '+ str(len(months)) +'";>' + country + '</td>\n'
                ref_country = country
            html_corpo += '       <td align="center";>' + date.strftime("%b %Y") + '</td>\n'
            
            if cohort_size[country][date]['RR1'] < 0:
                cohort_size[country][date]['RR1'] = -cohort_size[country][date]['RR1']
                html_corpo += '       <td align="center"; bgcolor="#EEEEEE";><font color="#FF0000">' + str(cohort_size[country][date]['RR1']) + '</td>\n'
            else:
                html_corpo += '       <td align="center"; bgcolor="#EEEEEE">' + str(cohort_size[country][date]['RR1']) + '</td>\n'
                
            for cohort in ('RR1','RR1_Ac'):
                for reference in reference_month:
                    if reference == '14_month':
                        if cohort_size[country][date]['RR1'] == 0 or cohort_lists[country][date][reference][cohort] >= pow(10,100):
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>''</td>\n'
                        elif cohort_lists[country][date][reference][cohort] < 0:
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>' + red + rate_format(100*float(-cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR1']) + '</td>\n'
                        else:
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>' + rate_format(100*float(cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR1']) + '</td>\n'
                    else:
                        if cohort_size[country][date]['RR1'] == 0 or cohort_lists[country][date][reference][cohort] >= pow(10,100):
                            html_corpo += '       <td align="center";>''</td>\n'
                        elif cohort_lists[country][date][reference][cohort] < 0:
                            html_corpo += '       <td align="center";">' + red + rate_format(100*float(-cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR1']) + '</td>\n'
                        else:
                            html_corpo += '       <td align="center";>' + rate_format(100*float(cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR1']) + '</td>\n'
            html_corpo += '    </tr>\n'
    
    html_corpo += '</table>\n <br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/>'        


    ### CORPO 2 (RR2)##########################################

    html_corpo += '\n\n<table border="1" style="font-size:9px; border-collapse: collapse;" width="1600" align="center"> \
    <style> table, th, td {border: 1px solid black;} </style>\n'

    html_corpo += '    <tr> \n\
            <th colspan="3"></th> \n\
            <th bgcolor="#18BD9D" colspan="15" style="border-width: 2px;"><font color = "white">RR2</font></th> \n\
            <th bgcolor="#18BD9D" colspan="15" style="border-width: 2px;"><font color = "white">RR2 Acummulated</font></th> \n\
        </tr>\n\n'

    html_corpo += '    <tr bgcolor="#36E6C4" colspan="2"  height="60" style="border: solid 2px; font-size:9px">\n'

    for title in titles_name:
        if title == 'Month':
            html_corpo += '       <th width="200" style="border-width: 1px 2px 1px 1px ;">'
        else:
            html_corpo += '       <th width="90" style="border-width: 1px 2px 1px 1px ;">'
        html_corpo += title
        html_corpo +='</th>\n'
    html_corpo += '    </tr>\n\n'

    ref_country = ''
    for country in countries:
        for date in months:
            if country == ref_country:
                html_corpo += '    <tr>\n'
                html_corpo += ''
            else:
                html_corpo += '    <tr style="border-top: 2px solid black;">\n'
                html_corpo += '       <td align="center"; rowspan=" '+ str(len(months)) +'";>' + country + '</td>\n'
                ref_country = country
            html_corpo += '       <td align="center";>' + date.strftime("%b %Y") + '</td>\n'
            
            if cohort_size[country][date]['RR2'] < 0:
                cohort_size[country][date]['RR2'] = -cohort_size[country][date]['RR2']
                html_corpo += '       <td align="center"; bgcolor="#EEEEEE";><font color="#FF0000">' + str(cohort_size[country][date]['RR2']) + '</td>\n'
            else:
                html_corpo += '       <td align="center"; bgcolor="#EEEEEE">' + str(cohort_size[country][date]['RR2']) + '</td>\n'
                
            for cohort in ('RR2','RR2_Ac'):
                for reference in reference_month:
                    if reference == '14_month':
                        if cohort_size[country][date]['RR2'] == 0 or cohort_lists[country][date][reference][cohort] >= pow(10,100):
                             html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>''</td>\n'
                        elif cohort_lists[country][date][reference][cohort] < 0:
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>' + red + rate_format(100*float(-cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR2']) + '</td>\n'
                        else:
                            html_corpo += '       <td align="center"; style="border-width: 1px 2px 1px 1px";>' + rate_format(100*float(cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR2']) + '</td>\n'
                    else:
                        if cohort_size[country][date]['RR2'] == 0 or cohort_lists[country][date][reference][cohort] >= pow(10,100):
                            html_corpo += '       <td align="center";>''</td>\n'
                        elif cohort_lists[country][date][reference][cohort] < 0:
                            html_corpo += '       <td align="center";>' + red + rate_format(100*float(-cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR2']) + '</td>\n'
                        else:
                            html_corpo += '       <td align="center";>' + rate_format(100*float(cohort_lists[country][date][reference][cohort])/cohort_size[country][date]['RR2']) + '</td>\n'
            html_corpo += '    </tr>\n'

    html_corpo += '</table> \n <br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/><br/>'

    html_body = html_titulo + html_corpo
    
    return html_body

# %%
def html_final():

    ### LEGENDA GERAL ##########################################
    html_legenda_geral = '<table border="1" style="font-size:12px; border-collapse: collapse; border-width: 2px;" width="700">\n\
    <tr>  \n\
        <th bgcolor="#18BD9D" width="160"><font color = "white">Traffic activity view</font></th>\n\
        <td>Date of when users book or offer a ride on the site</td>\n\
    </tr>\n\
    <tr>  \n\
        <th bgcolor="#18BD9D"><font color = "white">Realized view</font></th>\n\
        <td>Date of when trips actually occurs</td>\n\
    </tr>\n \
    </table><br/>\n'

    ### LEGENDA DETALHADA 1 ##########################################
    html_legenda_detalhada = '<table border="1" style="font-size:12px; border-collapse: collapse; border-width: 2px;" width="1100">\n\
    \
    <tr>  \n\
        <th bgcolor="#18BD9D" rowspan="6"  width="120" align="center"><font color = "white">Traffic activity view</font></th>\n\
        <th bgcolor="#36E6C4" width="200">New Users</th>\n\
        <td>New users on the given period</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">New Drivers</th>\n\
        <td>New drivers on the given period</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">New Passangers</th>\n\
        <td>New passangers  on the given period</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Trips Offered</th>\n\
        <td>Number of new trips offered in the given date. Number of trips don\'t include stopovers.\
    Eg: a trip from San Francisco to Los Angeles, stoping at Monterey and Santa Maria would count as 1 trip offered.</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Bookings</th>\n\
        <td>Number of bookings in the given period. Eg: a booking of 3 seats booked on 12/09/2014 to travel on 14/09/2014 would be counted as 1 booking on 12/09/2014 </td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Available Seat Kilometer (ASK)</th>\n\
        <td>Number of seats offered in the given period times the number of kilometers of each trip.</td>\n\
    </tr>\n'

    ### LEGENDA DETALHADA 2 ##########################################
    html_legenda_detalhada += '<tr>  \n\
        <th bgcolor="#18BD9D" rowspan="7" align="center"><font color = "white">Realized view</font></th>\n\
        <th bgcolor="#36E6C4">Trips realized</th>\n\
        <td>Number of trips with at least one Tripda passenger in the given period, regardless the number of bookings in the car.\
    Eg: a trip from Bogota to Manizales with 3 PAX and 3 different bookings would caount as 1 trip.</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">PAX transported</th>\n\
        <td>Number os passengers transported in the given period</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Average PAX per trip realized</th>\n\
        <td>Average PAX per trip realized  (PAX transported / Trips realized)</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Realized TRIP Yield</th>\n\
        <td>Percentage of outstanding trips offered that converted into a realized trip, having at least one PAX transported.\
    Don\'t confuse with "Trips offered". Here we consider the date when the trip takes place. \
    Eg: if in one day Malaysia had 100 trips outstanding and 12 trips realized, the \"Realized trip yield\" would be 12%.</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Average realized trip distance</th>\n\
        <td>Average distance traveled in the given period. The average is weighted by the number of passenger on each trip.</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">Driver Cancelation rate</th>\n\
        <td>Percentage of PAX affected by driver cancellations for trips that would happen in that given period.\
    If a Driver cancels a trip, in which no PAX has yet booked a seat, this wont\'t count for this statistics. \
    Eg: If there are 100 PAX travelig on Tripda in a given day and one driver cancels a ride with 4 seats booked, \
    the cacelation rate would be 4%</td>\n\
    </tr>\n\
    \
    <tr>  \n\
        <th bgcolor="#36E6C4">PAX Cancelation rate</th>\n\
        <td>Percentage of trips canceled by passengers that would actually become a real trip in the given period</td>\n\
    </tr>\n\
    \
    </table>'


    html_legend = html_legenda_geral + html_legenda_detalhada


    return html_legend

# %%
def SendEmail(subject, msgText, to, user,password, alias, imgName, replyTo=None):
    sender = alias

    try:
        conn = SMTP('smtp.gmail.com', 587)

        msg = MIMEMultipart()
        msg.attach(MIMEText(msgText, 'html'))
        msg['Subject']= subject
        msg['From']   = sender
        msg['cc'] = to
        #msg['cc'] = ', '.join(to)

        if replyTo:
            msg['reply-to'] = replyTo

        if imgName != None:
            fp = open(imgName, 'rb')
            img = MIMEImage(fp.read(), _subtype="pdf")
            fp.close()
            img.add_header('Content-Disposition', 'attachment', filename = imgName)
            msg.attach(img)

        conn.ehlo()
        conn.starttls()
        conn.set_debuglevel(False)
        conn.login(user, password)
        try:
            conn.sendmail(sender, to, msg.as_string())
        finally:
            conn.close()
    except:
        print "Unexpected error:", sys.exc_info()[0]

def titles (index):
    import time
    from time import strftime

    month = (date.today().strftime("%B"))
    Subject = "Tripda - Pax Cohort Report - " + month
    
    month = date.today().strftime("%B")
    year = date.today().strftime("%y")
    PDFReport_Name = "Cohorts " + month + " 20" +  year + ".pdf"

    if index == 1 :
        return Subject
    else:
        return PDFReport_Name

# %%
driver_first_list = transform_1(first_driver_table)
pax_first_list = transform_1(first_pax_table)

cohort_driver = transform_2(first_driver_table, all_drivers_table, driver_first_list)
cohort_passenger = transform_2(first_pax_table, all_pax_table, pax_first_list)

cohort_size_driver = transform_3(driver_first_list)
cohort_size_pax = transform_3(pax_first_list)

cohort_driver_final = transform_4(cohort_driver)
cohort_passenger_final = transform_4(cohort_passenger)
# Out:
# 2016-01-04 14:55:03.496505 ==>  TOTAL - 2014-10-22 - same_month
# 2016-01-04 14:55:04.909173 ==>  TOTAL - 2014-10-22 - 1_month
# 2016-01-04 14:55:06.377204 ==>  TOTAL - 2014-10-22 - 2_month
# 2016-01-04 14:55:07.874123 ==>  TOTAL - 2014-10-22 - 3_month
# 2016-01-04 14:55:08.883600 ==>  TOTAL - 2014-10-22 - 4_month
# 2016-01-04 14:55:09.870235 ==>  TOTAL - 2014-10-22 - 5_month
# 2016-01-04 14:55:10.860605 ==>  TOTAL - 2014-10-22 - 6_month
# 2016-01-04 14:55:11.854527 ==>  TOTAL - 2014-10-22 - 7_month
# 2016-01-04 14:55:13.420270 ==>  TOTAL - 2014-10-22 - 8_month
# 2016-01-04 14:55:14.750289 ==>  TOTAL - 2014-10-22 - 9_month
# 2016-01-04 14:55:15.914239 ==>  TOTAL - 2014-10-22 - 10_month
# 2016-01-04 14:55:16.912129 ==>  TOTAL - 2014-10-22 - 11_month
# 2016-01-04 14:55:17.925140 ==>  TOTAL - 2014-10-22 - 12_month
# 2016-01-04 14:55:19.514233 ==>  TOTAL - 2014-10-22 - 13_month
# 2016-01-04 14:55:21.242332 ==>  TOTAL - 2014-10-22 - 14_month
# 2016-01-04 14:55:22.389772 ==>  TOTAL - 2014-11-21 - same_month
# 2016-01-04 14:55:23.404809 ==>  TOTAL - 2014-11-21 - 1_month
# 2016-01-04 14:55:24.407442 ==>  TOTAL - 2014-11-21 - 2_month
# 2016-01-04 14:55:25.544046 ==>  TOTAL - 2014-11-21 - 3_month
# 2016-01-04 14:55:26.657828 ==>  TOTAL - 2014-11-21 - 4_month
# 2016-01-04 14:55:27.657104 ==>  TOTAL - 2014-11-21 - 5_month
# 2016-01-04 14:55:28.863557 ==>  TOTAL - 2014-11-21 - 6_month
# 2016-01-04 14:55:29.847254 ==>  TOTAL - 2014-11-21 - 7_month
# 2016-01-04 14:55:30.930990 ==>  TOTAL - 2014-11-21 - 8_month
# 2016-01-04 14:55:31.969177 ==>  TOTAL - 2014-11-21 - 9_month
# 2016-01-04 14:55:32.985545 ==>  TOTAL - 2014-11-21 - 10_month
# 2016-01-04 14:55:33.949913 ==>  TOTAL - 2014-11-21 - 11_month
# 2016-01-04 14:55:34.911979 ==>  TOTAL - 2014-11-21 - 12_month
# 2016-01-04 14:55:35.873629 ==>  TOTAL - 2014-11-21 - 13_month
# 2016-01-04 14:55:36.891659 ==>  TOTAL - 2014-11-21 - 14_month
# 2016-01-04 14:55:37.866939 ==>  TOTAL - 2014-12-21 - same_month
# 2016-01-04 14:55:38.847189 ==>  TOTAL - 2014-12-21 - 1_month
# 2016-01-04 14:55:39.870894 ==>  TOTAL - 2014-12-21 - 2_month
# 2016-01-04 14:55:40.868010 ==>  TOTAL - 2014-12-21 - 3_month
# 2016-01-04 14:55:41.842164 ==>  TOTAL - 2014-12-21 - 4_month
# 2016-01-04 14:55:42.795739 ==>  TOTAL - 2014-12-21 - 5_month
# 2016-01-04 14:55:43.734191 ==>  TOTAL - 2014-12-21 - 6_month
# 2016-01-04 14:55:44.671049 ==>  TOTAL - 2014-12-21 - 7_month
# 2016-01-04 14:55:45.604016 ==>  TOTAL - 2014-12-21 - 8_month
# 2016-01-04 14:55:46.542271 ==>  TOTAL - 2014-12-21 - 9_month
# 2016-01-04 14:55:47.489537 ==>  TOTAL - 2014-12-21 - 10_month
# 2016-01-04 14:55:48.505485 ==>  TOTAL - 2014-12-21 - 11_month
# 2016-01-04 14:55:49.505123 ==>  TOTAL - 2014-12-21 - 12_month
# 2016-01-04 14:55:50.590441 ==>  TOTAL - 2014-12-21 - 13_month
# 2016-01-04 14:55:51.565249 ==>  TOTAL - 2014-12-21 - 14_month
# 2016-01-04 14:55:52.632062 ==>  TOTAL - 2015-01-20 - same_month
# 2016-01-04 14:55:53.688768 ==>  TOTAL - 2015-01-20 - 1_month
# 2016-01-04 14:55:54.902513 ==>  TOTAL - 2015-01-20 - 2_month
# 2016-01-04 14:55:56.206342 ==>  TOTAL - 2015-01-20 - 3_month
# 2016-01-04 14:55:57.377172 ==>  TOTAL - 2015-01-20 - 4_month
# 2016-01-04 14:55:58.985952 ==>  TOTAL - 2015-01-20 - 5_month
# 2016-01-04 14:56:00.081558 ==>  TOTAL - 2015-01-20 - 6_month
# 2016-01-04 14:56:01.023570 ==>  TOTAL - 2015-01-20 - 7_month
# 2016-01-04 14:56:01.986329 ==>  TOTAL - 2015-01-20 - 8_month
# 2016-01-04 14:56:03.194295 ==>  TOTAL - 2015-01-20 - 9_month
# 2016-01-04 14:56:04.162704 ==>  TOTAL - 2015-01-20 - 10_month
# 2016-01-04 14:56:05.134608 ==>  TOTAL - 2015-01-20 - 11_month
# 2016-01-04 14:56:06.404613 ==>  TOTAL - 2015-01-20 - 12_month
# 2016-01-04 14:56:07.460680 ==>  TOTAL - 2015-01-20 - 13_month
# 2016-01-04 14:56:08.600305 ==>  TOTAL - 2015-01-20 - 14_month
# 2016-01-04 14:56:09.573975 ==>  TOTAL - 2015-02-19 - same_month
# 2016-01-04 14:56:10.575538 ==>  TOTAL - 2015-02-19 - 1_month
# 2016-01-04 14:56:11.525660 ==>  TOTAL - 2015-02-19 - 2_month
# 2016-01-04 14:56:12.466088 ==>  TOTAL - 2015-02-19 - 3_month
# 2016-01-04 14:56:13.481582 ==>  TOTAL - 2015-02-19 - 4_month
# 2016-01-04 14:56:14.546636 ==>  TOTAL - 2015-02-19 - 5_month
# 2016-01-04 14:56:15.774349 ==>  TOTAL - 2015-02-19 - 6_month
# 2016-01-04 14:56:16.781157 ==>  TOTAL - 2015-02-19 - 7_month
# 2016-01-04 14:56:17.771015 ==>  TOTAL - 2015-02-19 - 8_month
# 2016-01-04 14:56:18.791280 ==>  TOTAL - 2015-02-19 - 9_month
# 2016-01-04 14:56:19.783758 ==>  TOTAL - 2015-02-19 - 10_month
# 2016-01-04 14:56:20.750019 ==>  TOTAL - 2015-02-19 - 11_month
# 2016-01-04 14:56:21.679112 ==>  TOTAL - 2015-02-19 - 12_month
# 2016-01-04 14:56:22.624989 ==>  TOTAL - 2015-02-19 - 13_month
# 2016-01-04 14:56:23.565741 ==>  TOTAL - 2015-02-19 - 14_month
# 2016-01-04 14:56:24.799343 ==>  TOTAL - 2015-03-21 - same_month
# 2016-01-04 14:56:25.795622 ==>  TOTAL - 2015-03-21 - 1_month
# 2016-01-04 14:56:26.981133 ==>  TOTAL - 2015-03-21 - 2_month
# 2016-01-04 14:56:27.974027 ==>  TOTAL - 2015-03-21 - 3_month
# 2016-01-04 14:56:28.953616 ==>  TOTAL - 2015-03-21 - 4_month
# 2016-01-04 14:56:29.892073 ==>  TOTAL - 2015-03-21 - 5_month
# 2016-01-04 14:56:30.858304 ==>  TOTAL - 2015-03-21 - 6_month
# 2016-01-04 14:56:32.077059 ==>  TOTAL - 2015-03-21 - 7_month
# 2016-01-04 14:56:33.164888 ==>  TOTAL - 2015-03-21 - 8_month
# 2016-01-04 14:56:34.229002 ==>  TOTAL - 2015-03-21 - 9_month
# 2016-01-04 14:56:35.274208 ==>  TOTAL - 2015-03-21 - 10_month
# 2016-01-04 14:56:36.426489 ==>  TOTAL - 2015-03-21 - 11_month
# 2016-01-04 14:56:37.441658 ==>  TOTAL - 2015-03-21 - 12_month
# 2016-01-04 14:56:38.455154 ==>  TOTAL - 2015-03-21 - 13_month
# 2016-01-04 14:56:39.720271 ==>  TOTAL - 2015-03-21 - 14_month
# 2016-01-04 14:56:40.713513 ==>  TOTAL - 2015-04-20 - same_month
# 2016-01-04 14:56:42.059501 ==>  TOTAL - 2015-04-20 - 1_month
# 2016-01-04 14:56:42.994576 ==>  TOTAL - 2015-04-20 - 2_month
# 2016-01-04 14:56:43.929138 ==>  TOTAL - 2015-04-20 - 3_month
# 2016-01-04 14:56:45.018444 ==>  TOTAL - 2015-04-20 - 4_month
# 2016-01-04 14:56:46.228472 ==>  TOTAL - 2015-04-20 - 5_month
# 2016-01-04 14:56:47.175711 ==>  TOTAL - 2015-04-20 - 6_month
# 2016-01-04 14:56:48.151597 ==>  TOTAL - 2015-04-20 - 7_month
# 2016-01-04 14:56:49.096313 ==>  TOTAL - 2015-04-20 - 8_month
# 2016-01-04 14:56:50.048741 ==>  TOTAL - 2015-04-20 - 9_month
# 2016-01-04 14:56:51.034300 ==>  TOTAL - 2015-04-20 - 10_month
# 2016-01-04 14:56:52.022886 ==>  TOTAL - 2015-04-20 - 11_month
# 2016-01-04 14:56:53.034207 ==>  TOTAL - 2015-04-20 - 12_month
# 2016-01-04 14:56:54.096510 ==>  TOTAL - 2015-04-20 - 13_month
# 2016-01-04 14:56:55.159761 ==>  TOTAL - 2015-04-20 - 14_month
# 2016-01-04 14:56:56.254682 ==>  TOTAL - 2015-05-20 - same_month
# 2016-01-04 14:56:57.401270 ==>  TOTAL - 2015-05-20 - 1_month
# 2016-01-04 14:56:58.501133 ==>  TOTAL - 2015-05-20 - 2_month
# 2016-01-04 14:56:59.499238 ==>  TOTAL - 2015-05-20 - 3_month
# 2016-01-04 14:57:00.529220 ==>  TOTAL - 2015-05-20 - 4_month
# 2016-01-04 14:57:01.548527 ==>  TOTAL - 2015-05-20 - 5_month
# 2016-01-04 14:57:02.689452 ==>  TOTAL - 2015-05-20 - 6_month
# 2016-01-04 14:57:03.628192 ==>  TOTAL - 2015-05-20 - 7_month
# 2016-01-04 14:57:04.557560 ==>  TOTAL - 2015-05-20 - 8_month
# 2016-01-04 14:57:05.519816 ==>  TOTAL - 2015-05-20 - 9_month
# 2016-01-04 14:57:06.575247 ==>  TOTAL - 2015-05-20 - 10_month
# 2016-01-04 14:57:07.562842 ==>  TOTAL - 2015-05-20 - 11_month
# 2016-01-04 14:57:08.579394 ==>  TOTAL - 2015-05-20 - 12_month
# 2016-01-04 14:57:09.611432 ==>  TOTAL - 2015-05-20 - 13_month
# 2016-01-04 14:57:10.623235 ==>  TOTAL - 2015-05-20 - 14_month
# 2016-01-04 14:57:11.616126 ==>  TOTAL - 2015-06-19 - same_month
# 2016-01-04 14:57:12.551011 ==>  TOTAL - 2015-06-19 - 1_month
# 2016-01-04 14:57:13.505961 ==>  TOTAL - 2015-06-19 - 2_month
# 2016-01-04 14:57:14.439622 ==>  TOTAL - 2015-06-19 - 3_month
# 2016-01-04 14:57:15.406835 ==>  TOTAL - 2015-06-19 - 4_month
# 2016-01-04 14:57:16.356227 ==>  TOTAL - 2015-06-19 - 5_month
# 2016-01-04 14:57:17.306170 ==>  TOTAL - 2015-06-19 - 6_month
# 2016-01-04 14:57:18.571916 ==>  TOTAL - 2015-06-19 - 7_month
# 2016-01-04 14:57:19.558691 ==>  TOTAL - 2015-06-19 - 8_month
# 2016-01-04 14:57:20.552091 ==>  TOTAL - 2015-06-19 - 9_month
# 2016-01-04 14:57:21.495621 ==>  TOTAL - 2015-06-19 - 10_month
# 2016-01-04 14:57:22.437182 ==>  TOTAL - 2015-06-19 - 11_month
# 2016-01-04 14:57:23.395931 ==>  TOTAL - 2015-06-19 - 12_month
# 2016-01-04 14:57:24.443876 ==>  TOTAL - 2015-06-19 - 13_month
# 2016-01-04 14:57:25.500086 ==>  TOTAL - 2015-06-19 - 14_month
# 2016-01-04 14:57:26.546470 ==>  TOTAL - 2015-07-19 - same_month
# 2016-01-04 14:57:28.157566 ==>  TOTAL - 2015-07-19 - 1_month
# 2016-01-04 14:57:29.785730 ==>  TOTAL - 2015-07-19 - 2_month
# 2016-01-04 14:57:31.084413 ==>  TOTAL - 2015-07-19 - 3_month
# 2016-01-04 14:57:32.178380 ==>  TOTAL - 2015-07-19 - 4_month
# 2016-01-04 14:57:33.139235 ==>  TOTAL - 2015-07-19 - 5_month
# 2016-01-04 14:57:34.101332 ==>  TOTAL - 2015-07-19 - 6_month
# 2016-01-04 14:57:35.049357 ==>  TOTAL - 2015-07-19 - 7_month
# 2016-01-04 14:57:36.017914 ==>  TOTAL - 2015-07-19 - 8_month
# 2016-01-04 14:57:37.023895 ==>  TOTAL - 2015-07-19 - 9_month
# 2016-01-04 14:57:38.011942 ==>  TOTAL - 2015-07-19 - 10_month
# 2016-01-04 14:57:39.035367 ==>  TOTAL - 2015-07-19 - 11_month
# 2016-01-04 14:57:40.043836 ==>  TOTAL - 2015-07-19 - 12_month
# 2016-01-04 14:57:41.040338 ==>  TOTAL - 2015-07-19 - 13_month
# 2016-01-04 14:57:41.986543 ==>  TOTAL - 2015-07-19 - 14_month
# 2016-01-04 14:57:42.930950 ==>  TOTAL - 2015-08-18 - same_month
# 2016-01-04 14:57:43.882367 ==>  TOTAL - 2015-08-18 - 1_month
# 2016-01-04 14:57:44.921877 ==>  TOTAL - 2015-08-18 - 2_month
# 2016-01-04 14:57:46.548828 ==>  TOTAL - 2015-08-18 - 3_month
# 2016-01-04 14:57:47.561858 ==>  TOTAL - 2015-08-18 - 4_month
# 2016-01-04 14:57:48.545917 ==>  TOTAL - 2015-08-18 - 5_month
# 2016-01-04 14:57:49.503818 ==>  TOTAL - 2015-08-18 - 6_month
# 2016-01-04 14:57:50.462389 ==>  TOTAL - 2015-08-18 - 7_month
# 2016-01-04 14:57:51.441054 ==>  TOTAL - 2015-08-18 - 8_month
# 2016-01-04 14:57:52.404545 ==>  TOTAL - 2015-08-18 - 9_month
# 2016-01-04 14:57:53.374783 ==>  TOTAL - 2015-08-18 - 10_month
# 2016-01-04 14:57:54.342207 ==>  TOTAL - 2015-08-18 - 11_month
# 2016-01-04 14:57:55.547201 ==>  TOTAL - 2015-08-18 - 12_month
# 2016-01-04 14:57:56.551434 ==>  TOTAL - 2015-08-18 - 13_month
# 2016-01-04 14:57:58.152414 ==>  TOTAL - 2015-08-18 - 14_month
# 2016-01-04 14:57:59.862014 ==>  TOTAL - 2015-09-17 - same_month
# 2016-01-04 14:58:01.155892 ==>  TOTAL - 2015-09-17 - 1_month
# 2016-01-04 14:58:02.081957 ==>  TOTAL - 2015-09-17 - 2_month
# 2016-01-04 14:58:03.272062 ==>  TOTAL - 2015-09-17 - 3_month
# 2016-01-04 14:58:04.277241 ==>  TOTAL - 2015-09-17 - 4_month
# 2016-01-04 14:58:05.286768 ==>  TOTAL - 2015-09-17 - 5_month
# 2016-01-04 14:58:06.258822 ==>  TOTAL - 2015-09-17 - 6_month
# 2016-01-04 14:58:07.268027 ==>  TOTAL - 2015-09-17 - 7_month
# 2016-01-04 14:58:08.427527 ==>  TOTAL - 2015-09-17 - 8_month
# 2016-01-04 14:58:09.616283 ==>  TOTAL - 2015-09-17 - 9_month
# 2016-01-04 14:58:10.628111 ==>  TOTAL - 2015-09-17 - 10_month
# 2016-01-04 14:58:11.569746 ==>  TOTAL - 2015-09-17 - 11_month
# 2016-01-04 14:58:12.565680 ==>  TOTAL - 2015-09-17 - 12_month
# 2016-01-04 14:58:13.540703 ==>  TOTAL - 2015-09-17 - 13_month
# 2016-01-04 14:58:14.528762 ==>  TOTAL - 2015-09-17 - 14_month
# 2016-01-04 14:58:15.454506 ==>  TOTAL - 2015-10-17 - same_month
# 2016-01-04 14:58:16.407321 ==>  TOTAL - 2015-10-17 - 1_month
# 2016-01-04 14:58:17.385811 ==>  TOTAL - 2015-10-17 - 2_month
# 2016-01-04 14:58:18.406859 ==>  TOTAL - 2015-10-17 - 3_month
# 2016-01-04 14:58:19.429189 ==>  TOTAL - 2015-10-17 - 4_month
# 2016-01-04 14:58:20.436679 ==>  TOTAL - 2015-10-17 - 5_month
# 2016-01-04 14:58:21.382104 ==>  TOTAL - 2015-10-17 - 6_month
# 2016-01-04 14:58:22.395040 ==>  TOTAL - 2015-10-17 - 7_month
# 2016-01-04 14:58:23.388160 ==>  TOTAL - 2015-10-17 - 8_month
# 2016-01-04 14:58:24.381217 ==>  TOTAL - 2015-10-17 - 9_month
# 2016-01-04 14:58:25.357306 ==>  TOTAL - 2015-10-17 - 10_month
# 2016-01-04 14:58:26.363858 ==>  TOTAL - 2015-10-17 - 11_month
# 2016-01-04 14:58:27.375946 ==>  TOTAL - 2015-10-17 - 12_month
# 2016-01-04 14:58:28.446206 ==>  TOTAL - 2015-10-17 - 13_month
# 2016-01-04 14:58:29.421370 ==>  TOTAL - 2015-10-17 - 14_month
# 2016-01-04 14:58:30.451679 ==>  TOTAL - 2015-11-16 - same_month
# 2016-01-04 14:58:31.593380 ==>  TOTAL - 2015-11-16 - 1_month
# 2016-01-04 14:58:32.788334 ==>  TOTAL - 2015-11-16 - 2_month
# 2016-01-04 14:58:33.779543 ==>  TOTAL - 2015-11-16 - 3_month
# 2016-01-04 14:58:34.771262 ==>  TOTAL - 2015-11-16 - 4_month
# 2016-01-04 14:58:35.731325 ==>  TOTAL - 2015-11-16 - 5_month
# 2016-01-04 14:58:36.979348 ==>  TOTAL - 2015-11-16 - 6_month
# 2016-01-04 14:58:37.990732 ==>  TOTAL - 2015-11-16 - 7_month
# 2016-01-04 14:58:39.056031 ==>  TOTAL - 2015-11-16 - 8_month
# 2016-01-04 14:58:40.140444 ==>  TOTAL - 2015-11-16 - 9_month
# 2016-01-04 14:58:41.136398 ==>  TOTAL - 2015-11-16 - 10_month
# 2016-01-04 14:58:42.108263 ==>  TOTAL - 2015-11-16 - 11_month
# 2016-01-04 14:58:43.049475 ==>  TOTAL - 2015-11-16 - 12_month
# 2016-01-04 14:58:43.980762 ==>  TOTAL - 2015-11-16 - 13_month
# 2016-01-04 14:58:44.910695 ==>  TOTAL - 2015-11-16 - 14_month
# 2016-01-04 14:58:45.843292 ==>  TOTAL - 2015-12-16 - same_month
# 2016-01-04 14:58:46.780513 ==>  TOTAL - 2015-12-16 - 1_month
# 2016-01-04 14:58:47.742647 ==>  TOTAL - 2015-12-16 - 2_month
# 2016-01-04 14:58:48.850017 ==>  TOTAL - 2015-12-16 - 3_month
# 2016-01-04 14:58:49.936485 ==>  TOTAL - 2015-12-16 - 4_month
# 2016-01-04 14:58:50.912956 ==>  TOTAL - 2015-12-16 - 5_month
# 2016-01-04 14:58:51.875231 ==>  TOTAL - 2015-12-16 - 6_month
# 2016-01-04 14:58:52.818427 ==>  TOTAL - 2015-12-16 - 7_month
# 2016-01-04 14:58:53.805757 ==>  TOTAL - 2015-12-16 - 8_month
# 2016-01-04 14:58:54.754298 ==>  TOTAL - 2015-12-16 - 9_month
# 2016-01-04 14:58:56.031270 ==>  TOTAL - 2015-12-16 - 10_month
# 2016-01-04 14:58:57.148546 ==>  TOTAL - 2015-12-16 - 11_month
# 2016-01-04 14:58:58.566991 ==>  TOTAL - 2015-12-16 - 12_month
# 2016-01-04 14:59:00.125437 ==>  TOTAL - 2015-12-16 - 13_month
# 2016-01-04 14:59:01.295525 ==>  TOTAL - 2015-12-16 - 14_month
# 2016-01-04 14:59:02.278001 ==> Argentina + Uruguay - 2014-10-22 - same_month
# 2016-01-04 14:59:03.235729 ==> Argentina + Uruguay - 2014-10-22 - 1_month
# 2016-01-04 14:59:04.243754 ==> Argentina + Uruguay - 2014-10-22 - 2_month
# 2016-01-04 14:59:05.267339 ==> Argentina + Uruguay - 2014-10-22 - 3_month
# 2016-01-04 14:59:06.365118 ==> Argentina + Uruguay - 2014-10-22 - 4_month
# 2016-01-04 14:59:07.371245 ==> Argentina + Uruguay - 2014-10-22 - 5_month
# 2016-01-04 14:59:08.374299 ==> Argentina + Uruguay - 2014-10-22 - 6_month
# 2016-01-04 14:59:09.346885 ==> Argentina + Uruguay - 2014-10-22 - 7_month
# 2016-01-04 14:59:10.313363 ==> Argentina + Uruguay - 2014-10-22 - 8_month
# 2016-01-04 14:59:11.255437 ==> Argentina + Uruguay - 2014-10-22 - 9_month
# 2016-01-04 14:59:12.193995 ==> Argentina + Uruguay - 2014-10-22 - 10_month
# 2016-01-04 14:59:13.140892 ==> Argentina + Uruguay - 2014-10-22 - 11_month
# 2016-01-04 14:59:14.252271 ==> Argentina + Uruguay - 2014-10-22 - 12_month
# 2016-01-04 14:59:15.261373 ==> Argentina + Uruguay - 2014-10-22 - 13_month
# 2016-01-04 14:59:16.271712 ==> Argentina + Uruguay - 2014-10-22 - 14_month
# 2016-01-04 14:59:17.289621 ==> Argentina + Uruguay - 2014-11-21 - same_month
# 2016-01-04 14:59:18.542755 ==> Argentina + Uruguay - 2014-11-21 - 1_month
# 2016-01-04 14:59:19.549273 ==> Argentina + Uruguay - 2014-11-21 - 2_month
# 2016-01-04 14:59:20.542366 ==> Argentina + Uruguay - 2014-11-21 - 3_month
# 2016-01-04 14:59:21.472091 ==> Argentina + Uruguay - 2014-11-21 - 4_month
# 2016-01-04 14:59:22.408260 ==> Argentina + Uruguay - 2014-11-21 - 5_month
# 2016-01-04 14:59:23.345703 ==> Argentina + Uruguay - 2014-11-21 - 6_month
# 2016-01-04 14:59:24.558385 ==> Argentina + Uruguay - 2014-11-21 - 7_month
# 2016-01-04 14:59:25.551927 ==> Argentina + Uruguay - 2014-11-21 - 8_month
# 2016-01-04 14:59:26.846891 ==> Argentina + Uruguay - 2014-11-21 - 9_month
# 2016-01-04 14:59:27.944033 ==> Argentina + Uruguay - 2014-11-21 - 10_month
# 2016-01-04 14:59:29.023867 ==> Argentina + Uruguay - 2014-11-21 - 11_month
# 2016-01-04 14:59:30.069985 ==> Argentina + Uruguay - 2014-11-21 - 12_month
# 2016-01-04 14:59:31.097561 ==> Argentina + Uruguay - 2014-11-21 - 13_month
# 2016-01-04 14:59:32.283962 ==> Argentina + Uruguay - 2014-11-21 - 14_month
# 2016-01-04 14:59:33.466495 ==> Argentina + Uruguay - 2014-12-21 - same_month
# 2016-01-04 14:59:34.536053 ==> Argentina + Uruguay - 2014-12-21 - 1_month
# 2016-01-04 14:59:35.943307 ==> Argentina + Uruguay - 2014-12-21 - 2_month
# 2016-01-04 14:59:37.136021 ==> Argentina + Uruguay - 2014-12-21 - 3_month
# 2016-01-04 14:59:38.303297 ==> Argentina + Uruguay - 2014-12-21 - 4_month
# 2016-01-04 14:59:39.533395 ==> Argentina + Uruguay - 2014-12-21 - 5_month
# 2016-01-04 14:59:40.495543 ==> Argentina + Uruguay - 2014-12-21 - 6_month
# 2016-01-04 14:59:41.809374 ==> Argentina + Uruguay - 2014-12-21 - 7_month
# 2016-01-04 14:59:43.043405 ==> Argentina + Uruguay - 2014-12-21 - 8_month
# 2016-01-04 14:59:44.065249 ==> Argentina + Uruguay - 2014-12-21 - 9_month
# 2016-01-04 14:59:45.047190 ==> Argentina + Uruguay - 2014-12-21 - 10_month
# 2016-01-04 14:59:46.002955 ==> Argentina + Uruguay - 2014-12-21 - 11_month
# 2016-01-04 14:59:46.948438 ==> Argentina + Uruguay - 2014-12-21 - 12_month
# 2016-01-04 14:59:47.893050 ==> Argentina + Uruguay - 2014-12-21 - 13_month
# 2016-01-04 14:59:48.836619 ==> Argentina + Uruguay - 2014-12-21 - 14_month
# 2016-01-04 14:59:49.772508 ==> Argentina + Uruguay - 2015-01-20 - same_month
# 2016-01-04 14:59:50.708304 ==> Argentina + Uruguay - 2015-01-20 - 1_month
# 2016-01-04 14:59:51.717428 ==> Argentina + Uruguay - 2015-01-20 - 2_month
# 2016-01-04 14:59:52.707941 ==> Argentina + Uruguay - 2015-01-20 - 3_month
# 2016-01-04 14:59:53.687874 ==> Argentina + Uruguay - 2015-01-20 - 4_month
# 2016-01-04 14:59:54.628125 ==> Argentina + Uruguay - 2015-01-20 - 5_month
# 2016-01-04 14:59:55.629464 ==> Argentina + Uruguay - 2015-01-20 - 6_month
# 2016-01-04 14:59:56.720157 ==> Argentina + Uruguay - 2015-01-20 - 7_month
# 2016-01-04 14:59:57.824661 ==> Argentina + Uruguay - 2015-01-20 - 8_month
# 2016-01-04 14:59:58.837863 ==> Argentina + Uruguay - 2015-01-20 - 9_month
# 2016-01-04 14:59:59.853705 ==> Argentina + Uruguay - 2015-01-20 - 10_month
# 2016-01-04 15:00:00.913472 ==> Argentina + Uruguay - 2015-01-20 - 11_month
# 2016-01-04 15:00:01.914554 ==> Argentina + Uruguay - 2015-01-20 - 12_month
# 2016-01-04 15:00:02.889350 ==> Argentina + Uruguay - 2015-01-20 - 13_month
# 2016-01-04 15:00:03.943215 ==> Argentina + Uruguay - 2015-01-20 - 14_month
# 2016-01-04 15:00:05.085634 ==> Argentina + Uruguay - 2015-02-19 - same_month
# 2016-01-04 15:00:06.226072 ==> Argentina + Uruguay - 2015-02-19 - 1_month
# 2016-01-04 15:00:07.272218 ==> Argentina + Uruguay - 2015-02-19 - 2_month
# 2016-01-04 15:00:08.300020 ==> Argentina + Uruguay - 2015-02-19 - 3_month
# 2016-01-04 15:00:09.333247 ==> Argentina + Uruguay - 2015-02-19 - 4_month
# 2016-01-04 15:00:10.378063 ==> Argentina + Uruguay - 2015-02-19 - 5_month
# 2016-01-04 15:00:11.392097 ==> Argentina + Uruguay - 2015-02-19 - 6_month
# 2016-01-04 15:00:12.332577 ==> Argentina + Uruguay - 2015-02-19 - 7_month
# 2016-01-04 15:00:13.268943 ==> Argentina + Uruguay - 2015-02-19 - 8_month
# 2016-01-04 15:00:14.200529 ==> Argentina + Uruguay - 2015-02-19 - 9_month
# 2016-01-04 15:00:15.258598 ==> Argentina + Uruguay - 2015-02-19 - 10_month
# 2016-01-04 15:00:16.266255 ==> Argentina + Uruguay - 2015-02-19 - 11_month
# 2016-01-04 15:00:17.252923 ==> Argentina + Uruguay - 2015-02-19 - 12_month
# 2016-01-04 15:00:18.466795 ==> Argentina + Uruguay - 2015-02-19 - 13_month
# 2016-01-04 15:00:19.448260 ==> Argentina + Uruguay - 2015-02-19 - 14_month
# 2016-01-04 15:00:20.832477 ==> Argentina + Uruguay - 2015-03-21 - same_month
# 2016-01-04 15:00:21.874813 ==> Argentina + Uruguay - 2015-03-21 - 1_month
# 2016-01-04 15:00:23.020794 ==> Argentina + Uruguay - 2015-03-21 - 2_month
# 2016-01-04 15:00:24.031641 ==> Argentina + Uruguay - 2015-03-21 - 3_month
# 2016-01-04 15:00:25.219338 ==> Argentina + Uruguay - 2015-03-21 - 4_month
# 2016-01-04 15:00:26.181378 ==> Argentina + Uruguay - 2015-03-21 - 5_month
# 2016-01-04 15:00:27.212908 ==> Argentina + Uruguay - 2015-03-21 - 6_month
# 2016-01-04 15:00:28.960910 ==> Argentina + Uruguay - 2015-03-21 - 7_month
# 2016-01-04 15:00:30.393241 ==> Argentina + Uruguay - 2015-03-21 - 8_month
# 2016-01-04 15:00:31.572304 ==> Argentina + Uruguay - 2015-03-21 - 9_month
# 2016-01-04 15:00:32.672333 ==> Argentina + Uruguay - 2015-03-21 - 10_month
# 2016-01-04 15:00:33.717047 ==> Argentina + Uruguay - 2015-03-21 - 11_month
# 2016-01-04 15:00:34.687253 ==> Argentina + Uruguay - 2015-03-21 - 12_month
# 2016-01-04 15:00:35.641328 ==> Argentina + Uruguay - 2015-03-21 - 13_month
# 2016-01-04 15:00:36.592297 ==> Argentina + Uruguay - 2015-03-21 - 14_month
# 2016-01-04 15:00:37.609085 ==> Argentina + Uruguay - 2015-04-20 - same_month
# 2016-01-04 15:00:38.590650 ==> Argentina + Uruguay - 2015-04-20 - 1_month
# 2016-01-04 15:00:39.595105 ==> Argentina + Uruguay - 2015-04-20 - 2_month
# 2016-01-04 15:00:40.561300 ==> Argentina + Uruguay - 2015-04-20 - 3_month
# 2016-01-04 15:00:41.506067 ==> Argentina + Uruguay - 2015-04-20 - 4_month
# 2016-01-04 15:00:42.440058 ==> Argentina + Uruguay - 2015-04-20 - 5_month
# 2016-01-04 15:00:43.371757 ==> Argentina + Uruguay - 2015-04-20 - 6_month
# 2016-01-04 15:00:44.321829 ==> Argentina + Uruguay - 2015-04-20 - 7_month
# 2016-01-04 15:00:45.318070 ==> Argentina + Uruguay - 2015-04-20 - 8_month
# 2016-01-04 15:00:46.339172 ==> Argentina + Uruguay - 2015-04-20 - 9_month
# 2016-01-04 15:00:47.351898 ==> Argentina + Uruguay - 2015-04-20 - 10_month
# 2016-01-04 15:00:48.307764 ==> Argentina + Uruguay - 2015-04-20 - 11_month
# 2016-01-04 15:00:49.254419 ==> Argentina + Uruguay - 2015-04-20 - 12_month
# 2016-01-04 15:00:50.193982 ==> Argentina + Uruguay - 2015-04-20 - 13_month
# 2016-01-04 15:00:51.134188 ==> Argentina + Uruguay - 2015-04-20 - 14_month
# 2016-01-04 15:00:52.073438 ==> Argentina + Uruguay - 2015-05-20 - same_month
# 2016-01-04 15:00:53.016233 ==> Argentina + Uruguay - 2015-05-20 - 1_month
# 2016-01-04 15:00:53.961097 ==> Argentina + Uruguay - 2015-05-20 - 2_month
# 2016-01-04 15:00:54.915696 ==> Argentina + Uruguay - 2015-05-20 - 3_month
# 2016-01-04 15:00:55.934058 ==> Argentina + Uruguay - 2015-05-20 - 4_month
# 2016-01-04 15:00:57.206634 ==> Argentina + Uruguay - 2015-05-20 - 5_month
# 2016-01-04 15:00:58.939702 ==> Argentina + Uruguay - 2015-05-20 - 6_month
# 2016-01-04 15:01:00.599760 ==> Argentina + Uruguay - 2015-05-20 - 7_month
# 2016-01-04 15:01:01.571411 ==> Argentina + Uruguay - 2015-05-20 - 8_month
# 2016-01-04 15:01:02.511319 ==> Argentina + Uruguay - 2015-05-20 - 9_month
# 2016-01-04 15:01:03.468168 ==> Argentina + Uruguay - 2015-05-20 - 10_month
# 2016-01-04 15:01:04.614064 ==> Argentina + Uruguay - 2015-05-20 - 11_month
# 2016-01-04 15:01:06.143634 ==> Argentina + Uruguay - 2015-05-20 - 12_month
# 2016-01-04 15:01:07.235655 ==> Argentina + Uruguay - 2015-05-20 - 13_month
# 2016-01-04 15:01:08.520745 ==> Argentina + Uruguay - 2015-05-20 - 14_month
# 2016-01-04 15:01:09.725889 ==> Argentina + Uruguay - 2015-06-19 - same_month
# 2016-01-04 15:01:10.830427 ==> Argentina + Uruguay - 2015-06-19 - 1_month
# 2016-01-04 15:01:11.851024 ==> Argentina + Uruguay - 2015-06-19 - 2_month
# 2016-01-04 15:01:13.026787 ==> Argentina + Uruguay - 2015-06-19 - 3_month
# 2016-01-04 15:01:14.326825 ==> Argentina + Uruguay - 2015-06-19 - 4_month
# 2016-01-04 15:01:15.363078 ==> Argentina + Uruguay - 2015-06-19 - 5_month
# 2016-01-04 15:01:16.331867 ==> Argentina + Uruguay - 2015-06-19 - 6_month
# 2016-01-04 15:01:17.292442 ==> Argentina + Uruguay - 2015-06-19 - 7_month
# 2016-01-04 15:01:18.259030 ==> Argentina + Uruguay - 2015-06-19 - 8_month
# 2016-01-04 15:01:19.219845 ==> Argentina + Uruguay - 2015-06-19 - 9_month
# 2016-01-04 15:01:20.179261 ==> Argentina + Uruguay - 2015-06-19 - 10_month
# 2016-01-04 15:01:21.191328 ==> Argentina + Uruguay - 2015-06-19 - 11_month
# 2016-01-04 15:01:22.219300 ==> Argentina + Uruguay - 2015-06-19 - 12_month
# 2016-01-04 15:01:23.260126 ==> Argentina + Uruguay - 2015-06-19 - 13_month
# 2016-01-04 15:01:24.250891 ==> Argentina + Uruguay - 2015-06-19 - 14_month
# 2016-01-04 15:01:25.234619 ==> Argentina + Uruguay - 2015-07-19 - same_month
# 2016-01-04 15:01:26.252964 ==> Argentina + Uruguay - 2015-07-19 - 1_month
# 2016-01-04 15:01:27.424022 ==> Argentina + Uruguay - 2015-07-19 - 2_month
# 2016-01-04 15:01:28.797828 ==> Argentina + Uruguay - 2015-07-19 - 3_month
# 2016-01-04 15:01:29.880393 ==> Argentina + Uruguay - 2015-07-19 - 4_month
# 2016-01-04 15:01:31.010596 ==> Argentina + Uruguay - 2015-07-19 - 5_month
# 2016-01-04 15:01:32.298229 ==> Argentina + Uruguay - 2015-07-19 - 6_month
# 2016-01-04 15:01:33.642969 ==> Argentina + Uruguay - 2015-07-19 - 7_month
# 2016-01-04 15:01:34.670691 ==> Argentina + Uruguay - 2015-07-19 - 8_month
# 2016-01-04 15:01:35.648201 ==> Argentina + Uruguay - 2015-07-19 - 9_month
# 2016-01-04 15:01:37.015936 ==> Argentina + Uruguay - 2015-07-19 - 10_month
# 2016-01-04 15:01:38.395537 ==> Argentina + Uruguay - 2015-07-19 - 11_month
# 2016-01-04 15:01:39.515975 ==> Argentina + Uruguay - 2015-07-19 - 12_month
# 2016-01-04 15:01:40.543934 ==> Argentina + Uruguay - 2015-07-19 - 13_month
# 2016-01-04 15:01:41.541509 ==> Argentina + Uruguay - 2015-07-19 - 14_month
# 2016-01-04 15:01:42.487282 ==> Argentina + Uruguay - 2015-08-18 - same_month
# 2016-01-04 15:01:43.441561 ==> Argentina + Uruguay - 2015-08-18 - 1_month
# 2016-01-04 15:01:44.389298 ==> Argentina + Uruguay - 2015-08-18 - 2_month
# 2016-01-04 15:01:45.371876 ==> Argentina + Uruguay - 2015-08-18 - 3_month
# 2016-01-04 15:01:46.326988 ==> Argentina + Uruguay - 2015-08-18 - 4_month
# 2016-01-04 15:01:47.259417 ==> Argentina + Uruguay - 2015-08-18 - 5_month
# 2016-01-04 15:01:48.254755 ==> Argentina + Uruguay - 2015-08-18 - 6_month
# 2016-01-04 15:01:49.985051 ==> Argentina + Uruguay - 2015-08-18 - 7_month
# 2016-01-04 15:01:51.567551 ==> Argentina + Uruguay - 2015-08-18 - 8_month
# 2016-01-04 15:01:52.662245 ==> Argentina + Uruguay - 2015-08-18 - 9_month
# 2016-01-04 15:01:53.630900 ==> Argentina + Uruguay - 2015-08-18 - 10_month
# 2016-01-04 15:01:54.596425 ==> Argentina + Uruguay - 2015-08-18 - 11_month
# 2016-01-04 15:01:55.723971 ==> Argentina + Uruguay - 2015-08-18 - 12_month
# 2016-01-04 15:01:56.822414 ==> Argentina + Uruguay - 2015-08-18 - 13_month
# 2016-01-04 15:01:58.497831 ==> Argentina + Uruguay - 2015-08-18 - 14_month
# 2016-01-04 15:01:59.497700 ==> Argentina + Uruguay - 2015-09-17 - same_month
# 2016-01-04 15:02:00.743735 ==> Argentina + Uruguay - 2015-09-17 - 1_month
# 2016-01-04 15:02:01.779778 ==> Argentina + Uruguay - 2015-09-17 - 2_month
# 2016-01-04 15:02:02.806591 ==> Argentina + Uruguay - 2015-09-17 - 3_month
# 2016-01-04 15:02:03.790625 ==> Argentina + Uruguay - 2015-09-17 - 4_month
# 2016-01-04 15:02:04.800439 ==> Argentina + Uruguay - 2015-09-17 - 5_month
# 2016-01-04 15:02:05.767974 ==> Argentina + Uruguay - 2015-09-17 - 6_month
# 2016-01-04 15:02:07.186120 ==> Argentina + Uruguay - 2015-09-17 - 7_month
# 2016-01-04 15:02:08.813985 ==> Argentina + Uruguay - 2015-09-17 - 8_month
# 2016-01-04 15:02:10.467857 ==> Argentina + Uruguay - 2015-09-17 - 9_month
# 2016-01-04 15:02:12.227052 ==> Argentina + Uruguay - 2015-09-17 - 10_month
# 2016-01-04 15:02:13.475687 ==> Argentina + Uruguay - 2015-09-17 - 11_month
# 2016-01-04 15:02:14.602266 ==> Argentina + Uruguay - 2015-09-17 - 12_month
# 2016-01-04 15:02:15.625522 ==> Argentina + Uruguay - 2015-09-17 - 13_month
# 2016-01-04 15:02:16.637163 ==> Argentina + Uruguay - 2015-09-17 - 14_month
# 2016-01-04 15:02:17.609548 ==> Argentina + Uruguay - 2015-10-17 - same_month
# 2016-01-04 15:02:18.655363 ==> Argentina + Uruguay - 2015-10-17 - 1_month
# 2016-01-04 15:02:19.768011 ==> Argentina + Uruguay - 2015-10-17 - 2_month
# 2016-01-04 15:02:20.988049 ==> Argentina + Uruguay - 2015-10-17 - 3_month
# 2016-01-04 15:02:22.137836 ==> Argentina + Uruguay - 2015-10-17 - 4_month
# 2016-01-04 15:02:23.638348 ==> Argentina + Uruguay - 2015-10-17 - 5_month
# 2016-01-04 15:02:24.901444 ==> Argentina + Uruguay - 2015-10-17 - 6_month
# 2016-01-04 15:02:25.936961 ==> Argentina + Uruguay - 2015-10-17 - 7_month
# 2016-01-04 15:02:26.969388 ==> Argentina + Uruguay - 2015-10-17 - 8_month
# 2016-01-04 15:02:27.991130 ==> Argentina + Uruguay - 2015-10-17 - 9_month
# 2016-01-04 15:02:29.019878 ==> Argentina + Uruguay - 2015-10-17 - 10_month
# 2016-01-04 15:02:30.104843 ==> Argentina + Uruguay - 2015-10-17 - 11_month
# 2016-01-04 15:02:31.376316 ==> Argentina + Uruguay - 2015-10-17 - 12_month
# 2016-01-04 15:02:32.535383 ==> Argentina + Uruguay - 2015-10-17 - 13_month
# 2016-01-04 15:02:33.807659 ==> Argentina + Uruguay - 2015-10-17 - 14_month
# 2016-01-04 15:02:35.000905 ==> Argentina + Uruguay - 2015-11-16 - same_month
# 2016-01-04 15:02:36.111119 ==> Argentina + Uruguay - 2015-11-16 - 1_month
# 2016-01-04 15:02:37.381698 ==> Argentina + Uruguay - 2015-11-16 - 2_month
# 2016-01-04 15:02:38.846748 ==> Argentina + Uruguay - 2015-11-16 - 3_month
# 2016-01-04 15:02:40.238845 ==> Argentina + Uruguay - 2015-11-16 - 4_month
# 2016-01-04 15:02:41.860968 ==> Argentina + Uruguay - 2015-11-16 - 5_month
# 2016-01-04 15:02:43.224835 ==> Argentina + Uruguay - 2015-11-16 - 6_month
# 2016-01-04 15:02:44.348506 ==> Argentina + Uruguay - 2015-11-16 - 7_month
# 2016-01-04 15:02:45.898866 ==> Argentina + Uruguay - 2015-11-16 - 8_month
# 2016-01-04 15:02:47.326797 ==> Argentina + Uruguay - 2015-11-16 - 9_month
# 2016-01-04 15:02:48.700990 ==> Argentina + Uruguay - 2015-11-16 - 10_month
# 2016-01-04 15:02:50.252104 ==> Argentina + Uruguay - 2015-11-16 - 11_month
# 2016-01-04 15:02:51.826613 ==> Argentina + Uruguay - 2015-11-16 - 12_month
# 2016-01-04 15:02:52.900917 ==> Argentina + Uruguay - 2015-11-16 - 13_month
# 2016-01-04 15:02:54.076315 ==> Argentina + Uruguay - 2015-11-16 - 14_month
# 2016-01-04 15:02:55.489766 ==> Argentina + Uruguay - 2015-12-16 - same_month
# 2016-01-04 15:02:56.819987 ==> Argentina + Uruguay - 2015-12-16 - 1_month
# 2016-01-04 15:02:58.295267 ==> Argentina + Uruguay - 2015-12-16 - 2_month
# 2016-01-04 15:02:59.591995 ==> Argentina + Uruguay - 2015-12-16 - 3_month
# 2016-01-04 15:03:00.610826 ==> Argentina + Uruguay - 2015-12-16 - 4_month
# 2016-01-04 15:03:02.230771 ==> Argentina + Uruguay - 2015-12-16 - 5_month
# 2016-01-04 15:03:03.303712 ==> Argentina + Uruguay - 2015-12-16 - 6_month
# 2016-01-04 15:03:04.378816 ==> Argentina + Uruguay - 2015-12-16 - 7_month
# 2016-01-04 15:03:05.329889 ==> Argentina + Uruguay - 2015-12-16 - 8_month
# 2016-01-04 15:03:06.376217 ==> Argentina + Uruguay - 2015-12-16 - 9_month
# 2016-01-04 15:03:08.111331 ==> Argentina + Uruguay - 2015-12-16 - 10_month
# 2016-01-04 15:03:09.862786 ==> Argentina + Uruguay - 2015-12-16 - 11_month
# 2016-01-04 15:03:11.592965 ==> Argentina + Uruguay - 2015-12-16 - 12_month
# 2016-01-04 15:03:13.070173 ==> Argentina + Uruguay - 2015-12-16 - 13_month
# 2016-01-04 15:03:14.456544 ==> Argentina + Uruguay - 2015-12-16 - 14_month
# 2016-01-04 15:03:15.590159 ==> Brasil - 2014-10-22 - same_month
# 2016-01-04 15:03:16.701002 ==> Brasil - 2014-10-22 - 1_month
# 2016-01-04 15:03:18.033421 ==> Brasil - 2014-10-22 - 2_month
# 2016-01-04 15:03:19.754750 ==> Brasil - 2014-10-22 - 3_month
# 2016-01-04 15:03:21.146387 ==> Brasil - 2014-10-22 - 4_month
# 2016-01-04 15:03:22.871838 ==> Brasil - 2014-10-22 - 5_month
# 2016-01-04 15:03:24.580561 ==> Brasil - 2014-10-22 - 6_month
# 2016-01-04 15:03:25.773915 ==> Brasil - 2014-10-22 - 7_month
# 2016-01-04 15:03:26.946505 ==> Brasil - 2014-10-22 - 8_month
# 2016-01-04 15:03:28.321563 ==> Brasil - 2014-10-22 - 9_month
# 2016-01-04 15:03:29.408116 ==> Brasil - 2014-10-22 - 10_month
# 2016-01-04 15:03:30.483566 ==> Brasil - 2014-10-22 - 11_month
# 2016-01-04 15:03:31.530909 ==> Brasil - 2014-10-22 - 12_month
# 2016-01-04 15:03:32.688652 ==> Brasil - 2014-10-22 - 13_month
# 2016-01-04 15:03:34.422387 ==> Brasil - 2014-10-22 - 14_month
# 2016-01-04 15:03:35.906076 ==> Brasil - 2014-11-21 - same_month
# 2016-01-04 15:03:37.214245 ==> Brasil - 2014-11-21 - 1_month
# 2016-01-04 15:03:38.556603 ==> Brasil - 2014-11-21 - 2_month
# 2016-01-04 15:03:39.791190 ==> Brasil - 2014-11-21 - 3_month
# 2016-01-04 15:03:40.816930 ==> Brasil - 2014-11-21 - 4_month
# 2016-01-04 15:03:41.865217 ==> Brasil - 2014-11-21 - 5_month
# 2016-01-04 15:03:42.826054 ==> Brasil - 2014-11-21 - 6_month
# 2016-01-04 15:03:43.806392 ==> Brasil - 2014-11-21 - 7_month
# 2016-01-04 15:03:44.784736 ==> Brasil - 2014-11-21 - 8_month
# 2016-01-04 15:03:45.788407 ==> Brasil - 2014-11-21 - 9_month
# 2016-01-04 15:03:46.846901 ==> Brasil - 2014-11-21 - 10_month
# 2016-01-04 15:03:48.333363 ==> Brasil - 2014-11-21 - 11_month
# 2016-01-04 15:03:50.114985 ==> Brasil - 2014-11-21 - 12_month
# 2016-01-04 15:03:51.617757 ==> Brasil - 2014-11-21 - 13_month
# 2016-01-04 15:03:52.576560 ==> Brasil - 2014-11-21 - 14_month
# 2016-01-04 15:03:53.550273 ==> Brasil - 2014-12-21 - same_month
# 2016-01-04 15:03:54.538095 ==> Brasil - 2014-12-21 - 1_month
# 2016-01-04 15:03:55.581796 ==> Brasil - 2014-12-21 - 2_month
# 2016-01-04 15:03:56.651094 ==> Brasil - 2014-12-21 - 3_month
# 2016-01-04 15:03:57.762685 ==> Brasil - 2014-12-21 - 4_month
# 2016-01-04 15:03:58.832806 ==> Brasil - 2014-12-21 - 5_month
# 2016-01-04 15:03:59.856639 ==> Brasil - 2014-12-21 - 6_month
# 2016-01-04 15:04:00.863384 ==> Brasil - 2014-12-21 - 7_month
# 2016-01-04 15:04:01.840329 ==> Brasil - 2014-12-21 - 8_month
# 2016-01-04 15:04:02.801192 ==> Brasil - 2014-12-21 - 9_month
# 2016-01-04 15:04:03.790318 ==> Brasil - 2014-12-21 - 10_month
# 2016-01-04 15:04:05.303316 ==> Brasil - 2014-12-21 - 11_month
# 2016-01-04 15:04:07.079232 ==> Brasil - 2014-12-21 - 12_month
# 2016-01-04 15:04:08.348123 ==> Brasil - 2014-12-21 - 13_month
# 2016-01-04 15:04:09.507504 ==> Brasil - 2014-12-21 - 14_month
# 2016-01-04 15:04:11.010135 ==> Brasil - 2015-01-20 - same_month
# 2016-01-04 15:04:12.600907 ==> Brasil - 2015-01-20 - 1_month
# 2016-01-04 15:04:13.642377 ==> Brasil - 2015-01-20 - 2_month
# 2016-01-04 15:04:14.777450 ==> Brasil - 2015-01-20 - 3_month
# 2016-01-04 15:04:16.246458 ==> Brasil - 2015-01-20 - 4_month
# 2016-01-04 15:04:18.002198 ==> Brasil - 2015-01-20 - 5_month
# 2016-01-04 15:04:19.060189 ==> Brasil - 2015-01-20 - 6_month
# 2016-01-04 15:04:20.115004 ==> Brasil - 2015-01-20 - 7_month
# 2016-01-04 15:04:21.118918 ==> Brasil - 2015-01-20 - 8_month
# 2016-01-04 15:04:22.102004 ==> Brasil - 2015-01-20 - 9_month
# 2016-01-04 15:04:23.324353 ==> Brasil - 2015-01-20 - 10_month
# 2016-01-04 15:04:24.436333 ==> Brasil - 2015-01-20 - 11_month
# 2016-01-04 15:04:25.440130 ==> Brasil - 2015-01-20 - 12_month
# 2016-01-04 15:04:26.410545 ==> Brasil - 2015-01-20 - 13_month
# 2016-01-04 15:04:27.428193 ==> Brasil - 2015-01-20 - 14_month
# 2016-01-04 15:04:28.468561 ==> Brasil - 2015-02-19 - same_month
# 2016-01-04 15:04:29.503662 ==> Brasil - 2015-02-19 - 1_month
# 2016-01-04 15:04:30.499038 ==> Brasil - 2015-02-19 - 2_month
# 2016-01-04 15:04:31.482043 ==> Brasil - 2015-02-19 - 3_month
# 2016-01-04 15:04:32.495523 ==> Brasil - 2015-02-19 - 4_month
# 2016-01-04 15:04:33.528861 ==> Brasil - 2015-02-19 - 5_month
# 2016-01-04 15:04:34.589225 ==> Brasil - 2015-02-19 - 6_month
# 2016-01-04 15:04:35.575368 ==> Brasil - 2015-02-19 - 7_month
# 2016-01-04 15:04:36.568231 ==> Brasil - 2015-02-19 - 8_month
# 2016-01-04 15:04:37.651128 ==> Brasil - 2015-02-19 - 9_month
# 2016-01-04 15:04:38.963479 ==> Brasil - 2015-02-19 - 10_month
# 2016-01-04 15:04:40.144131 ==> Brasil - 2015-02-19 - 11_month
# 2016-01-04 15:04:41.335871 ==> Brasil - 2015-02-19 - 12_month
# 2016-01-04 15:04:42.400444 ==> Brasil - 2015-02-19 - 13_month
# 2016-01-04 15:04:43.438170 ==> Brasil - 2015-02-19 - 14_month
# 2016-01-04 15:04:44.456214 ==> Brasil - 2015-03-21 - same_month
# 2016-01-04 15:04:45.462309 ==> Brasil - 2015-03-21 - 1_month
# 2016-01-04 15:04:46.447146 ==> Brasil - 2015-03-21 - 2_month
# 2016-01-04 15:04:47.442954 ==> Brasil - 2015-03-21 - 3_month
# 2016-01-04 15:04:48.433203 ==> Brasil - 2015-03-21 - 4_month
# 2016-01-04 15:04:49.840750 ==> Brasil - 2015-03-21 - 5_month
# 2016-01-04 15:04:51.632462 ==> Brasil - 2015-03-21 - 6_month
# 2016-01-04 15:04:52.789385 ==> Brasil - 2015-03-21 - 7_month
# 2016-01-04 15:04:53.796051 ==> Brasil - 2015-03-21 - 8_month
# 2016-01-04 15:04:54.773573 ==> Brasil - 2015-03-21 - 9_month
# 2016-01-04 15:04:55.843628 ==> Brasil - 2015-03-21 - 10_month
# 2016-01-04 15:04:56.886279 ==> Brasil - 2015-03-21 - 11_month
# 2016-01-04 15:04:57.971669 ==> Brasil - 2015-03-21 - 12_month
# 2016-01-04 15:04:59.019873 ==> Brasil - 2015-03-21 - 13_month
# 2016-01-04 15:05:00.059708 ==> Brasil - 2015-03-21 - 14_month
# 2016-01-04 15:05:01.038955 ==> Brasil - 2015-04-20 - same_month
# 2016-01-04 15:05:02.021050 ==> Brasil - 2015-04-20 - 1_month
# 2016-01-04 15:05:03.004515 ==> Brasil - 2015-04-20 - 2_month
# 2016-01-04 15:05:04.038276 ==> Brasil - 2015-04-20 - 3_month
# 2016-01-04 15:05:05.072096 ==> Brasil - 2015-04-20 - 4_month
# 2016-01-04 15:05:06.087197 ==> Brasil - 2015-04-20 - 5_month
# 2016-01-04 15:05:07.144466 ==> Brasil - 2015-04-20 - 6_month
# 2016-01-04 15:05:08.197744 ==> Brasil - 2015-04-20 - 7_month
# 2016-01-04 15:05:09.339222 ==> Brasil - 2015-04-20 - 8_month
# 2016-01-04 15:05:10.406148 ==> Brasil - 2015-04-20 - 9_month
# 2016-01-04 15:05:11.458263 ==> Brasil - 2015-04-20 - 10_month
# 2016-01-04 15:05:12.475822 ==> Brasil - 2015-04-20 - 11_month
# 2016-01-04 15:05:13.457596 ==> Brasil - 2015-04-20 - 12_month
# 2016-01-04 15:05:14.434629 ==> Brasil - 2015-04-20 - 13_month
# 2016-01-04 15:05:15.407311 ==> Brasil - 2015-04-20 - 14_month
# 2016-01-04 15:05:16.464260 ==> Brasil - 2015-05-20 - same_month
# 2016-01-04 15:05:17.477447 ==> Brasil - 2015-05-20 - 1_month
# 2016-01-04 15:05:18.497770 ==> Brasil - 2015-05-20 - 2_month
# 2016-01-04 15:05:19.488408 ==> Brasil - 2015-05-20 - 3_month
# 2016-01-04 15:05:21.082358 ==> Brasil - 2015-05-20 - 4_month
# 2016-01-04 15:05:22.862128 ==> Brasil - 2015-05-20 - 5_month
# 2016-01-04 15:05:24.043969 ==> Brasil - 2015-05-20 - 6_month
# 2016-01-04 15:05:25.323997 ==> Brasil - 2015-05-20 - 7_month
# 2016-01-04 15:05:26.392805 ==> Brasil - 2015-05-20 - 8_month
# 2016-01-04 15:05:27.778835 ==> Brasil - 2015-05-20 - 9_month
# 2016-01-04 15:05:28.835413 ==> Brasil - 2015-05-20 - 10_month
# 2016-01-04 15:05:29.912884 ==> Brasil - 2015-05-20 - 11_month
# 2016-01-04 15:05:31.697015 ==> Brasil - 2015-05-20 - 12_month
# 2016-01-04 15:05:33.385508 ==> Brasil - 2015-05-20 - 13_month
# 2016-01-04 15:05:34.644910 ==> Brasil - 2015-05-20 - 14_month
# 2016-01-04 15:05:36.069409 ==> Brasil - 2015-06-19 - same_month
# 2016-01-04 15:05:37.437084 ==> Brasil - 2015-06-19 - 1_month
# 2016-01-04 15:05:38.643018 ==> Brasil - 2015-06-19 - 2_month
# 2016-01-04 15:05:39.781198 ==> Brasil - 2015-06-19 - 3_month
# 2016-01-04 15:05:40.881294 ==> Brasil - 2015-06-19 - 4_month
# 2016-01-04 15:05:41.956091 ==> Brasil - 2015-06-19 - 5_month
# 2016-01-04 15:05:43.125616 ==> Brasil - 2015-06-19 - 6_month
# 2016-01-04 15:05:44.172702 ==> Brasil - 2015-06-19 - 7_month
# 2016-01-04 15:05:45.248672 ==> Brasil - 2015-06-19 - 8_month
# 2016-01-04 15:05:46.276187 ==> Brasil - 2015-06-19 - 9_month
# 2016-01-04 15:05:47.291913 ==> Brasil - 2015-06-19 - 10_month
# 2016-01-04 15:05:48.305937 ==> Brasil - 2015-06-19 - 11_month
# 2016-01-04 15:05:49.329330 ==> Brasil - 2015-06-19 - 12_month
# 2016-01-04 15:05:50.311365 ==> Brasil - 2015-06-19 - 13_month
# 2016-01-04 15:05:51.292420 ==> Brasil - 2015-06-19 - 14_month
# 2016-01-04 15:05:52.320945 ==> Brasil - 2015-07-19 - same_month
# 2016-01-04 15:05:53.361752 ==> Brasil - 2015-07-19 - 1_month
# 2016-01-04 15:05:54.456785 ==> Brasil - 2015-07-19 - 2_month
# 2016-01-04 15:05:55.702378 ==> Brasil - 2015-07-19 - 3_month
# 2016-01-04 15:05:56.749717 ==> Brasil - 2015-07-19 - 4_month
# 2016-01-04 15:05:57.853991 ==> Brasil - 2015-07-19 - 5_month
# 2016-01-04 15:05:58.911190 ==> Brasil - 2015-07-19 - 6_month
# 2016-01-04 15:05:59.942322 ==> Brasil - 2015-07-19 - 7_month
# 2016-01-04 15:06:00.984389 ==> Brasil - 2015-07-19 - 8_month
# 2016-01-04 15:06:02.735354 ==> Brasil - 2015-07-19 - 9_month
# 2016-01-04 15:06:04.527313 ==> Brasil - 2015-07-19 - 10_month
# 2016-01-04 15:06:05.551085 ==> Brasil - 2015-07-19 - 11_month
# 2016-01-04 15:06:06.751024 ==> Brasil - 2015-07-19 - 12_month
# 2016-01-04 15:06:07.817980 ==> Brasil - 2015-07-19 - 13_month
# 2016-01-04 15:06:08.957630 ==> Brasil - 2015-07-19 - 14_month
# 2016-01-04 15:06:10.073070 ==> Brasil - 2015-08-18 - same_month
# 2016-01-04 15:06:11.130227 ==> Brasil - 2015-08-18 - 1_month
# 2016-01-04 15:06:12.159371 ==> Brasil - 2015-08-18 - 2_month
# 2016-01-04 15:06:13.178136 ==> Brasil - 2015-08-18 - 3_month
# 2016-01-04 15:06:14.152203 ==> Brasil - 2015-08-18 - 4_month
# 2016-01-04 15:06:15.114500 ==> Brasil - 2015-08-18 - 5_month
# 2016-01-04 15:06:16.075054 ==> Brasil - 2015-08-18 - 6_month
# 2016-01-04 15:06:17.051604 ==> Brasil - 2015-08-18 - 7_month
# 2016-01-04 15:06:18.028115 ==> Brasil - 2015-08-18 - 8_month
# 2016-01-04 15:06:19.060449 ==> Brasil - 2015-08-18 - 9_month
# 2016-01-04 15:06:20.823147 ==> Brasil - 2015-08-18 - 10_month
# 2016-01-04 15:06:22.583482 ==> Brasil - 2015-08-18 - 11_month
# 2016-01-04 15:06:23.614192 ==> Brasil - 2015-08-18 - 12_month
# 2016-01-04 15:06:24.663417 ==> Brasil - 2015-08-18 - 13_month
# 2016-01-04 15:06:25.660490 ==> Brasil - 2015-08-18 - 14_month
# 2016-01-04 15:06:26.844581 ==> Brasil - 2015-09-17 - same_month
# 2016-01-04 15:06:27.952117 ==> Brasil - 2015-09-17 - 1_month
# 2016-01-04 15:06:29.432577 ==> Brasil - 2015-09-17 - 2_month
# 2016-01-04 15:06:30.962699 ==> Brasil - 2015-09-17 - 3_month
# 2016-01-04 15:06:32.062682 ==> Brasil - 2015-09-17 - 4_month
# 2016-01-04 15:06:33.394450 ==> Brasil - 2015-09-17 - 5_month
# 2016-01-04 15:06:34.458522 ==> Brasil - 2015-09-17 - 6_month
# 2016-01-04 15:06:35.469273 ==> Brasil - 2015-09-17 - 7_month
# 2016-01-04 15:06:36.443033 ==> Brasil - 2015-09-17 - 8_month
# 2016-01-04 15:06:37.473769 ==> Brasil - 2015-09-17 - 9_month
# 2016-01-04 15:06:38.518018 ==> Brasil - 2015-09-17 - 10_month
# 2016-01-04 15:06:39.631616 ==> Brasil - 2015-09-17 - 11_month
# 2016-01-04 15:06:40.669643 ==> Brasil - 2015-09-17 - 12_month
# 2016-01-04 15:06:41.711206 ==> Brasil - 2015-09-17 - 13_month
# 2016-01-04 15:06:42.714891 ==> Brasil - 2015-09-17 - 14_month
# 2016-01-04 15:06:43.718605 ==> Brasil - 2015-10-17 - same_month
# 2016-01-04 15:06:44.741736 ==> Brasil - 2015-10-17 - 1_month
# 2016-01-04 15:06:45.750038 ==> Brasil - 2015-10-17 - 2_month
# 2016-01-04 15:06:46.814255 ==> Brasil - 2015-10-17 - 3_month
# 2016-01-04 15:06:47.867305 ==> Brasil - 2015-10-17 - 4_month
# 2016-01-04 15:06:48.858652 ==> Brasil - 2015-10-17 - 5_month
# 2016-01-04 15:06:49.838355 ==> Brasil - 2015-10-17 - 6_month
# 2016-01-04 15:06:50.821037 ==> Brasil - 2015-10-17 - 7_month
# 2016-01-04 15:06:51.881046 ==> Brasil - 2015-10-17 - 8_month
# 2016-01-04 15:06:53.072366 ==> Brasil - 2015-10-17 - 9_month
# 2016-01-04 15:06:54.224650 ==> Brasil - 2015-10-17 - 10_month
# 2016-01-04 15:06:55.347362 ==> Brasil - 2015-10-17 - 11_month
# 2016-01-04 15:06:56.441841 ==> Brasil - 2015-10-17 - 12_month
# 2016-01-04 15:06:57.543985 ==> Brasil - 2015-10-17 - 13_month
# 2016-01-04 15:06:58.772287 ==> Brasil - 2015-10-17 - 14_month
# 2016-01-04 15:06:59.849096 ==> Brasil - 2015-11-16 - same_month
# 2016-01-04 15:07:00.862326 ==> Brasil - 2015-11-16 - 1_month
# 2016-01-04 15:07:01.843565 ==> Brasil - 2015-11-16 - 2_month
# 2016-01-04 15:07:02.828509 ==> Brasil - 2015-11-16 - 3_month
# 2016-01-04 15:07:03.982151 ==> Brasil - 2015-11-16 - 4_month
# 2016-01-04 15:07:05.077523 ==> Brasil - 2015-11-16 - 5_month
# 2016-01-04 15:07:06.357083 ==> Brasil - 2015-11-16 - 6_month
# 2016-01-04 15:07:07.426597 ==> Brasil - 2015-11-16 - 7_month
# 2016-01-04 15:07:08.643839 ==> Brasil - 2015-11-16 - 8_month
# 2016-01-04 15:07:09.724544 ==> Brasil - 2015-11-16 - 9_month
# 2016-01-04 15:07:10.994061 ==> Brasil - 2015-11-16 - 10_month
# 2016-01-04 15:07:12.286083 ==> Brasil - 2015-11-16 - 11_month
# 2016-01-04 15:07:13.718679 ==> Brasil - 2015-11-16 - 12_month
# 2016-01-04 15:07:14.779502 ==> Brasil - 2015-11-16 - 13_month
# 2016-01-04 15:07:15.829093 ==> Brasil - 2015-11-16 - 14_month
# 2016-01-04 15:07:16.835533 ==> Brasil - 2015-12-16 - same_month
# 2016-01-04 15:07:17.818098 ==> Brasil - 2015-12-16 - 1_month
# 2016-01-04 15:07:18.831865 ==> Brasil - 2015-12-16 - 2_month
# 2016-01-04 15:07:19.816999 ==> Brasil - 2015-12-16 - 3_month
# 2016-01-04 15:07:20.798538 ==> Brasil - 2015-12-16 - 4_month
# 2016-01-04 15:07:21.796007 ==> Brasil - 2015-12-16 - 5_month
# 2016-01-04 15:07:22.777429 ==> Brasil - 2015-12-16 - 6_month
# 2016-01-04 15:07:24.167383 ==> Brasil - 2015-12-16 - 7_month
# 2016-01-04 15:07:25.208145 ==> Brasil - 2015-12-16 - 8_month
# 2016-01-04 15:07:26.404267 ==> Brasil - 2015-12-16 - 9_month
# 2016-01-04 15:07:27.779886 ==> Brasil - 2015-12-16 - 10_month
# 2016-01-04 15:07:29.250073 ==> Brasil - 2015-12-16 - 11_month
# 2016-01-04 15:07:30.269011 ==> Brasil - 2015-12-16 - 12_month
# 2016-01-04 15:07:31.243105 ==> Brasil - 2015-12-16 - 13_month
# 2016-01-04 15:07:32.286719 ==> Brasil - 2015-12-16 - 14_month
# 2016-01-04 15:07:33.427136 ==> Chile - 2014-10-22 - same_month
# 2016-01-04 15:07:34.470429 ==> Chile - 2014-10-22 - 1_month
# 2016-01-04 15:07:35.468661 ==> Chile - 2014-10-22 - 2_month
# 2016-01-04 15:07:36.519875 ==> Chile - 2014-10-22 - 3_month
# 2016-01-04 15:07:37.592104 ==> Chile - 2014-10-22 - 4_month
# 2016-01-04 15:07:38.714672 ==> Chile - 2014-10-22 - 5_month
# 2016-01-04 15:07:39.828846 ==> Chile - 2014-10-22 - 6_month
# 2016-01-04 15:07:40.944921 ==> Chile - 2014-10-22 - 7_month
# 2016-01-04 15:07:41.965040 ==> Chile - 2014-10-22 - 8_month
# 2016-01-04 15:07:42.961037 ==> Chile - 2014-10-22 - 9_month
# 2016-01-04 15:07:43.989172 ==> Chile - 2014-10-22 - 10_month
# 2016-01-04 15:07:45.032464 ==> Chile - 2014-10-22 - 11_month
# 2016-01-04 15:07:46.059059 ==> Chile - 2014-10-22 - 12_month
# 2016-01-04 15:07:47.058346 ==> Chile - 2014-10-22 - 13_month
# 2016-01-04 15:07:48.064919 ==> Chile - 2014-10-22 - 14_month
# 2016-01-04 15:07:49.306282 ==> Chile - 2014-11-21 - same_month
# 2016-01-04 15:07:50.301335 ==> Chile - 2014-11-21 - 1_month
# 2016-01-04 15:07:51.327879 ==> Chile - 2014-11-21 - 2_month
# 2016-01-04 15:07:52.285519 ==> Chile - 2014-11-21 - 3_month
# 2016-01-04 15:07:53.258478 ==> Chile - 2014-11-21 - 4_month
# 2016-01-04 15:07:54.252199 ==> Chile - 2014-11-21 - 5_month
# 2016-01-04 15:07:55.279319 ==> Chile - 2014-11-21 - 6_month
# 2016-01-04 15:07:56.312857 ==> Chile - 2014-11-21 - 7_month
# 2016-01-04 15:07:57.409537 ==> Chile - 2014-11-21 - 8_month
# 2016-01-04 15:07:58.469542 ==> Chile - 2014-11-21 - 9_month
# 2016-01-04 15:07:59.532562 ==> Chile - 2014-11-21 - 10_month
# 2016-01-04 15:08:00.610488 ==> Chile - 2014-11-21 - 11_month
# 2016-01-04 15:08:01.574329 ==> Chile - 2014-11-21 - 12_month
# 2016-01-04 15:08:02.534053 ==> Chile - 2014-11-21 - 13_month
# 2016-01-04 15:08:03.656327 ==> Chile - 2014-11-21 - 14_month
# 2016-01-04 15:08:04.710469 ==> Chile - 2014-12-21 - same_month
# 2016-01-04 15:08:05.834430 ==> Chile - 2014-12-21 - 1_month
# 2016-01-04 15:08:07.001899 ==> Chile - 2014-12-21 - 2_month
# 2016-01-04 15:08:08.131624 ==> Chile - 2014-12-21 - 3_month
# 2016-01-04 15:08:09.496949 ==> Chile - 2014-12-21 - 4_month
# 2016-01-04 15:08:11.263291 ==> Chile - 2014-12-21 - 5_month
# 2016-01-04 15:08:12.621554 ==> Chile - 2014-12-21 - 6_month
# 2016-01-04 15:08:13.620968 ==> Chile - 2014-12-21 - 7_month
# 2016-01-04 15:08:14.613299 ==> Chile - 2014-12-21 - 8_month
# 2016-01-04 15:08:15.636749 ==> Chile - 2014-12-21 - 9_month
# 2016-01-04 15:08:16.773225 ==> Chile - 2014-12-21 - 10_month
# 2016-01-04 15:08:17.810165 ==> Chile - 2014-12-21 - 11_month
# 2016-01-04 15:08:18.855921 ==> Chile - 2014-12-21 - 12_month
# 2016-01-04 15:08:19.862438 ==> Chile - 2014-12-21 - 13_month
# 2016-01-04 15:08:20.855765 ==> Chile - 2014-12-21 - 14_month
# 2016-01-04 15:08:21.823730 ==> Chile - 2015-01-20 - same_month
# 2016-01-04 15:08:23.393564 ==> Chile - 2015-01-20 - 1_month
# 2016-01-04 15:08:24.440640 ==> Chile - 2015-01-20 - 2_month
# 2016-01-04 15:08:25.620180 ==> Chile - 2015-01-20 - 3_month
# 2016-01-04 15:08:26.655488 ==> Chile - 2015-01-20 - 4_month
# 2016-01-04 15:08:27.685447 ==> Chile - 2015-01-20 - 5_month
# 2016-01-04 15:08:28.727902 ==> Chile - 2015-01-20 - 6_month
# 2016-01-04 15:08:29.910388 ==> Chile - 2015-01-20 - 7_month
# 2016-01-04 15:08:31.075952 ==> Chile - 2015-01-20 - 8_month
# 2016-01-04 15:08:32.150170 ==> Chile - 2015-01-20 - 9_month
# 2016-01-04 15:08:33.535907 ==> Chile - 2015-01-20 - 10_month
# 2016-01-04 15:08:34.996415 ==> Chile - 2015-01-20 - 11_month
# 2016-01-04 15:08:36.172668 ==> Chile - 2015-01-20 - 12_month
# ...
# 2016-01-04 16:59:09.055462 ==> Mexico - 2015-11-16 - 3_month
# 2016-01-04 16:59:12.297613 ==> Mexico - 2015-11-16 - 4_month
# 2016-01-04 16:59:15.288207 ==> Mexico - 2015-11-16 - 5_month
# 2016-01-04 16:59:18.370701 ==> Mexico - 2015-11-16 - 6_month
# 2016-01-04 16:59:20.835649 ==> Mexico - 2015-11-16 - 7_month
# 2016-01-04 16:59:23.534715 ==> Mexico - 2015-11-16 - 8_month
# 2016-01-04 16:59:27.720790 ==> Mexico - 2015-11-16 - 9_month
# 2016-01-04 16:59:30.177146 ==> Mexico - 2015-11-16 - 10_month
# 2016-01-04 16:59:32.823720 ==> Mexico - 2015-11-16 - 11_month
# 2016-01-04 16:59:36.649297 ==> Mexico - 2015-11-16 - 12_month
# 2016-01-04 16:59:39.490111 ==> Mexico - 2015-11-16 - 13_month
# 2016-01-04 16:59:42.382798 ==> Mexico - 2015-11-16 - 14_month
# 2016-01-04 16:59:45.256765 ==> Mexico - 2015-12-16 - same_month
# 2016-01-04 16:59:48.069999 ==> Mexico - 2015-12-16 - 1_month
# 2016-01-04 16:59:50.618943 ==> Mexico - 2015-12-16 - 2_month
# 2016-01-04 16:59:53.845718 ==> Mexico - 2015-12-16 - 3_month
# 2016-01-04 16:59:56.913983 ==> Mexico - 2015-12-16 - 4_month
# 2016-01-04 16:59:59.780489 ==> Mexico - 2015-12-16 - 5_month
# 2016-01-04 17:00:02.786721 ==> Mexico - 2015-12-16 - 6_month
# 2016-01-04 17:00:05.670191 ==> Mexico - 2015-12-16 - 7_month
# 2016-01-04 17:00:08.380806 ==> Mexico - 2015-12-16 - 8_month
# 2016-01-04 17:00:11.362206 ==> Mexico - 2015-12-16 - 9_month
# 2016-01-04 17:00:15.024206 ==> Mexico - 2015-12-16 - 10_month
# 2016-01-04 17:00:17.920046 ==> Mexico - 2015-12-16 - 11_month
# 2016-01-04 17:00:20.604757 ==> Mexico - 2015-12-16 - 12_month
# 2016-01-04 17:00:23.761527 ==> Mexico - 2015-12-16 - 13_month
# 2016-01-04 17:00:26.476507 ==> Mexico - 2015-12-16 - 14_month
# 2016-01-04 17:00:29.149888 ==> Pakistan - 2014-10-22 - same_month
# 2016-01-04 17:00:32.106310 ==> Pakistan - 2014-10-22 - 1_month
# 2016-01-04 17:00:35.056222 ==> Pakistan - 2014-10-22 - 2_month
# 2016-01-04 17:00:38.495714 ==> Pakistan - 2014-10-22 - 3_month
# 2016-01-04 17:00:42.338730 ==> Pakistan - 2014-10-22 - 4_month
# 2016-01-04 17:00:45.126817 ==> Pakistan - 2014-10-22 - 5_month
# 2016-01-04 17:00:48.072541 ==> Pakistan - 2014-10-22 - 6_month
# 2016-01-04 17:00:51.027765 ==> Pakistan - 2014-10-22 - 7_month
# 2016-01-04 17:00:54.855858 ==> Pakistan - 2014-10-22 - 8_month
# 2016-01-04 17:00:58.810755 ==> Pakistan - 2014-10-22 - 9_month
# 2016-01-04 17:01:02.516825 ==> Pakistan - 2014-10-22 - 10_month
# 2016-01-04 17:01:05.657587 ==> Pakistan - 2014-10-22 - 11_month
# 2016-01-04 17:01:08.892204 ==> Pakistan - 2014-10-22 - 12_month
# 2016-01-04 17:01:12.456398 ==> Pakistan - 2014-10-22 - 13_month
# 2016-01-04 17:01:15.552001 ==> Pakistan - 2014-10-22 - 14_month
# 2016-01-04 17:01:18.674020 ==> Pakistan - 2014-11-21 - same_month
# 2016-01-04 17:01:21.454256 ==> Pakistan - 2014-11-21 - 1_month
# 2016-01-04 17:01:24.662345 ==> Pakistan - 2014-11-21 - 2_month
# 2016-01-04 17:01:27.195512 ==> Pakistan - 2014-11-21 - 3_month
# 2016-01-04 17:01:29.904197 ==> Pakistan - 2014-11-21 - 4_month
# 2016-01-04 17:01:33.523026 ==> Pakistan - 2014-11-21 - 5_month
# 2016-01-04 17:01:36.762382 ==> Pakistan - 2014-11-21 - 6_month
# 2016-01-04 17:01:39.650676 ==> Pakistan - 2014-11-21 - 7_month
# 2016-01-04 17:01:42.493190 ==> Pakistan - 2014-11-21 - 8_month
# 2016-01-04 17:01:45.078972 ==> Pakistan - 2014-11-21 - 9_month
# 2016-01-04 17:01:47.700556 ==> Pakistan - 2014-11-21 - 10_month
# 2016-01-04 17:01:50.433244 ==> Pakistan - 2014-11-21 - 11_month
# 2016-01-04 17:01:53.431224 ==> Pakistan - 2014-11-21 - 12_month
# 2016-01-04 17:01:56.788111 ==> Pakistan - 2014-11-21 - 13_month
# 2016-01-04 17:02:00.868125 ==> Pakistan - 2014-11-21 - 14_month
# 2016-01-04 17:02:03.985391 ==> Pakistan - 2014-12-21 - same_month
# 2016-01-04 17:02:07.882880 ==> Pakistan - 2014-12-21 - 1_month
# 2016-01-04 17:02:10.622575 ==> Pakistan - 2014-12-21 - 2_month
# 2016-01-04 17:02:13.528947 ==> Pakistan - 2014-12-21 - 3_month
# 2016-01-04 17:02:16.259412 ==> Pakistan - 2014-12-21 - 4_month
# 2016-01-04 17:02:18.928277 ==> Pakistan - 2014-12-21 - 5_month
# 2016-01-04 17:02:21.487140 ==> Pakistan - 2014-12-21 - 6_month
# 2016-01-04 17:02:24.041628 ==> Pakistan - 2014-12-21 - 7_month
# 2016-01-04 17:02:26.821257 ==> Pakistan - 2014-12-21 - 8_month
# 2016-01-04 17:02:29.962704 ==> Pakistan - 2014-12-21 - 9_month
# 2016-01-04 17:02:33.656754 ==> Pakistan - 2014-12-21 - 10_month
# 2016-01-04 17:02:36.357045 ==> Pakistan - 2014-12-21 - 11_month
# 2016-01-04 17:02:38.911313 ==> Pakistan - 2014-12-21 - 12_month
# 2016-01-04 17:02:41.691931 ==> Pakistan - 2014-12-21 - 13_month
# 2016-01-04 17:02:44.545601 ==> Pakistan - 2014-12-21 - 14_month
# 2016-01-04 17:02:47.455042 ==> Pakistan - 2015-01-20 - same_month
# 2016-01-04 17:02:50.045685 ==> Pakistan - 2015-01-20 - 1_month
# 2016-01-04 17:02:52.585119 ==> Pakistan - 2015-01-20 - 2_month
# 2016-01-04 17:02:55.672452 ==> Pakistan - 2015-01-20 - 3_month
# 2016-01-04 17:02:58.374337 ==> Pakistan - 2015-01-20 - 4_month
# 2016-01-04 17:03:01.310767 ==> Pakistan - 2015-01-20 - 5_month
# 2016-01-04 17:03:03.949744 ==> Pakistan - 2015-01-20 - 6_month
# 2016-01-04 17:03:07.041452 ==> Pakistan - 2015-01-20 - 7_month
# 2016-01-04 17:03:10.961877 ==> Pakistan - 2015-01-20 - 8_month
# 2016-01-04 17:03:14.030924 ==> Pakistan - 2015-01-20 - 9_month
# 2016-01-04 17:03:16.744452 ==> Pakistan - 2015-01-20 - 10_month
# 2016-01-04 17:03:20.764277 ==> Pakistan - 2015-01-20 - 11_month
# 2016-01-04 17:03:24.499346 ==> Pakistan - 2015-01-20 - 12_month
# 2016-01-04 17:03:27.869395 ==> Pakistan - 2015-01-20 - 13_month
# 2016-01-04 17:03:31.052885 ==> Pakistan - 2015-01-20 - 14_month
# 2016-01-04 17:03:34.021470 ==> Pakistan - 2015-02-19 - same_month
# 2016-01-04 17:03:36.950756 ==> Pakistan - 2015-02-19 - 1_month
# 2016-01-04 17:03:40.072342 ==> Pakistan - 2015-02-19 - 2_month
# 2016-01-04 17:03:43.111001 ==> Pakistan - 2015-02-19 - 3_month
# 2016-01-04 17:03:46.974814 ==> Pakistan - 2015-02-19 - 4_month
# 2016-01-04 17:03:49.710534 ==> Pakistan - 2015-02-19 - 5_month
# 2016-01-04 17:03:52.790241 ==> Pakistan - 2015-02-19 - 6_month
# 2016-01-04 17:03:56.073238 ==> Pakistan - 2015-02-19 - 7_month
# 2016-01-04 17:03:58.852390 ==> Pakistan - 2015-02-19 - 8_month
# 2016-01-04 17:04:01.673893 ==> Pakistan - 2015-02-19 - 9_month
# 2016-01-04 17:04:04.203710 ==> Pakistan - 2015-02-19 - 10_month
# 2016-01-04 17:04:07.038321 ==> Pakistan - 2015-02-19 - 11_month
# 2016-01-04 17:04:09.841372 ==> Pakistan - 2015-02-19 - 12_month
# 2016-01-04 17:04:12.398706 ==> Pakistan - 2015-02-19 - 13_month
# 2016-01-04 17:04:14.957470 ==> Pakistan - 2015-02-19 - 14_month
# 2016-01-04 17:04:17.549212 ==> Pakistan - 2015-03-21 - same_month
# 2016-01-04 17:04:20.142260 ==> Pakistan - 2015-03-21 - 1_month
# 2016-01-04 17:04:23.026207 ==> Pakistan - 2015-03-21 - 2_month
# 2016-01-04 17:04:25.981509 ==> Pakistan - 2015-03-21 - 3_month
# 2016-01-04 17:04:29.069504 ==> Pakistan - 2015-03-21 - 4_month
# 2016-01-04 17:04:31.984573 ==> Pakistan - 2015-03-21 - 5_month
# 2016-01-04 17:04:35.513051 ==> Pakistan - 2015-03-21 - 6_month
# 2016-01-04 17:04:39.877967 ==> Pakistan - 2015-03-21 - 7_month
# 2016-01-04 17:04:43.761165 ==> Pakistan - 2015-03-21 - 8_month
# 2016-01-04 17:04:47.051239 ==> Pakistan - 2015-03-21 - 9_month
# 2016-01-04 17:04:50.114466 ==> Pakistan - 2015-03-21 - 10_month
# 2016-01-04 17:04:52.935172 ==> Pakistan - 2015-03-21 - 11_month
# 2016-01-04 17:04:55.360386 ==> Pakistan - 2015-03-21 - 12_month
# 2016-01-04 17:04:58.115383 ==> Pakistan - 2015-03-21 - 13_month
# 2016-01-04 17:05:00.672329 ==> Pakistan - 2015-03-21 - 14_month
# 2016-01-04 17:05:03.800612 ==> Pakistan - 2015-04-20 - same_month
# 2016-01-04 17:05:06.649922 ==> Pakistan - 2015-04-20 - 1_month
# 2016-01-04 17:05:09.889719 ==> Pakistan - 2015-04-20 - 2_month
# 2016-01-04 17:05:13.182322 ==> Pakistan - 2015-04-20 - 3_month
# 2016-01-04 17:05:16.074172 ==> Pakistan - 2015-04-20 - 4_month
# 2016-01-04 17:05:19.144451 ==> Pakistan - 2015-04-20 - 5_month
# 2016-01-04 17:05:23.258172 ==> Pakistan - 2015-04-20 - 6_month
# 2016-01-04 17:05:26.512833 ==> Pakistan - 2015-04-20 - 7_month
# 2016-01-04 17:05:30.000644 ==> Pakistan - 2015-04-20 - 8_month
# 2016-01-04 17:05:32.782288 ==> Pakistan - 2015-04-20 - 9_month
# 2016-01-04 17:05:35.644800 ==> Pakistan - 2015-04-20 - 10_month
# 2016-01-04 17:05:39.459162 ==> Pakistan - 2015-04-20 - 11_month
# 2016-01-04 17:05:43.021439 ==> Pakistan - 2015-04-20 - 12_month
# 2016-01-04 17:05:46.085070 ==> Pakistan - 2015-04-20 - 13_month
# 2016-01-04 17:05:49.763356 ==> Pakistan - 2015-04-20 - 14_month
# 2016-01-04 17:05:52.358576 ==> Pakistan - 2015-05-20 - same_month
# 2016-01-04 17:05:54.957267 ==> Pakistan - 2015-05-20 - 1_month
# 2016-01-04 17:05:57.571336 ==> Pakistan - 2015-05-20 - 2_month
# 2016-01-04 17:06:00.233501 ==> Pakistan - 2015-05-20 - 3_month
# 2016-01-04 17:06:02.818027 ==> Pakistan - 2015-05-20 - 4_month
# 2016-01-04 17:06:05.361741 ==> Pakistan - 2015-05-20 - 5_month
# 2016-01-04 17:06:07.932413 ==> Pakistan - 2015-05-20 - 6_month
# 2016-01-04 17:06:10.616966 ==> Pakistan - 2015-05-20 - 7_month
# 2016-01-04 17:06:13.228270 ==> Pakistan - 2015-05-20 - 8_month
# 2016-01-04 17:06:16.206109 ==> Pakistan - 2015-05-20 - 9_month
# 2016-01-04 17:06:19.604139 ==> Pakistan - 2015-05-20 - 10_month
# 2016-01-04 17:06:22.367641 ==> Pakistan - 2015-05-20 - 11_month
# 2016-01-04 17:06:25.604058 ==> Pakistan - 2015-05-20 - 12_month
# 2016-01-04 17:06:28.563152 ==> Pakistan - 2015-05-20 - 13_month
# 2016-01-04 17:06:31.835325 ==> Pakistan - 2015-05-20 - 14_month
# 2016-01-04 17:06:34.684831 ==> Pakistan - 2015-06-19 - same_month
# 2016-01-04 17:06:37.299350 ==> Pakistan - 2015-06-19 - 1_month
# 2016-01-04 17:06:41.118659 ==> Pakistan - 2015-06-19 - 2_month
# 2016-01-04 17:06:44.614591 ==> Pakistan - 2015-06-19 - 3_month
# 2016-01-04 17:06:47.326218 ==> Pakistan - 2015-06-19 - 4_month
# 2016-01-04 17:06:50.589006 ==> Pakistan - 2015-06-19 - 5_month
# 2016-01-04 17:06:53.507233 ==> Pakistan - 2015-06-19 - 6_month
# 2016-01-04 17:06:56.392836 ==> Pakistan - 2015-06-19 - 7_month
# 2016-01-04 17:07:00.219618 ==> Pakistan - 2015-06-19 - 8_month
# 2016-01-04 17:07:03.498385 ==> Pakistan - 2015-06-19 - 9_month
# 2016-01-04 17:07:06.336493 ==> Pakistan - 2015-06-19 - 10_month
# 2016-01-04 17:07:09.950830 ==> Pakistan - 2015-06-19 - 11_month
# 2016-01-04 17:07:12.917469 ==> Pakistan - 2015-06-19 - 12_month
# 2016-01-04 17:07:15.748821 ==> Pakistan - 2015-06-19 - 13_month
# 2016-01-04 17:07:18.857856 ==> Pakistan - 2015-06-19 - 14_month
# 2016-01-04 17:07:22.287006 ==> Pakistan - 2015-07-19 - same_month
# 2016-01-04 17:07:25.230711 ==> Pakistan - 2015-07-19 - 1_month
# 2016-01-04 17:07:27.873856 ==> Pakistan - 2015-07-19 - 2_month
# 2016-01-04 17:07:30.512660 ==> Pakistan - 2015-07-19 - 3_month
# 2016-01-04 17:07:33.330063 ==> Pakistan - 2015-07-19 - 4_month
# 2016-01-04 17:07:36.005491 ==> Pakistan - 2015-07-19 - 5_month
# 2016-01-04 17:07:39.768810 ==> Pakistan - 2015-07-19 - 6_month
# 2016-01-04 17:07:42.395494 ==> Pakistan - 2015-07-19 - 7_month
# 2016-01-04 17:07:45.023430 ==> Pakistan - 2015-07-19 - 8_month
# 2016-01-04 17:07:47.996845 ==> Pakistan - 2015-07-19 - 9_month
# 2016-01-04 17:07:50.877982 ==> Pakistan - 2015-07-19 - 10_month
# 2016-01-04 17:07:54.060043 ==> Pakistan - 2015-07-19 - 11_month
# 2016-01-04 17:07:57.211734 ==> Pakistan - 2015-07-19 - 12_month
# 2016-01-04 17:08:00.305962 ==> Pakistan - 2015-07-19 - 13_month
# 2016-01-04 17:08:03.073981 ==> Pakistan - 2015-07-19 - 14_month
# 2016-01-04 17:08:05.848603 ==> Pakistan - 2015-08-18 - same_month
# 2016-01-04 17:08:08.741282 ==> Pakistan - 2015-08-18 - 1_month
# 2016-01-04 17:08:12.076862 ==> Pakistan - 2015-08-18 - 2_month
# 2016-01-04 17:08:14.744706 ==> Pakistan - 2015-08-18 - 3_month
# 2016-01-04 17:08:17.225844 ==> Pakistan - 2015-08-18 - 4_month
# 2016-01-04 17:08:19.896652 ==> Pakistan - 2015-08-18 - 5_month
# 2016-01-04 17:08:22.495002 ==> Pakistan - 2015-08-18 - 6_month
# 2016-01-04 17:08:25.214333 ==> Pakistan - 2015-08-18 - 7_month
# 2016-01-04 17:08:29.396914 ==> Pakistan - 2015-08-18 - 8_month
# 2016-01-04 17:08:33.094689 ==> Pakistan - 2015-08-18 - 9_month
# 2016-01-04 17:08:35.981131 ==> Pakistan - 2015-08-18 - 10_month
# 2016-01-04 17:08:39.299787 ==> Pakistan - 2015-08-18 - 11_month
# 2016-01-04 17:08:42.447003 ==> Pakistan - 2015-08-18 - 12_month
# 2016-01-04 17:08:45.647984 ==> Pakistan - 2015-08-18 - 13_month
# 2016-01-04 17:08:48.297896 ==> Pakistan - 2015-08-18 - 14_month
# 2016-01-04 17:08:51.707758 ==> Pakistan - 2015-09-17 - same_month
# 2016-01-04 17:08:54.978342 ==> Pakistan - 2015-09-17 - 1_month
# 2016-01-04 17:08:58.030451 ==> Pakistan - 2015-09-17 - 2_month
# 2016-01-04 17:09:02.077649 ==> Pakistan - 2015-09-17 - 3_month
# 2016-01-04 17:09:04.893575 ==> Pakistan - 2015-09-17 - 4_month
# 2016-01-04 17:09:08.654653 ==> Pakistan - 2015-09-17 - 5_month
# 2016-01-04 17:09:11.784966 ==> Pakistan - 2015-09-17 - 6_month
# 2016-01-04 17:09:15.753799 ==> Pakistan - 2015-09-17 - 7_month
# 2016-01-04 17:09:18.503537 ==> Pakistan - 2015-09-17 - 8_month
# 2016-01-04 17:09:20.989722 ==> Pakistan - 2015-09-17 - 9_month
# 2016-01-04 17:09:23.798583 ==> Pakistan - 2015-09-17 - 10_month
# 2016-01-04 17:09:27.133873 ==> Pakistan - 2015-09-17 - 11_month
# 2016-01-04 17:09:31.432547 ==> Pakistan - 2015-09-17 - 12_month
# 2016-01-04 17:09:34.379061 ==> Pakistan - 2015-09-17 - 13_month
# 2016-01-04 17:09:37.082378 ==> Pakistan - 2015-09-17 - 14_month
# 2016-01-04 17:09:39.786788 ==> Pakistan - 2015-10-17 - same_month
# 2016-01-04 17:09:43.302612 ==> Pakistan - 2015-10-17 - 1_month
# 2016-01-04 17:09:46.066584 ==> Pakistan - 2015-10-17 - 2_month
# 2016-01-04 17:09:48.769315 ==> Pakistan - 2015-10-17 - 3_month
# 2016-01-04 17:09:52.156196 ==> Pakistan - 2015-10-17 - 4_month
# 2016-01-04 17:09:55.440013 ==> Pakistan - 2015-10-17 - 5_month
# 2016-01-04 17:09:58.439430 ==> Pakistan - 2015-10-17 - 6_month
# 2016-01-04 17:10:02.541490 ==> Pakistan - 2015-10-17 - 7_month
# 2016-01-04 17:10:06.391224 ==> Pakistan - 2015-10-17 - 8_month
# 2016-01-04 17:10:09.869840 ==> Pakistan - 2015-10-17 - 9_month
# 2016-01-04 17:10:13.301686 ==> Pakistan - 2015-10-17 - 10_month
# 2016-01-04 17:10:16.699523 ==> Pakistan - 2015-10-17 - 11_month
# 2016-01-04 17:10:19.297595 ==> Pakistan - 2015-10-17 - 12_month
# 2016-01-04 17:10:23.601149 ==> Pakistan - 2015-10-17 - 13_month
# 2016-01-04 17:10:27.674531 ==> Pakistan - 2015-10-17 - 14_month
# 2016-01-04 17:10:30.705300 ==> Pakistan - 2015-11-16 - same_month
# 2016-01-04 17:10:33.778234 ==> Pakistan - 2015-11-16 - 1_month
# 2016-01-04 17:10:36.646528 ==> Pakistan - 2015-11-16 - 2_month
# 2016-01-04 17:10:39.883033 ==> Pakistan - 2015-11-16 - 3_month
# 2016-01-04 17:10:43.429576 ==> Pakistan - 2015-11-16 - 4_month
# 2016-01-04 17:10:46.883543 ==> Pakistan - 2015-11-16 - 5_month
# 2016-01-04 17:10:49.763033 ==> Pakistan - 2015-11-16 - 6_month
# 2016-01-04 17:10:52.520370 ==> Pakistan - 2015-11-16 - 7_month
# 2016-01-04 17:10:55.648994 ==> Pakistan - 2015-11-16 - 8_month
# 2016-01-04 17:10:58.704173 ==> Pakistan - 2015-11-16 - 9_month
# 2016-01-04 17:11:02.826596 ==> Pakistan - 2015-11-16 - 10_month
# 2016-01-04 17:11:05.533125 ==> Pakistan - 2015-11-16 - 11_month
# 2016-01-04 17:11:08.287239 ==> Pakistan - 2015-11-16 - 12_month
# 2016-01-04 17:11:11.720423 ==> Pakistan - 2015-11-16 - 13_month
# 2016-01-04 17:11:14.803088 ==> Pakistan - 2015-11-16 - 14_month
# 2016-01-04 17:11:17.875789 ==> Pakistan - 2015-12-16 - same_month
# 2016-01-04 17:11:20.958418 ==> Pakistan - 2015-12-16 - 1_month
# 2016-01-04 17:11:23.724121 ==> Pakistan - 2015-12-16 - 2_month
# 2016-01-04 17:11:26.266805 ==> Pakistan - 2015-12-16 - 3_month
# 2016-01-04 17:11:30.055534 ==> Pakistan - 2015-12-16 - 4_month
# 2016-01-04 17:11:33.393882 ==> Pakistan - 2015-12-16 - 5_month
# 2016-01-04 17:11:36.362309 ==> Pakistan - 2015-12-16 - 6_month
# 2016-01-04 17:11:39.524768 ==> Pakistan - 2015-12-16 - 7_month
# 2016-01-04 17:11:42.882256 ==> Pakistan - 2015-12-16 - 8_month
# 2016-01-04 17:11:45.483212 ==> Pakistan - 2015-12-16 - 9_month
# 2016-01-04 17:11:48.293141 ==> Pakistan - 2015-12-16 - 10_month
# 2016-01-04 17:11:50.830416 ==> Pakistan - 2015-12-16 - 11_month
# 2016-01-04 17:11:53.431405 ==> Pakistan - 2015-12-16 - 12_month
# 2016-01-04 17:11:57.103914 ==> Pakistan - 2015-12-16 - 13_month
# 2016-01-04 17:12:00.349034 ==> Pakistan - 2015-12-16 - 14_month

# %%
html_driver = html(cohort_driver_final,cohort_size_driver,1)
html_pax = html(cohort_passenger_final,cohort_size_pax,2)

# %%
html_pdf = html_driver + '<br/><br/><br/><br/><br/><br/><br/><br/>' +  html_pax 
PDFReport_Name = titles(2)
pdfkit.from_string(html_pdf, "/home/ricardo/Tripda/cohort/" + 'Cohorts-November_2015_all_data.pdf')
# Out:
# Loading pages (1/5)
# Resolving links (2/5)
# Counting pages (3/5)
# Printing pages (5/5)
# Done
# True

# %%
html_body = html_inicial() + html_driver + html_pax
Subject = titles(1)
SendEmail('teste',html_body,'ricardo.nakano@tripda.com.br','tripda-datateam@tripda.com.br','123@datateam','','')
# Out:
# Unexpected error: <type 'exceptions.IOError'>

# %%
df = pd.DataFrame(columns=('Country', 'Date', 'Reference', \
                           'cohort size RR1 driver','cohort size RR2 driver', \
                           'RR1 driver', 'RR1 driver_Ac','RR2 driver', 'RR2 driver_Ac', \
                           'cohort size RR1 pax','cohort size  RR2 pax',\
                           'RR1 pax', 'RR1 pax_Ac','RR2 pax', 'RR2 pax_Ac'))
count = 0

for locate in countries:
    for date in months:
        for referece in reference_month:
            toexcel = []
            toexcel.append(locate)
            toexcel.append(date.strftime("%b/%Y"))
            toexcel.append(referece)
            
            toexcel.append(cohort_size_driver[locate][date]['RR1'])
            toexcel.append(cohort_size_driver[locate][date]['RR2'])
            if cohort_driver_final[locate][date][referece]['RR1'] < 0:
                toexcel.append(-cohort_driver_final[locate][date][referece]['RR1'])
                toexcel.append(-cohort_driver_final[locate][date][referece]['RR1_Ac'])
            elif cohort_driver_final[locate][date][referece]['RR1'] >= pow(10,100):
                toexcel.append(0)  
                toexcel.append(0)
            else:
                toexcel.append(cohort_driver_final[locate][date][referece]['RR1'])
                toexcel.append(cohort_driver_final[locate][date][referece]['RR1_Ac'])   
                
            if cohort_driver_final[locate][date][referece]['RR2'] < 0:
                toexcel.append(-cohort_driver_final[locate][date][referece]['RR2'])
                toexcel.append(-cohort_driver_final[locate][date][referece]['RR2_Ac'])
            elif cohort_driver_final[locate][date][referece]['RR2'] >= pow(10,100):
                toexcel.append(0)
                toexcel.append(0) 
            else:
                toexcel.append(cohort_driver_final[locate][date][referece]['RR2'])
                toexcel.append(cohort_driver_final[locate][date][referece]['RR2_Ac']) 
            
            toexcel.append(cohort_size_pax[locate][date]['RR1'])
            toexcel.append(cohort_size_pax[locate][date]['RR2'])
            if cohort_passenger_final[locate][date][referece]['RR1'] < 0:
                toexcel.append(-cohort_passenger_final[locate][date][referece]['RR1'])
                toexcel.append(-cohort_passenger_final[locate][date][referece]['RR1_Ac'])
            elif cohort_passenger_final[locate][date][referece]['RR1'] >= pow(10,100):
                toexcel.append(0)
                toexcel.append(0)
            else:
                toexcel.append(cohort_passenger_final[locate][date][referece]['RR1']) 
                toexcel.append(cohort_passenger_final[locate][date][referece]['RR1_Ac']) 
                
            if cohort_passenger_final[locate][date][referece]['RR2'] < 0:
                toexcel.append(-cohort_passenger_final[locate][date][referece]['RR2'])
                toexcel.append(-cohort_passenger_final[locate][date][referece]['RR2_Ac'])
            elif cohort_passenger_final[locate][date][referece]['RR2'] >= pow(10,100):
                toexcel.append(0)
                toexcel.append(0) 
            else:
                toexcel.append(cohort_passenger_final[locate][date][referece]['RR2'])
                toexcel.append(cohort_passenger_final[locate][date][referece]['RR2_Ac'])

            df.loc[count] = toexcel
            count += 1

# %%
df.to_csv('/home/ricardo/Tripda/cohort/cohort.csv', sep=',')

# %%
writer = pd.ExcelWriter('/home/ricardo/Tripda/cohort/cohort.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='cohort')

writer.save()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-3548906aefb2> in <module>()
# ----> 1 writer = pd.ExcelWriter('/home/ricardo/Tripda/cohort/cohort.csv', engine='xlsxwriter')
#       2 df.to_excel(writer, sheet_name='cohort')
#       3
#       4 writer.save()
#
# /home/ricardo/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, path, engine, date_format, datetime_format, **engine_kwargs)
#    1288                                           date_format=date_format,
#    1289                                           datetime_format=datetime_format,
# -> 1290                                           **engine_kwargs)
#    1291
#    1292         self.book = xlsxwriter.Workbook(path, **engine_kwargs)
#
# /home/ricardo/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, path, engine, date_format, datetime_format, **engine_kwargs)
#     576         # validate that this engine can handle the extension
#     577         ext = os.path.splitext(path)[-1]
# --> 578         self.check_extension(ext)
#     579
#     580         self.path = path
#
# /home/ricardo/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in check_extension(cls, ext)
#     608             msg = (u("Invalid extension for engine '%s': '%s'") %
#     609                    (pprint_thing(cls.engine), pprint_thing(ext)))
# --> 610             raise ValueError(msg)
#     611         else:
#     612             return True
#
# ValueError: Invalid extension for engine 'xlsxwriter': 'csv'

# %%
df
# Out:
#       Country      Date      Reference  cohort size RR1 driver  \
# 0       TOTAL  Jan/2015     same_month                    1430
# 1       TOTAL  Jan/2015        1_month                    1430
# 2       TOTAL  Jan/2015        2_month                    1430
# 3       TOTAL  Jan/2015        3_month                    1430
# 4       TOTAL  Jan/2015        4_month                    1430
# 5       TOTAL  Jan/2015        5_month                    1430
# 6       TOTAL  Jan/2015        6_month                    1430
# 7       TOTAL  Jan/2015  7_to_12_month                    1430
# 8       TOTAL  Feb/2015     same_month                    1292
# 9       TOTAL  Feb/2015        1_month                    1292
# 10      TOTAL  Feb/2015        2_month                    1292
# 11      TOTAL  Feb/2015        3_month                    1292
# 12      TOTAL  Feb/2015        4_month                    1292
# 13      TOTAL  Feb/2015        5_month                    1292
# 14      TOTAL  Feb/2015        6_month                    1292
# 15      TOTAL  Feb/2015  7_to_12_month                    1292
# 16      TOTAL  Mar/2015     same_month                    2226
# 17      TOTAL  Mar/2015        1_month                    2226
# 18      TOTAL  Mar/2015        2_month                    2226
# 19      TOTAL  Mar/2015        3_month                    2226
# 20      TOTAL  Mar/2015        4_month                    2226
# 21      TOTAL  Mar/2015        5_month                    2226
# 22      TOTAL  Mar/2015        6_month                    2226
# 23      TOTAL  Mar/2015  7_to_12_month                    2226
# 24      TOTAL  Apr/2015     same_month                    2191
# 25      TOTAL  Apr/2015        1_month                    2191
# 26      TOTAL  Apr/2015        2_month                    2191
# 27      TOTAL  Apr/2015        3_month                    2191
# 28      TOTAL  Apr/2015        4_month                    2191
# 29      TOTAL  Apr/2015        5_month                    2191
# ..        ...       ...            ...                     ...
# 618  Pakistan  Jun/2015        2_month                     134
# 619  Pakistan  Jun/2015        3_month                     134
# 620  Pakistan  Jun/2015        4_month                     134
# 621  Pakistan  Jun/2015        5_month                     134
# 622  Pakistan  Jun/2015        6_month                     134
# 623  Pakistan  Jun/2015  7_to_12_month                     134
# 624  Pakistan  Jul/2015     same_month                     242
# 625  Pakistan  Jul/2015        1_month                     242
# 626  Pakistan  Jul/2015        2_month                     242
# 627  Pakistan  Jul/2015        3_month                     242
# 628  Pakistan  Jul/2015        4_month                     242
# 629  Pakistan  Jul/2015        5_month                     242
# 630  Pakistan  Jul/2015        6_month                     242
# 631  Pakistan  Jul/2015  7_to_12_month                     242
# 632  Pakistan  Aug/2015     same_month                     342
# 633  Pakistan  Aug/2015        1_month                     342
# 634  Pakistan  Aug/2015        2_month                     342
# 635  Pakistan  Aug/2015        3_month                     342
# 636  Pakistan  Aug/2015        4_month                     342
# 637  Pakistan  Aug/2015        5_month                     342
# 638  Pakistan  Aug/2015        6_month                     342
# 639  Pakistan  Aug/2015  7_to_12_month                     342
# 640  Pakistan  Sep/2015     same_month                     363
# 641  Pakistan  Sep/2015        1_month                     363
# 642  Pakistan  Sep/2015        2_month                     363
# 643  Pakistan  Sep/2015        3_month                     363
# 644  Pakistan  Sep/2015        4_month                     363
# 645  Pakistan  Sep/2015        5_month                     363
# 646  Pakistan  Sep/2015        6_month                     363
# 647  Pakistan  Sep/2015  7_to_12_month                     363
#
#      cohort size RR2 driver  RR1 driver  RR2 driver_Ac  RR1 driver  \
# 0                    552509         363            363      335060
# 1                    552509         211            465      199302
# 2                    552509         158            498      170602
# 3                    552509         157            523      197137
# 4                    552509         105            531      159756
# 5                    552509         110            542      135796
# 6                    552509          87            552      109172
# 7                    552509         121            569      267525
# 8                    464459         364            364      380072
# 9                    464459         246            486      285114
# 10                   464459         194            522      252522
# 11                   464459         150            542      199337
# 12                   464459         115            560      148095
# 13                   464459         101            576      141697
# 14                   464459         121            589      192987
# 15                   464459         106            599      148485
# 16                   656994         870            870      582504
# 17                   656994         341           1008      331995
# 18                   656994         269           1059      277306
# 19                   656994         211           1079      242789
# 20                   656994         151           1094      161811
# 21                   656994         176           1120      216228
# 22                   656994         171           1137      185390
# 23                   656994           0              0           0
# 24                  1083582        1067           1067     1077493
# 25                  1083582         426           1203      405099
# 26                  1083582         327           1263      317056
# 27                  1083582         183           1285      177573
# 28                  1083582         290           1322      371125
# 29                  1083582         247           1342      309001
# ..                      ...         ...            ...         ...
# 618                  165748          11             32       13966
# 619                  165748           8             36        4578
# 620                  165748           0              0           0
# 621                  165748           0              0           0
# 622                  165748           0              0           0
# 623                  165748           0              0           0
# 624                  195906          69             69      139687
# 625                  195906          44             89       41345
# 626                  195906          27             96       23780
# 627                  195906           0              0           0
# 628                  195906           0              0           0
# 629                  195906           0              0           0
# 630                  195906           0              0           0
# 631                  195906           0              0           0
# 632                  278117         109            109      230906
# 633                  278117          53            126       19073
# 634                  278117           0              0           0
# 635                  278117           0              0           0
# 636                  278117           0              0           0
# 637                  278117           0              0           0
# 638                  278117           0              0           0
# 639                  278117           0              0           0
# 640                  188576         106            106       69288
# 641                  188576           0              0           0
# 642                  188576           0              0           0
# 643                  188576           0              0           0
# 644                  188576           0              0           0
# 645                  188576           0              0           0
# 646                  188576           0              0           0
# 647                  188576           0              0           0
#
#      RR2 driver_Ac
# 0           335060
# 1           534362
# 2           704964
# 3           902101
# 4          1061857
# 5          1197653
# 6          1306825
# 7          1574350
# 8           380072
# 9           665186
# 10          917708
# 11         1117045
# 12         1265140
# 13         1406837
# 14         1599824
# 15         1748309
# 16          582504
# 17          914499
# 18         1191805
# 19         1434594
# 20         1596405
# 21         1812633
# 22         1998023
# 23               0
# 24         1077493
# 25         1482592
# 26         1799648
# 27         1977221
# 28         2348346
# 29         2657347
# ..             ...
# 618          89904
# 619          94482
# 620              0
# 621              0
# 622              0
# 623              0
# 624         139687
# 625         181032
# 626         204812
# 627              0
# 628              0
# 629              0
# 630              0
# 631              0
# 632         230906
# 633         249979
# 634              0
# 635              0
# 636              0
# 637              0
# 638              0
# 639              0
# 640          69288
# 641              0
# 642              0
# 643              0
# 644              0
# 645              0
# 646              0
# 647              0
#
# [648 rows x 9 columns]

# %%
datetime.strptime('15' + '09' + '2015' , "%d%m%Y").date()
# Out:
# datetime.date(2015, 9, 15)

# %%
months
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-947b8a09ca50> in <module>()
# ----> 1 months
#
# NameError: name 'months' is not defined
