# %%
import csv
import json
import os
import sys

# %%
os.chdir('/home/ricardo/Tripda/Testes')

# %%
csvfile = open('trips.csv', 'r')
jsonfile = open('trips.json', 'w')

fieldnames = ('id','valid','tc_id','driver_id','trip_created_at','trip_departure_datetime','country','seats_offered','trip_canceled','auto_accept','trip_comment','recurrent','ladies_only','is_return','promo_code','description_code')
reader = csv.DictReader( csvfile, fieldnames)
for row in reader:
    json.dump(row, jsonfile)
    jsonfile.write('\n')

# %%
jsonfile = open('trips.json', 'r')
for row in jsonfile:
    json_row= json.loads(row)
    print json_row["id"]
# Out:
# 100000-2015-05-19-0
# 100001-2015-05-18-0
# 10000-2014-11-16-0
# 100002-2015-05-18-0
# 100002-2015-05-18-1
# 100002-2015-05-25-0
# 100002-2015-05-25-1
# 100002-2015-06-01-0
# 100002-2015-06-01-1
# 100002-2015-06-08-0
# 100002-2015-06-08-1
# 100002-2015-06-15-0
# 100002-2015-06-15-1
# 100002-2015-06-22-0
# 100002-2015-06-22-1
# 100002-2015-06-29-0
# 100002-2015-06-29-1
# 100002-2015-07-06-0
# 100002-2015-07-06-1
# 100002-2015-07-13-0
# 100002-2015-07-13-1
# 100003-2015-05-19-0
# 100004-2015-05-18-0
# 100005-2015-05-18-0
# 100006-2015-05-18-0
# 100006-2015-05-18-1
# 100006-2015-05-25-0
# 100006-2015-05-25-1
# 100006-2015-06-01-0
# 100006-2015-06-01-1
# 100006-2015-06-08-0
# 100006-2015-06-08-1
# 100006-2015-06-15-0
# 100006-2015-06-15-1
# 100006-2015-06-22-0
# 100006-2015-06-22-1
# 100006-2015-06-29-0
# 100006-2015-06-29-1
# 100006-2015-07-06-0
# 100006-2015-07-06-1
# 100007-2015-05-18-0
# 100007-2015-05-18-1
# 100007-2015-05-25-0
# 100007-2015-05-25-1
# 100007-2015-06-01-0
# ...
